# %% [markdown]
# # 14-Cluster Baseline Classification for Parkinson's Disease (Acoustic Features Only)
#
# **This notebook uses 14 feature clusters with mean aggregation, then trains the same models as baseline.**
#
# ## Overview
#
# This notebook implements a baseline classification pipeline with cluster-based feature aggregation:
# 1. Data loading and preprocessing (static audio features only - no demographics)
# 2. **Load 14 cluster assignments and aggregate features by mean (131 → 14 features)**
# 3. Baseline classifier training on aggregated features
# 4. Evaluation on test data
# 5. Comparison with baseline results
#
# **All code is self-contained - no external dependencies on other notebooks.**

# %% [markdown]
# ## 1. Setup and Imports

# %%
# ============================================================
# All Required Imports
# ============================================================

import os
import json
from pathlib import Path
from datetime import datetime
import pickle
import copy

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter, defaultdict
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, roc_auc_score, average_precision_score,
    precision_score, recall_score, f1_score,
    confusion_matrix, classification_report,
    roc_curve, precision_recall_curve
)

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

print("✓ All imports loaded successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# ✓ All imports loaded successfully!
# PyTorch version: 2.8.0+cu128
# CUDA available: True

# %% [markdown]
# ## 2. Configuration

# %%
# ============================================================
# Configuration
# ============================================================

# Random seed for reproducibility
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# ============================================================
# Feature Selection: Phenotype vs Acoustic Only
# ============================================================
# Set to True to include phenotype/demographic features
# Set to False to use only acoustic/static features
USE_PHENOTYPE_FEATURES = False  # ACOUSTIC-ONLY VERSION

print("=" * 60)
print("FEATURE CONFIGURATION")
print("=" * 60)
if USE_PHENOTYPE_FEATURES:
    print("✓ Using: Phenotype/Demographic features + Acoustic features")
else:
    print("✓ Using: Acoustic features only (no phenotype/demographics)")
print("=" * 60)

# Paths
ROOT = Path.cwd()
DATA_PATH = ROOT / 'physionet.org' / 'files' / 'b2ai-voice' / '2.0.1'
OUTPUT_DIR = ROOT / 'outputs' / 'cluster_14_baseline'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Cluster assignments file (from Cluster_Based_Feature_Engineering_no_XG notebook)
CLUSTER_ASSIGNMENTS_FILE = ROOT / 'outputs' / 'cluster_feature_engineering' / 'cluster_assignments_14.csv'

# Data files
PHENOTYPE_FILE = DATA_PATH / 'phenotype.tsv'
STATIC_FILE = DATA_PATH / 'static_features.tsv'

# Visualization settings
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# Device selection
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
    print(f"✓ Using CUDA: {torch.cuda.get_device_name(0)}")
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    DEVICE = torch.device('mps')
    print("✓ Using MPS (Apple Silicon)")
else:
    DEVICE = torch.device('cpu')
    print("✓ Using CPU")

print(f"\nOutput directory: {OUTPUT_DIR}")
print(f"Random seed: {SEED}")
print(f"Data path: {DATA_PATH}")

# Check file existence
print("\n" + "=" * 60)
print("File Existence Check")
print("=" * 60)
print(f"Phenotype file exists: {PHENOTYPE_FILE.exists()}")
print(f"Static features file exists: {STATIC_FILE.exists()}")
print("=" * 60)
# Out:
# ============================================================
# FEATURE CONFIGURATION
# ============================================================
# ✓ Using: Acoustic features only (no phenotype/demographics)
# ============================================================
# ✓ Using CUDA: NVIDIA GeForce RTX 2080 Ti
#
# Output directory: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline
# Random seed: 42
# Data path: /home/Phenotype and Voice for PD/physionet.org/files/b2ai-voice/2.0.1
#
# ============================================================
# File Existence Check
# ============================================================
# Phenotype file exists: True
# Static features file exists: True
# ============================================================

# %% [markdown]
# ## 3. Data Loading and Label Creation

# %%
# ============================================================
# Load Data and Create Labels
# ============================================================

print("=" * 60)
print("LOADING DATA AND CREATING LABELS")
print("=" * 60)

# Load phenotype data
if not PHENOTYPE_FILE.exists():
    raise FileNotFoundError(f"Phenotype file not found: {PHENOTYPE_FILE}")

phenotype_df = pd.read_csv(PHENOTYPE_FILE, sep='\t', low_memory=False)
print(f"✓ Phenotype shape: {phenotype_df.shape}")

# Detect control and Parkinson's columns
control_col = None
for c in phenotype_df.columns:
    if "control" in c.lower() or "healthy" in c.lower():
        control_col = c
        break

if "parkinsons" in phenotype_df.columns:
    pd_col = "parkinsons"
elif "parkinson" in phenotype_df.columns:
    pd_col = "parkinson"
else:
    raise RuntimeError("Cannot detect Parkinson's column")

print(f"✓ Control column: {control_col}")
print(f"✓ Parkinson's column: {pd_col}")

# Create labels
phenotype_df['pd_label'] = phenotype_df[pd_col].astype(str).str.lower().eq("checked").astype(int)
phenotype_df['control_label'] = phenotype_df[control_col].astype(str).str.lower().eq("yes").astype(int)
phenotype_df['label'] = phenotype_df['pd_label']
phenotype_df.loc[phenotype_df['control_label'] == 1, 'label'] = 0

# Keep only Parkinsons and controls
phenotype_df = phenotype_df[(phenotype_df['pd_label'] == 1) | (phenotype_df['control_label'] == 1)]

print(f"\n✓ Label distribution:")
print(phenotype_df['label'].value_counts())

# ============================================================
# Prepare Screening Demographics (if USE_PHENOTYPE_FEATURES is True)
# ============================================================
if USE_PHENOTYPE_FEATURES:
    print("\n" + "=" * 60)
    print("PREPARING SCREENING DEMOGRAPHICS")
    print("=" * 60)
else:
    print("\n" + "=" * 60)
    print("SKIPPING PHENOTYPE FEATURES (Acoustic-only mode)")
    print("=" * 60)
    screening_cols_to_merge = []
    screening_categorical_vars = []
    screening_numeric_vars = []

if USE_PHENOTYPE_FEATURES:
    # Clean age
    if 'age' in phenotype_df.columns:
        def extract_age(value):
            if pd.isna(value):
                return np.nan
            value_str = str(value)
            if 'and above' in value_str.lower() or '90+' in value_str:
                return 90.0
            import re
            matches = re.findall(r'\b([1-9][0-9])\b', value_str)
            if matches:
                for match in matches:
                    age_val = float(match)
                    if 10 <= age_val <= 120:
                        return age_val
            try:
                age_val = float(value_str)
                if 10 <= age_val <= 120:
                    return age_val
            except:
                pass
            return np.nan
        
        phenotype_df['age_clean'] = phenotype_df['age'].apply(extract_age)
        phenotype_df['age_clean'] = pd.to_numeric(phenotype_df['age_clean'], errors='coerce')

    # Calculate BMI
    if 'weight' in phenotype_df.columns and 'height' in phenotype_df.columns:
        weight_data = pd.to_numeric(phenotype_df['weight'], errors='coerce')
        height_data = pd.to_numeric(phenotype_df['height'], errors='coerce')
        
        # Check units
        if 'unit' in phenotype_df.columns:
            units = phenotype_df['unit'].dropna().unique()
            use_metric = 'US customary units' not in str(units).lower() if len(units) > 0 else True
        else:
            use_metric = height_data.mean() > 100 if height_data.notna().any() else True
        
        # Convert to metric if needed
        if not use_metric:
            height_m = height_data * 0.0254  # inches to meters
            weight_kg = weight_data * 0.453592  # lbs to kg
        else:
            if height_data.mean() > 100:  # Likely cm
                height_m = height_data * 0.01  # cm to meters
            else:
                height_m = height_data
            weight_kg = weight_data
        
        # Calculate BMI
        bmi = weight_kg / (height_m ** 2)
        bmi = bmi[(bmi > 10) & (bmi < 60)]
        phenotype_df['bmi'] = np.nan
        phenotype_df.loc[bmi.index, 'bmi'] = bmi.values

    # Select screening variables to include
    # Note: Removed country, hydration_today, caffeine_intake_today
    # Note: Removed weight and height (keeping only BMI)
    screening_vars_to_include = {
        'age': 'age_clean' if 'age_clean' in phenotype_df.columns else 'age',
        'sex': 'sex_at_birth',
        'bmi': 'bmi',  # Only BMI, not weight/height separately
        'ethnicity': 'ethnicity',
        'alcohol_yn': 'alcohol_yn',
        'alcohol_freq': 'alcohol_freq',
        'alcohol_amt': 'alcohol_amt',
        'household_count': 'household_count',
        'caffeine_intake': 'caffeine_intake',  # Generic, not _today
        'hydration': 'hydration',  # Generic, not _today
        'tired_measure': 'tired_measure',
        'smoking_hx': 'smoking_hx',
    }

    # Create screening variables with prefix
    screening_cols_to_merge = []
    screening_categorical_vars = ['sex', 'ethnicity', 'alcohol_yn', 'alcohol_freq', 'alcohol_amt', 'smoking_hx']
    screening_numeric_vars = ['age', 'bmi', 'household_count', 'caffeine_intake', 'hydration', 'tired_measure']

    for var_name, col_name in screening_vars_to_include.items():
        if col_name in phenotype_df.columns:
            screening_var_name = f'screening_{var_name}'
            phenotype_df[screening_var_name] = phenotype_df[col_name]
            screening_cols_to_merge.append(screening_var_name)
            
            # Fill NaN values in screening variables before merging
            if var_name in screening_numeric_vars:
                # For numeric, fill with median or 0
                median_val = phenotype_df[screening_var_name].median()
                if pd.isna(median_val):
                    phenotype_df[screening_var_name] = phenotype_df[screening_var_name].fillna(0)
                else:
                    phenotype_df[screening_var_name] = phenotype_df[screening_var_name].fillna(median_val)
            # Categorical will be handled by encoding step below

    print(f"✓ Prepared {len(screening_cols_to_merge)} screening demographic variables")
    print(f"  Variables: {[v.replace('screening_', '') for v in screening_cols_to_merge]}")

    # ============================================================
    # Encode Categorical Screening Variables
    # ============================================================
    print("\n" + "=" * 60)
    print("ENCODING CATEGORICAL SCREENING VARIABLES")
    print("=" * 60)

    from sklearn.preprocessing import LabelEncoder

    # Store label encoders for potential inverse transform later
    screening_label_encoders = {}

    # For categorical variables, we'll use label encoding (convert to numeric)
    # This allows them to be included in the numeric feature matrix
    for var_name in screening_categorical_vars:
        screening_col = f'screening_{var_name}'
        if screening_col in phenotype_df.columns:
            # Fill missing values with 'unknown' before encoding
            nan_count = phenotype_df[screening_col].isna().sum()
            if nan_count > 0:
                print(f"  Filling {nan_count} NaN values in {var_name} with 'unknown'")
            phenotype_df[screening_col] = phenotype_df[screening_col].fillna('unknown')
            
            # Use label encoding to convert to numeric
            le = LabelEncoder()
            encoded_values = le.fit_transform(phenotype_df[screening_col].astype(str))
            phenotype_df[screening_col] = encoded_values
            
            # Store encoder for reference
            screening_label_encoders[screening_col] = le
            
            print(f"✓ Encoded {var_name}: {len(le.classes_)} unique values")
            print(f"  Classes: {list(le.classes_)[:5]}{'...' if len(le.classes_) > 5 else ''}")

    print(f"\n✓ Encoded {len(screening_label_encoders)} categorical screening variables")

# Load static features
if not STATIC_FILE.exists():
    raise FileNotFoundError(f"Static features file not found: {STATIC_FILE}")

static_df = pd.read_csv(STATIC_FILE, sep='\t', low_memory=False)
print(f"\n✓ Static features shape: {static_df.shape}")

# Merge datasets
merge_cols = ['participant_id', 'session_id']
if 'task_name' in static_df.columns and 'task_name' in phenotype_df.columns:
    merge_cols.append('task_name')

# Merge datasets (include screening demographics only if USE_PHENOTYPE_FEATURES is True)
if USE_PHENOTYPE_FEATURES:
    phenotype_cols_to_merge = merge_cols + ['label', 'pd_label'] + screening_cols_to_merge
else:
    # Acoustic-only mode: only merge labels, no screening demographics
    phenotype_cols_to_merge = merge_cols + ['label', 'pd_label']

merged_df = static_df.merge(
    phenotype_df[phenotype_cols_to_merge],
    on=merge_cols,
    how='inner'
)

print(f"\n✓ Merged dataset shape: {merged_df.shape}")
print(f"  Label distribution: {merged_df['label'].value_counts().to_dict()}")

# Verify both classes are present after merge
if 'label' in merged_df.columns:
    label_counts = merged_df['label'].value_counts()
    if 0 not in label_counts.index:
        raise ValueError("ERROR: No Control (0) samples after merge! Check merge keys.")
    if 1 not in label_counts.index:
        raise ValueError("ERROR: No Parkinson's (1) samples after merge! Check merge keys.")
    print(f"  ✓ Both classes present: Control={label_counts.get(0, 0)}, Parkinson's={label_counts.get(1, 0)}")

# Identify feature columns
id_cols = ['participant_id', 'session_id', 'task_name'] if 'task_name' in merged_df.columns else ['participant_id', 'session_id']
if 'transcription' in merged_df.columns:
    id_cols.append('transcription')
label_cols = ['label', 'pd_label', 'control_label']
feature_cols = [c for c in merged_df.columns if c not in id_cols + label_cols]

# Convert screening categorical variables to numeric if they're still object type after merge
# (Some might not have been encoded if they weren't in phenotype_df)
# Only do this if phenotype features are enabled
if USE_PHENOTYPE_FEATURES:
    for var_name in screening_categorical_vars:
        screening_col = f'screening_{var_name}'
        if screening_col in merged_df.columns:
            if merged_df[screening_col].dtype == 'object':
                # Fill missing and encode
                nan_count = merged_df[screening_col].isna().sum()
                if nan_count > 0:
                    print(f"  Post-merge: Filling {nan_count} NaN values in {var_name} with 'unknown'")
                merged_df[screening_col] = merged_df[screening_col].fillna('unknown').astype(str)
                # Use label encoder to convert to numeric
                le = LabelEncoder()
                merged_df[screening_col] = le.fit_transform(merged_df[screening_col])
                print(f"✓ Post-merge encoded {var_name}: {len(le.classes_)} unique values")
            
            # Also ensure numeric screening variables don't have NaN after merge
            elif var_name in screening_numeric_vars:
                nan_count = merged_df[screening_col].isna().sum()
                if nan_count > 0:
                    median_val = merged_df[screening_col].median()
                    if pd.isna(median_val):
                        merged_df[screening_col] = merged_df[screening_col].fillna(0)
                        print(f"  Post-merge: Filled {nan_count} NaN values in {var_name} with 0")
                    else:
                        merged_df[screening_col] = merged_df[screening_col].fillna(median_val)
                        print(f"  Post-merge: Filled {nan_count} NaN values in {var_name} with median={median_val:.2f}")

# Filter to numeric columns only (now includes encoded categoricals)
feature_cols = [c for c in feature_cols if merged_df[c].dtype in [np.float64, np.float32, np.int64, np.int32]]

print(f"\n✓ Number of feature columns: {len(feature_cols)}")

# Check how many screening demographics are included
screening_features_included = [c for c in feature_cols if c.startswith('screening_')]
print(f"✓ Screening demographics included: {len(screening_features_included)}")
if len(screening_features_included) > 0:
    print(f"  Screening features: {[c.replace('screening_', '') for c in screening_features_included[:10]]}")
    if len(screening_features_included) > 10:
        print(f"  ... and {len(screening_features_included) - 10} more")
    
    # Show breakdown by type
    numeric_screening = [c for c in screening_features_included if c.replace('screening_', '') in screening_numeric_vars]
    categorical_screening = [c for c in screening_features_included if c.replace('screening_', '') in screening_categorical_vars]
    print(f"  - Numeric: {len(numeric_screening)}")
    print(f"  - Categorical (encoded): {len(categorical_screening)}")

print("=" * 60)
# Out:
# ============================================================
# LOADING DATA AND CREATING LABELS
# ============================================================
# ✓ Phenotype shape: (442, 1109)
# ✓ Control column: is_control_participant
# ✓ Parkinson's column: parkinsons
#
# ✓ Label distribution:
# label
# 0    64
# 1    61
# Name: count, dtype: int64
#
# ============================================================
# SKIPPING PHENOTYPE FEATURES (Acoustic-only mode)
# ============================================================
#
# ✓ Static features shape: (19271, 135)
#
# ✓ Merged dataset shape: (4879, 137)
#   Label distribution: {1: 2441, 0: 2438}
#   ✓ Both classes present: Control=2438, Parkinson's=2441
#
# ✓ Number of feature columns: 131
# ✓ Screening demographics included: 0
# ============================================================

# %% [markdown]
# ## 4. Data Preprocessing and Participant-Level Splits

# %% [markdown]
# ## 4.5. Load Cluster Assignments and Aggregate Features

# %%
# ============================================================
# Load 14 Cluster Assignments and Aggregate Features
# ============================================================

print("=" * 60)
print("LOADING CLUSTER ASSIGNMENTS AND AGGREGATING FEATURES")
print("=" * 60)

# Load cluster assignments
if not CLUSTER_ASSIGNMENTS_FILE.exists():
    raise FileNotFoundError(
        f"Cluster assignments file not found: {CLUSTER_ASSIGNMENTS_FILE}\n"
        f"Please run the Cluster_Based_Feature_Engineering_no_XG notebook first."
    )

cluster_df = pd.read_csv(CLUSTER_ASSIGNMENTS_FILE)
print(f"✓ Loaded cluster assignments: {len(cluster_df)} features")
print(f"  Number of clusters: {cluster_df['cluster'].nunique()}")

print(f"\nCluster sizes:")
cluster_sizes = cluster_df['cluster'].value_counts().sort_index()
for cluster_id, size in cluster_sizes.items():
    print(f"  Cluster {cluster_id}: {size} features")

# Create mapping: feature -> cluster
feature_to_cluster = dict(zip(cluster_df['feature'], cluster_df['cluster']))

# Create reverse mapping: cluster -> list of features
cluster_to_features = defaultdict(list)
for feature, cluster_id in feature_to_cluster.items():
    cluster_to_features[cluster_id].append(feature)

print(f"\n✓ Created feature-to-cluster mapping")
print(f"✓ Created cluster-to-features mapping")

# Function to aggregate features by cluster using mean
def aggregate_features_by_cluster(X_data, feature_cols, cluster_to_features, aggregation='mean'):
    """
    Aggregate features by cluster using specified aggregation method.
    """
    if isinstance(X_data, pd.DataFrame):
        X_array = X_data.values
    else:
        X_array = X_data
    
    n_samples = X_array.shape[0]
    n_clusters = len(cluster_to_features)
    
    X_aggregated = np.zeros((n_samples, n_clusters))
    aggregated_feature_names = []
    
    for cluster_id in sorted(cluster_to_features.keys()):
        cluster_features = cluster_to_features[cluster_id]
        
        # Get indices of features in this cluster
        feature_indices = [feature_cols.index(f) for f in cluster_features if f in feature_cols]
        
        if len(feature_indices) == 0:
            print(f"  ⚠ Warning: No features found for cluster {cluster_id}")
            X_aggregated[:, cluster_id - 1] = 0  # cluster_id is 1-indexed
        else:
            # Extract features for this cluster
            cluster_data = X_array[:, feature_indices]
            
            # Aggregate using mean
            X_aggregated[:, cluster_id - 1] = np.mean(cluster_data, axis=1)
        
        aggregated_feature_names.append(f"cluster_{cluster_id}")
    
    return X_aggregated, aggregated_feature_names

print("\n" + "=" * 60)
print("FEATURE AGGREGATION")
print("=" * 60)
print("=" * 60)
# Out:
# ============================================================
# LOADING CLUSTER ASSIGNMENTS AND AGGREGATING FEATURES
# ============================================================
# ✓ Loaded cluster assignments: 131 features
#   Number of clusters: 14
#
# Cluster sizes:
#   Cluster 1: 19 features
#   Cluster 2: 8 features
#   Cluster 3: 15 features
#   Cluster 4: 15 features
#   Cluster 5: 16 features
#   Cluster 6: 6 features
#   Cluster 7: 3 features
#   Cluster 8: 7 features
#   Cluster 9: 7 features
#   Cluster 10: 5 features
#   Cluster 11: 6 features
#   Cluster 12: 7 features
#   Cluster 13: 9 features
#   Cluster 14: 8 features
#
# ✓ Created feature-to-cluster mapping
# ✓ Created cluster-to-features mapping
#
# ============================================================
# FEATURE AGGREGATION
# ============================================================
# ============================================================

# %%
# ============================================================
# Data Cleaning and Participant-Level Splits
# ============================================================

print("=" * 60)
print("DATA CLEANING & PARTICIPANT-LEVEL SPLITS")
print("=" * 60)

# Extract features and labels
X_full = merged_df[feature_cols].copy()
y_full = merged_df['label'].astype(int).copy()
pid_full = merged_df['participant_id'].astype(str).copy()

# Clean: handle NaN and Inf
X_full = X_full.replace([np.inf, -np.inf], np.nan)

# Handle missing values: fill with column means/medians
# For columns that are all NaN, fill with 0
for col in X_full.columns:
    if X_full[col].isna().all():
        # If entire column is NaN, fill with 0
        X_full[col].fillna(0, inplace=True)
        print(f"⚠ Warning: Column '{col}' was entirely NaN, filled with 0")
    elif X_full[col].dtype in [np.float64, np.float32, np.int64, np.int32]:
        # For numeric columns, fill with median (more robust than mean)
        col_median = X_full[col].median()
        if pd.isna(col_median):
            # If median is also NaN, use 0
            X_full[col].fillna(0, inplace=True)
        else:
            X_full[col].fillna(col_median, inplace=True)
    else:
        # For non-numeric, fill with mode or 0
        mode_val = X_full[col].mode()
        if len(mode_val) > 0:
            X_full[col].fillna(mode_val.iloc[0], inplace=True)
        else:
            X_full[col].fillna(0, inplace=True)

# Verify no NaN/Inf remain
remaining_nan = X_full.isna().sum().sum()
remaining_inf = np.isinf(X_full.select_dtypes(include=[np.number])).sum().sum()
if remaining_nan > 0 or remaining_inf > 0:
    print(f"⚠ Warning: Still have {remaining_nan} NaN and {remaining_inf} Inf values after cleaning")
    # Force fill any remaining NaN/Inf with 0
    X_full = X_full.fillna(0)
    X_full = X_full.replace([np.inf, -np.inf], 0)

# Participant-level splits (no data leakage)
unique_participants = pid_full.unique()
participant_labels = merged_df.groupby('participant_id')['label'].first()

# Split participants (not recordings)
pids_train_val, pids_test, y_p_train_val, y_p_test = train_test_split(
    unique_participants,
    participant_labels.loc[unique_participants],
    test_size=0.2,
    random_state=SEED,
    stratify=participant_labels.loc[unique_participants]
)

pids_train, pids_val, y_p_train, y_p_val = train_test_split(
    pids_train_val,
    y_p_train_val,
    test_size=0.2,
    random_state=SEED,
    stratify=y_p_train_val
)

# Map participant splits to recording level
train_mask = pid_full.isin(pids_train)
val_mask = pid_full.isin(pids_val)
test_mask = pid_full.isin(pids_test)

X_train_raw = X_full[train_mask].copy()
X_val_raw = X_full[val_mask].copy()
X_test_raw = X_full[test_mask].copy()

y_train_raw = y_full[train_mask].copy()
y_val_raw = y_full[val_mask].copy()
y_test_raw = y_full[test_mask].copy()

# Extract participant IDs for each split (CRITICAL for participant-level CV)
pid_train = pid_full[train_mask].values
pid_val = pid_full[val_mask].values
pid_test = pid_full[test_mask].values

print(f"\n✓ Recording-level splits:")
print(f"  Train: {len(X_train_raw)} ({y_train_raw.value_counts().to_dict()})")
print(f"  Val:   {len(X_val_raw)} ({y_val_raw.value_counts().to_dict()})")
print(f"  Test:  {len(X_test_raw)} ({y_test_raw.value_counts().to_dict()})")
print(f"\n✓ Unique participants per split:")
print(f"  Train: {len(np.unique(pid_train))}, Val: {len(np.unique(pid_val))}, Test: {len(np.unique(pid_test))}")

# Standardize using training data only (BEFORE aggregation)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_raw.values.astype(np.float32))
X_val_scaled = scaler.transform(X_val_raw.values.astype(np.float32))
X_test_scaled = scaler.transform(X_test_raw.values.astype(np.float32))

# Clip extreme values
X_train_scaled = np.clip(X_train_scaled, -8.0, 8.0)
X_val_scaled = np.clip(X_val_scaled, -8.0, 8.0)
X_test_scaled = np.clip(X_test_scaled, -8.0, 8.0)

# ============================================================
# AGGREGATE FEATURES BY CLUSTER (MEAN)
# ============================================================
print("\n" + "=" * 60)
print("AGGREGATING FEATURES BY CLUSTER (MEAN)")
print("=" * 60)

# Aggregate features using mean per cluster
X_train_agg, agg_feature_names = aggregate_features_by_cluster(
    X_train_scaled, feature_cols, cluster_to_features, aggregation='mean'
)
X_val_agg, _ = aggregate_features_by_cluster(
    X_val_scaled, feature_cols, cluster_to_features, aggregation='mean'
)
X_test_agg, _ = aggregate_features_by_cluster(
    X_test_scaled, feature_cols, cluster_to_features, aggregation='mean'
)

print(f"\n✓ Feature aggregation complete:")
print(f"  Original features: {len(feature_cols)}")
print(f"  Aggregated features: {len(agg_feature_names)}")
print(f"  Reduction: {len(feature_cols)} → {len(agg_feature_names)} ({len(agg_feature_names)/len(feature_cols)*100:.1f}%)")

# Convert to DataFrames (using aggregated features)
X_train = pd.DataFrame(X_train_agg, columns=agg_feature_names, index=X_train_raw.index)
X_val = pd.DataFrame(X_val_agg, columns=agg_feature_names, index=X_val_raw.index)
X_test = pd.DataFrame(X_test_agg, columns=agg_feature_names, index=X_test_raw.index)

# Store global scaler for later use (for original features)
global_scaler = scaler

# Create a NEW scaler for aggregated features (fitted on aggregated training data)
scaler_agg = StandardScaler()
X_train_agg_scaled_final = scaler_agg.fit_transform(X_train_agg.astype(np.float32))
X_val_agg_scaled_final = scaler_agg.transform(X_val_agg.astype(np.float32))
X_test_agg_scaled_final = scaler_agg.transform(X_test_agg.astype(np.float32))

# Clip extreme values
X_train_agg_scaled_final = np.clip(X_train_agg_scaled_final, -8.0, 8.0)
X_val_agg_scaled_final = np.clip(X_val_agg_scaled_final, -8.0, 8.0)
X_test_agg_scaled_final = np.clip(X_test_agg_scaled_final, -8.0, 8.0)

# Update feature dimension to use aggregated features
original_feature_cols = feature_cols.copy()  # Keep original for reference
feature_dim = len(agg_feature_names)
input_dim = feature_dim
feature_cols = agg_feature_names  # Update to use aggregated feature names

# Update DataFrames to use the properly scaled aggregated data
X_train = pd.DataFrame(X_train_agg_scaled_final, columns=agg_feature_names, index=X_train_raw.index)
X_val = pd.DataFrame(X_val_agg_scaled_final, columns=agg_feature_names, index=X_val_raw.index)
X_test = pd.DataFrame(X_test_agg_scaled_final, columns=agg_feature_names, index=X_test_raw.index)

# Store aggregated scaler for later use (for synthetic data)
global_scaler_agg = scaler_agg

print(f"\n✓ Feature dimension: {feature_dim} (aggregated from {len(original_feature_cols)} original features)")
print(f"✓ Data cleaned, standardized, and aggregated by cluster")
print(f"✓ Aggregated scaler created and stored (for synthetic data)")
print("=" * 60)
# Out:
# ============================================================
# DATA CLEANING & PARTICIPANT-LEVEL SPLITS
# ============================================================
#
# ✓ Recording-level splits:
#   Train: 3071 ({1: 1557, 0: 1514})
#   Val:   832 ({1: 421, 0: 411})
#   Test:  976 ({0: 513, 1: 463})
#
# ✓ Unique participants per split:
#   Train: 80, Val: 20, Test: 25
#
# ============================================================
# AGGREGATING FEATURES BY CLUSTER (MEAN)
# ============================================================
#
# ✓ Feature aggregation complete:
#   Original features: 131
#   Aggregated features: 14
#   Reduction: 131 → 14 (10.7%)
#
# ✓ Feature dimension: 14 (aggregated from 131 original features)
# ✓ Data cleaned, standardized, and aggregated by cluster
# ✓ Aggregated scaler created and stored (for synthetic data)
# ============================================================

# %% [markdown]
# ## 5. Baseline Classifier Architecture

# %%
# ============================================================
# Baseline Classifier: RegularizedHybridNet
# ============================================================

class RegularizedHybridNet(nn.Module):
    """
    Regularized Hybrid Network for binary classification.
    Updated with increased dropout to reduce overfitting.
    """
    def __init__(self, input_dim):
        super().__init__()
        self.fc_in = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.SiLU(),
            nn.Dropout(0.50),  # Increased from 0.35 to reduce overfitting
        )
        self.block1 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.SiLU(),
            nn.Dropout(0.50),  # Increased from 0.35
        )
        self.block2 = nn.Sequential(
            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.SiLU(),
            nn.Dropout(0.50),  # Increased from 0.35
        )
        self.block3 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(),
            nn.Dropout(0.45),  # Increased from 0.35
        )
        self.block4 = nn.Sequential(
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.40),  # Increased from 0.30
        )
        self.block5 = nn.Sequential(
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.35),  # Increased from 0.25
        )
        self.fc_out = nn.Linear(128, 1)
    
    def forward(self, x):
        x = self.fc_in(x)
        x = x + self.block1(x)
        x = x + self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        return self.fc_out(x).squeeze(1)

print("✓ RegularizedHybridNet defined")
test_model = RegularizedHybridNet(input_dim)
total_params = sum(p.numel() for p in test_model.parameters())
print(f"  Total parameters: {total_params:,}")
del test_model
# Out:
# ✓ RegularizedHybridNet defined
#   Total parameters: 2,811,649

# %% [markdown]
# ## 6. Training Functions

# %%
# ============================================================
# Baseline Classifier Training Function
# ============================================================
import copy  # For proper model state deepcopy

def train_model_with_checkpointing(
    model, train_loader, val_loader,
    epochs=100, lr=6e-4, weight_decay=8e-3,  # Further reduced LR, increased weight decay
    min_delta=1e-4, gradient_clip=0.5,  # Reduced gradient clip for more stable gradients
    use_data_augmentation=True, noise_std=0.01,  # Reduced noise (was 0.03)
    label_smoothing=0.1,  # Add label smoothing to reduce overconfidence
    patience=6  # Early stopping patience
):
    """Train baseline classifier with checkpointing."""
    model = model.to(DEVICE)
    # Use label smoothing to reduce overconfidence and overfitting
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    # Use OneCycleLR for better convergence
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=lr,
        epochs=epochs,
        steps_per_epoch=len(train_loader),
        pct_start=0.2
    )
    
    history = {
        'train_loss': [], 'val_loss': [],
        'train_acc': [], 'val_acc': [],
        'learning_rate': [],  # Fixed: added missing comma
        'val_roc_auc': [],  # Track validation ROC-AUC
    }
    
    best_val_roc_auc = -1.0  # Track best ROC-AUC (higher is better)
    best_model_state = None
    best_epoch = 0
    no_improve = 0  # Early stopping counter
    
    print(f"Training on device: {DEVICE}")
    print(f"Epochs: {epochs}, LR: {lr:.0e}, Weight decay: {weight_decay:.0e}")
    print("=" * 60)
    
    for epoch in range(epochs):
        # Training
        model.train()
        running_loss = 0
        running_correct = 0
        total = 0
        
        for xb, yb in train_loader:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            
            # Squeeze labels to match logits shape (batch_size, 1) -> (batch_size,)
            yb = yb.squeeze(1) if yb.dim() > 1 else yb
            
            if use_data_augmentation and model.training:
                noise = torch.randn_like(xb) * noise_std
                xb = xb + noise
            
            optimizer.zero_grad()
            logits = model(xb)
            
            # Apply label smoothing if specified
            if label_smoothing > 0:
                # Smooth labels: 0 -> label_smoothing, 1 -> 1-label_smoothing
                yb_smooth = yb.float() * (1 - 2 * label_smoothing) + label_smoothing
                loss = criterion(logits, yb_smooth)
            else:
                loss = criterion(logits, yb.float())
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), gradient_clip)
            optimizer.step()
            scheduler.step()  # Step scheduler per batch (OneCycleLR requirement)
            
            running_loss += loss.item() * xb.size(0)
            preds = (torch.sigmoid(logits) >= 0.5).float()
            running_correct += (preds == yb).sum().item()
            total += xb.size(0)
        
        train_loss = running_loss / total
        train_acc = running_correct / total
        
        # Validation
        model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        val_all_probs = []
        val_all_labels = []
        
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                
                # Squeeze labels to match logits shape (batch_size, 1) -> (batch_size,)
                yb = yb.squeeze(1) if yb.dim() > 1 else yb
                
                logits = model(xb)
                loss = criterion(logits, yb.float())
                val_loss += loss.item() * xb.size(0)
                preds = (torch.sigmoid(logits) >= 0.5).float()
                val_correct += (preds == yb).sum().item()
                # Get predictions and probabilities for ROC-AUC
                probs = torch.sigmoid(logits).cpu().numpy().flatten()
                preds = (probs >= 0.5).astype(int)  # Use numpy .astype() not .float()
                yb_np = yb.cpu().numpy()
                
                # Store for ROC-AUC calculation
                val_all_probs.extend(probs)
                val_all_labels.extend(yb_np)
                val_total += xb.size(0)
        
        val_loss /= val_total
        val_acc = val_correct / val_total
        
        # Calculate validation ROC-AUC
        val_y_true = np.array(val_all_labels)
        val_y_probs = np.array(val_all_probs)
        if len(np.unique(val_y_true)) > 1:
            val_roc_auc = roc_auc_score(val_y_true, val_y_probs)
        else:
            val_roc_auc = 0.0  # Handle edge case with single class
        
        
        current_lr = optimizer.param_groups[0]['lr']
        
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        history['val_roc_auc'].append(val_roc_auc)
        history['learning_rate'].append(current_lr)
        
        # Select best model based on Validation ROC-AUC (higher is better)
        if val_roc_auc > best_val_roc_auc + min_delta:
            best_val_roc_auc = val_roc_auc
            best_model_state = copy.deepcopy(model.state_dict())  # Fixed: use deepcopy
            best_epoch = epoch
            no_improve = 0  # Reset counter on improvement
        else:
            no_improve += 1
            # Early stopping
            if no_improve >= patience:
                print(f"\n⏹ Early stopping at epoch {epoch+1}. Best epoch: {best_epoch+1} (AUC {best_val_roc_auc:.4f})")
                break
        
        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch {epoch+1:3d}/{epochs}: "
                  f"train_loss={train_loss:.4f}, val_loss={val_loss:.4f}, "
                  f"train_acc={train_acc:.3f}, val_acc={val_acc:.3f}, "
                  f"val_roc_auc={val_roc_auc:.4f}")
    
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\n✓ Loaded best model from epoch {best_epoch + 1} (Val ROC-AUC: {best_val_roc_auc:.4f})")
    
    return model, history, best_epoch

print("✓ Baseline training function defined")
# Out:
# ✓ Baseline training function defined

# %% [markdown]
# ## 7. Evaluation Functions

# %%
# ============================================================
# Evaluation Function
# ============================================================

def find_best_threshold(model, loader):
    """Find optimal threshold on validation set based on F1 score."""
    from sklearn.metrics import f1_score
    model.eval()
    probs, ys = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            yb = yb.squeeze(1).cpu().numpy().astype(int)
            p = torch.sigmoid(model(xb)).cpu().numpy().flatten()
            probs.append(p)
            ys.append(yb)
    probs = np.concatenate(probs)
    ys = np.concatenate(ys)
    
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(ys, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

def evaluate_on_real(model, loader, threshold=0.5):
    """Evaluate model on real data with configurable threshold."""
    model.eval()
    all_probs = []
    all_labels = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)
            
            # Squeeze labels if needed
            yb = yb.squeeze(1) if yb.dim() > 1 else yb
            
            logits = model(xb)
            if logits.ndim > 1:
                logits = logits.squeeze(-1)
            
            probs = torch.sigmoid(logits)
            all_probs.append(probs.cpu().numpy().ravel())
            all_labels.append(yb.cpu().numpy().ravel())
    
    y_prob = np.concatenate(all_probs).astype(float)
    y_true = np.concatenate(all_labels).astype(int)
    
    mask = np.isfinite(y_prob)
    if not np.all(mask):
        y_prob = y_prob[mask]
        y_true = y_true[mask]
    
    y_pred = (y_prob >= threshold).astype(int)  # Use configurable threshold
    
    acc = accuracy_score(y_true, y_pred)
    
    if len(np.unique(y_true)) < 2:
        auc = np.nan
    else:
        auc = roc_auc_score(y_true, y_prob)
    
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    # Calculate precision and recall
    if len(np.unique(y_true)) < 2:
        prec = np.nan
        rec = np.nan
    else:
        prec = precision_score(y_true, y_pred, zero_division=0)
        rec = recall_score(y_true, y_pred, zero_division=0)
    
    return {
        'accuracy': acc,
        'roc_auc': auc,
        'f1': f1,
        'precision': prec,
        'recall': rec
    }

print("✓ Evaluation function defined")
# Out:
# ✓ Evaluation function defined

# %% [markdown]
# ## 8. Neural Network: Baseline Experiment

# %%
# ============================================================
# Device Selection with Safe CPU Fallback
# ============================================================

def get_device():
    # Try to use CUDA if available, otherwise CPU
    if torch.cuda.is_available():
        try:
            device = torch.device("cuda")
            # Try a tiny allocation to check if CUDA is actually usable
            _ = torch.tensor([0.0], device=device)
            print("✅ Using CUDA GPU")
            return device
        except RuntimeError as e:
            # If OOM or other CUDA error, fall back to CPU
            print(f"⚠️ CUDA error ({e}); falling back to CPU.")
            return torch.device("cpu")
    else:
        print("⚠️ CUDA not available, using CPU.")
        return torch.device("cpu")

DEVICE = get_device()
print("Final DEVICE:", DEVICE)
# Out:
# ⚠️ CUDA error (CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# ); falling back to CPU.
# Final DEVICE: cpu

# %%
# ============================================================
# Experiment 0: Train on Real Data (Baseline)
# ============================================================

print("=" * 60)
print("EXPERIMENT 0: Train on REAL Training Data → Test on REAL Test Data")
print("=" * 60)

# Prepare real training and validation data loaders
from sklearn.preprocessing import StandardScaler

X_train_np_real = X_train.values.astype(np.float32)
y_train_np_real = y_train_raw.values.astype(int).astype(np.float32)

# Clean: remove NaN/Inf
train_finite_mask = np.isfinite(X_train_np_real).all(axis=1) & np.isfinite(y_train_np_real)
X_train_np_real = X_train_np_real[train_finite_mask]
y_train_np_real = y_train_np_real[train_finite_mask]

# Prepare validation data
X_val_np_real = X_val.values.astype(np.float32)
y_val_np_real = y_val_raw.values.astype(int).astype(np.float32)

val_finite_mask = np.isfinite(X_val_np_real).all(axis=1) & np.isfinite(y_val_np_real)
X_val_np_real = X_val_np_real[val_finite_mask]
y_val_np_real = y_val_np_real[val_finite_mask]

# Standardize features (fit on train, transform train/val/test)
scaler = StandardScaler()
X_train_np_real = scaler.fit_transform(X_train_np_real)
X_val_np_real = scaler.transform(X_val_np_real)

print(f"Training samples: {len(X_train_np_real)}")
print(f"  - Control (0): {(y_train_np_real == 0).sum()}")
print(f"  - Parkinson's (1): {(y_train_np_real == 1).sum()}")

print(f"\nValidation samples: {len(X_val_np_real)}")
print(f"  - Control (0): {(y_val_np_real == 0).sum()}")
print(f"  - Parkinson's (1): {(y_val_np_real == 1).sum()}")

# Create DataLoaders
train_tensor_x = torch.tensor(X_train_np_real, dtype=torch.float32)
train_tensor_y = torch.tensor(y_train_np_real.reshape(-1, 1), dtype=torch.float32)

val_tensor_x = torch.tensor(X_val_np_real, dtype=torch.float32)
val_tensor_y = torch.tensor(y_val_np_real.reshape(-1, 1), dtype=torch.float32)

train_dataset = TensorDataset(train_tensor_x, train_tensor_y)
val_dataset = TensorDataset(val_tensor_x, val_tensor_y)

train_loader_real = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader_real = DataLoader(val_dataset, batch_size=128, shuffle=False)

# Prepare test loader (reuse from Experiment 1 setup, but create it here if not already defined)
# Prepare test data with standardization
if 'test_loader' not in globals():
    X_test_np = X_test.values.astype(np.float32)
    # Standardize test data using the same scaler fitted on training data
    X_test_np = scaler.transform(X_test_np)
    X_test_tensor = torch.tensor(X_test_np, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test_raw.values.reshape(-1, 1), dtype=torch.float32)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# Create and train model
print("\nTraining baseline model on real data...")

# nn_best_params should be set by grid search in section 8.0
# If grid search hasn't been run, use default parameters as fallback
if 'nn_best_params' not in globals() or nn_best_params is None:
    print("⚠ Grid search not run yet. Using default parameters.")
    nn_best_params = {
        'lr': 6e-4,
        'weight_decay': 8e-3,
        'noise_std': 0.01,
        'label_smoothing': 0.1,
        'gradient_clip': 0.5
    }
else:
    print(f"✓ Using grid search parameters: {nn_best_params}")

model_real_baseline = RegularizedHybridNet(input_dim).to(DEVICE)

model_real_baseline, hist_real_baseline, best_epoch_real_baseline = train_model_with_checkpointing(
    model_real_baseline,
    train_loader=train_loader_real,
    val_loader=val_loader_real,
    epochs=40,
    lr=nn_best_params['lr'],
    weight_decay=nn_best_params['weight_decay'],
    use_data_augmentation=True,
    noise_std=nn_best_params['noise_std'],
    label_smoothing=nn_best_params['label_smoothing'],
    gradient_clip=nn_best_params['gradient_clip'],
    patience=6  # Early stopping patience
)

# Find best threshold on validation set
print("\n" + "=" * 60)
print("TUNING THRESHOLD ON VALIDATION SET")
print("=" * 60)
best_threshold, best_val_f1 = find_best_threshold(model_real_baseline, val_loader_real)
print(f"Best threshold on validation: {best_threshold:.3f} (val F1={best_val_f1:.4f})")

# Evaluate on real test data with optimal threshold
print("\n" + "=" * 60)
print("EVALUATING ON REAL TEST DATA")
print("=" * 60)

metrics_real_baseline = evaluate_on_real(model_real_baseline, test_loader, threshold=best_threshold)

print("\nPerformance on REAL test data (trained on REAL training data - Baseline):")
for k, v in metrics_real_baseline.items():
    print(f"  {k}: {v:.4f}")
print(f"  (using threshold: {best_threshold:.3f})")

print("=" * 60)
# Out:
# ============================================================
# EXPERIMENT 0: Train on REAL Training Data → Test on REAL Test Data
# ============================================================
# Training samples: 3071
#   - Control (0): 1514
#   - Parkinson's (1): 1557
#
# Validation samples: 832
#   - Control (0): 411
#   - Parkinson's (1): 421
#
# Training baseline model on real data...
# ⚠ Grid search not run yet. Using default parameters.
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7163, val_loss=0.6878, train_acc=0.496, val_acc=0.513, val_roc_auc=0.6171
# Epoch  10/40: train_loss=0.6210, val_loss=0.5929, train_acc=0.694, val_acc=0.643, val_roc_auc=0.7342
# Epoch  20/40: train_loss=0.5875, val_loss=0.5932, train_acc=0.743, val_acc=0.651, val_roc_auc=0.7436
# Epoch  30/40: train_loss=0.5670, val_loss=0.5879, train_acc=0.763, val_acc=0.666, val_roc_auc=0.7578
#
# ⏹ Early stopping at epoch 32. Best epoch: 26 (AUC 0.7607)
#
# ✓ Loaded best model from epoch 26 (Val ROC-AUC: 0.7607)
#
# ============================================================
# TUNING THRESHOLD ON VALIDATION SET
# ============================================================
# Best threshold on validation: 0.400 (val F1=0.7144)
#
# ============================================================
# EVALUATING ON REAL TEST DATA
# ============================================================
#
# Performance on REAL test data (trained on REAL training data - Baseline):
#   accuracy: 0.6762
#   roc_auc: 0.7970
#   f1: 0.7179
#   precision: 0.6119
#   recall: 0.8683
#   (using threshold: 0.400)
# ============================================================

# %% [markdown]
# ### 8.1. Neural Network: Hyperparameter Grid Search

# %%
# ============================================================
# Neural Network: Default Parameters
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: DEFAULT PARAMETERS")
print("=" * 60)

# Set default parameters for Neural Network
nn_best_params = {
    'lr': 6e-4,
    'weight_decay': 8e-3,
    'noise_std': 0.01,
    'label_smoothing': 0.1,
    'gradient_clip': 0.5
}

print(f"\nUsing default parameters: {nn_best_params}")
print(f"\n✓ Parameters stored in 'nn_best_params' for use in 5-fold CV and final training")
print("=" * 60)
# Out:
# ============================================================
# NEURAL NETWORK: DEFAULT PARAMETERS
# ============================================================
#
# Using default parameters: {'lr': 0.0006, 'weight_decay': 0.008, 'noise_std': 0.01, 'label_smoothing': 0.1, 'gradient_clip': 0.5}
#
# ✓ Parameters stored in 'nn_best_params' for use in 5-fold CV and final training
# ============================================================

# %% [markdown]
# ## 8.2. Neural Network: Cross-Validation Functions

# %%
# ============================================================
# Cross-Validation Functions (Participant-Level)
# ============================================================

from sklearn.model_selection import StratifiedKFold
from collections import defaultdict

def participant_level_cross_validation(
    X_full, y_full, pid_full, 
    n_splits=5,
    epochs=40,
    lr=6e-4,
    weight_decay=8e-3,
    use_data_augmentation=True,
    noise_std=0.01,
    label_smoothing=0.1,
    patience=6,
    verbose=True
):
    """
    Perform participant-level stratified k-fold cross-validation.
    
    This ensures no data leakage by splitting at the participant level,
    not the recording level.
    """
    print("=" * 60)
    print(f"PARTICIPANT-LEVEL {n_splits}-FOLD CROSS-VALIDATION")
    print("=" * 60)
    
    # Get unique participants and their labels
    # Ensure pid_full and y_full are aligned (convert to numpy for grouping)
    pid_full_np = pid_full.values if isinstance(pid_full, pd.Series) else pid_full
    y_full_np = y_full.values if isinstance(y_full, pd.Series) else y_full
    
    # Create a DataFrame to group by participant
    df_temp = pd.DataFrame({
        'participant_id': pid_full_np,
        'label': y_full_np
    })
    
    # Get unique participants and their labels (use first label per participant)
    participant_df = df_temp.groupby('participant_id')['label'].first().reset_index()
    unique_participants = participant_df['participant_id'].values
    participant_labels = participant_df['label'].values
    
    # Verify we have participants
    if len(unique_participants) == 0:
        raise ValueError("ERROR: No unique participants found! Check pid_full and y_full alignment.")
    if len(unique_participants) < n_splits:
        raise ValueError(f"ERROR: Only {len(unique_participants)} unique participants, but need at least {n_splits} for {n_splits}-fold CV!")
    
    print(f"✓ Found {len(unique_participants)} unique participants")
    print(f"  Label distribution: {pd.Series(participant_labels).value_counts().to_dict()}")
    
    # Create participant-level k-fold splitter
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    # Store results for each fold
    cv_results = {
        'fold': [],
        'train_acc': [],
        'val_acc': [],
        'val_roc_auc': [],
        'val_f1': [],
        'test_acc': [],
        'test_roc_auc': [],
        'test_f1': [],
        'best_epoch': [],
        'best_threshold': []
    }
    
    fold_models = []
    fold_histories = []
    
    for fold, (train_pid_idx, val_pid_idx) in enumerate(skf.split(unique_participants, participant_labels)):
        print(f"\n{'='*60}")
        print(f"FOLD {fold + 1}/{n_splits}")
        print(f"{'='*60}")
        
        # Get participant IDs for this fold
        train_pids = unique_participants[train_pid_idx]
        val_pids = unique_participants[val_pid_idx]
        
        # Map to recording level (use numpy version)
        pid_full_np = pid_full.values if isinstance(pid_full, pd.Series) else pid_full
        train_mask = np.isin(pid_full_np, train_pids)
        val_mask = np.isin(pid_full_np, val_pids)
        
        # Split train into train/val for early stopping
        # Use 80% of train_pids for training, 20% for validation
        train_pids_subset = unique_participants[train_pid_idx]
        train_pids_subset_labels = participant_labels[train_pid_idx]
        
        train_pids_train, train_pids_val, _, _ = train_test_split(
            train_pids_subset,
            train_pids_subset_labels,
            test_size=0.2,
            random_state=SEED,
            stratify=train_pids_subset_labels
        )
        
        # Create masks (use numpy version for consistency)
        pid_full_np = pid_full.values if isinstance(pid_full, pd.Series) else pid_full
        train_mask_final = np.isin(pid_full_np, train_pids_train)
        val_mask_final = np.isin(pid_full_np, train_pids_val)
        test_mask_final = np.isin(pid_full_np, val_pids)  # This is the CV test set
        
        # Extract data
        # Convert to numpy if needed
        if isinstance(X_full, pd.DataFrame):
            X_train_cv = X_full.loc[train_mask_final].values.astype(np.float32)
            X_val_cv = X_full.loc[val_mask_final].values.astype(np.float32)
            X_test_cv = X_full.loc[test_mask_final].values.astype(np.float32)
        else:
            X_train_cv = X_full[train_mask_final].astype(np.float32)
            X_val_cv = X_full[val_mask_final].astype(np.float32)
            X_test_cv = X_full[test_mask_final].astype(np.float32)
        
        if isinstance(y_full, pd.Series):
            y_train_cv = y_full.loc[train_mask_final].values.astype(int)
            y_val_cv = y_full.loc[val_mask_final].values.astype(int)
            y_test_cv = y_full.loc[test_mask_final].values.astype(int)
        else:
            y_train_cv = y_full[train_mask_final].astype(int)
            y_val_cv = y_full[val_mask_final].astype(int)
            y_test_cv = y_full[test_mask_final].astype(int)
        
        # Standardize
        scaler_cv = StandardScaler()
        X_train_cv = scaler_cv.fit_transform(X_train_cv)
        X_val_cv = scaler_cv.transform(X_val_cv)
        X_test_cv = scaler_cv.transform(X_test_cv)
        
        # Clip extreme values
        X_train_cv = np.clip(X_train_cv, -8.0, 8.0)
        X_val_cv = np.clip(X_val_cv, -8.0, 8.0)
        X_test_cv = np.clip(X_test_cv, -8.0, 8.0)
        
        print(f"Train: {len(X_train_cv)} samples ({np.sum(y_train_cv == 0)} Control, {np.sum(y_train_cv == 1)} PD)")
        print(f"Val (for early stopping): {len(X_val_cv)} samples ({np.sum(y_val_cv == 0)} Control, {np.sum(y_val_cv == 1)} PD)")
        print(f"Test (CV fold): {len(X_test_cv)} samples ({np.sum(y_test_cv == 0)} Control, {np.sum(y_test_cv == 1)} PD)")
        
        # Create data loaders
        train_dataset_cv = TensorDataset(
            torch.tensor(X_train_cv, dtype=torch.float32),
            torch.tensor(y_train_cv.reshape(-1, 1), dtype=torch.float32)
        )
        val_dataset_cv = TensorDataset(
            torch.tensor(X_val_cv, dtype=torch.float32),
            torch.tensor(y_val_cv.reshape(-1, 1), dtype=torch.float32)
        )
        test_dataset_cv = TensorDataset(
            torch.tensor(X_test_cv, dtype=torch.float32),
            torch.tensor(y_test_cv.reshape(-1, 1), dtype=torch.float32)
        )
        
        train_loader_cv = DataLoader(train_dataset_cv, batch_size=128, shuffle=True)
        val_loader_cv = DataLoader(val_dataset_cv, batch_size=128, shuffle=False)
        test_loader_cv = DataLoader(test_dataset_cv, batch_size=128, shuffle=False)
        
        # Train model
        model_cv = RegularizedHybridNet(input_dim).to(DEVICE)
        model_cv, hist_cv, best_epoch_cv = train_model_with_checkpointing(
            model_cv,
            train_loader=train_loader_cv,
            val_loader=val_loader_cv,
            epochs=epochs,
            lr=lr,
            weight_decay=weight_decay,
            use_data_augmentation=use_data_augmentation,
            noise_std=noise_std,
            label_smoothing=label_smoothing,
            patience=patience
        )
        
        # Find best threshold on validation set
        best_threshold_cv, best_val_f1_cv = find_best_threshold(model_cv, val_loader_cv)
        
        # Evaluate on validation set
        metrics_val_cv = evaluate_on_real(model_cv, val_loader_cv, threshold=best_threshold_cv)
        
        # Evaluate on test set (CV fold)
        metrics_test_cv = evaluate_on_real(model_cv, test_loader_cv, threshold=best_threshold_cv)
        
        # Store results
        cv_results['fold'].append(fold + 1)
        cv_results['train_acc'].append(hist_cv['train_acc'][-1])
        cv_results['val_acc'].append(metrics_val_cv['accuracy'])
        cv_results['val_roc_auc'].append(metrics_val_cv['roc_auc'])
        cv_results['val_f1'].append(metrics_val_cv['f1'])
        cv_results['test_acc'].append(metrics_test_cv['accuracy'])
        cv_results['test_roc_auc'].append(metrics_test_cv['roc_auc'])
        cv_results['test_f1'].append(metrics_test_cv['f1'])
        cv_results['best_epoch'].append(best_epoch_cv + 1)
        cv_results['best_threshold'].append(best_threshold_cv)
        
        fold_models.append(model_cv)
        fold_histories.append(hist_cv)
        
        if verbose:
            print(f"\nFold {fold + 1} Results:")
            print(f"  Validation - Acc: {metrics_val_cv['accuracy']:.4f}, ROC-AUC: {metrics_val_cv['roc_auc']:.4f}, F1: {metrics_val_cv['f1']:.4f}")
            print(f"  Test (CV)   - Acc: {metrics_test_cv['accuracy']:.4f}, ROC-AUC: {metrics_test_cv['roc_auc']:.4f}, F1: {metrics_test_cv['f1']:.4f}")
            print(f"  Best epoch: {best_epoch_cv + 1}, Best threshold: {best_threshold_cv:.3f}")
    
    # Calculate summary statistics
    print(f"\n{'='*60}")
    print("CROSS-VALIDATION SUMMARY")
    print(f"{'='*60}")
    
    cv_summary = {
        'metric': [],
        'mean': [],
        'std': [],
        'min': [],
        'max': []
    }
    
    for metric in ['val_acc', 'val_roc_auc', 'val_f1', 'test_acc', 'test_roc_auc', 'test_f1']:
        values = np.array(cv_results[metric])
        cv_summary['metric'].append(metric)
        cv_summary['mean'].append(np.mean(values))
        cv_summary['std'].append(np.std(values))
        cv_summary['min'].append(np.min(values))
        cv_summary['max'].append(np.max(values))
    
    cv_summary_df = pd.DataFrame(cv_summary)
    print("\nValidation Set Metrics:")
    print(cv_summary_df[cv_summary_df['metric'].str.startswith('val_')].to_string(index=False))
    print("\nTest Set (CV) Metrics:")
    print(cv_summary_df[cv_summary_df['metric'].str.startswith('test_')].to_string(index=False))
    
    return {
        'results': cv_results,
        'summary': cv_summary_df,
        'models': fold_models,
        'histories': fold_histories
    }

print("✓ Cross-validation function defined")
# Out:
# ✓ Cross-validation function defined

# %%
# ============================================================
# Feature Importance Analysis
# ============================================================

def compute_feature_importance(model, X, y, feature_cols, n_iterations=10):
    """
    Compute feature importance using permutation importance.
    """
    print("=" * 60)
    print("COMPUTING FEATURE IMPORTANCE (Permutation Importance)")
    print("=" * 60)
    
    model.eval()
    baseline_probs = []
    baseline_labels = []
    
    # Get baseline predictions
    with torch.no_grad():
        X_tensor = torch.tensor(X.astype(np.float32), dtype=torch.float32).to(DEVICE)
        logits = model(X_tensor)
        probs = torch.sigmoid(logits).cpu().numpy().flatten()
        baseline_probs = probs
        baseline_labels = y
    
    baseline_auc = roc_auc_score(baseline_labels, baseline_probs)
    
    # Permute each feature and measure impact
    importance_scores = []
    
    for i, feat_name in enumerate(feature_cols):
        if i % 20 == 0:
            print(f"  Processing feature {i+1}/{len(feature_cols)}: {feat_name}")
        
        # Permute feature multiple times and average
        permuted_aucs = []
        for _ in range(n_iterations):
            X_permuted = X.copy()
            np.random.shuffle(X_permuted[:, i])
            
            with torch.no_grad():
                X_tensor = torch.tensor(X_permuted.astype(np.float32), dtype=torch.float32).to(DEVICE)
                logits = model(X_tensor)
                probs = torch.sigmoid(logits).cpu().numpy().flatten()
            
            permuted_auc = roc_auc_score(baseline_labels, probs)
            permuted_aucs.append(permuted_auc)
        
        # Importance = drop in performance
        importance = baseline_auc - np.mean(permuted_aucs)
        importance_scores.append({
            'feature': feat_name,
            'importance': importance,
            'baseline_auc': baseline_auc,
            'permuted_auc_mean': np.mean(permuted_aucs),
            'permuted_auc_std': np.std(permuted_aucs)
        })
    
    importance_df = pd.DataFrame(importance_scores)
    importance_df = importance_df.sort_values('importance', ascending=False)
    
    print(f"\n✓ Computed importance for {len(feature_cols)} features")
    print(f"  Baseline AUC: {baseline_auc:.4f}")
    print(f"\nTop 10 Most Important Features:")
    print(importance_df.head(10)[['feature', 'importance']].to_string(index=False))
    
    return importance_df

print("✓ Feature importance function defined")
# Out:
# ✓ Feature importance function defined

# %% [markdown]
# ### 8.2.1. Neural Network: Run 5-Fold Cross-Validation

# %%
# ============================================================
# Run 5-Fold Cross-Validation
# ============================================================

# Prepare data for CV (use full training+validation data, exclude test)
# Ensure we have the correct indices
X_cv_full = pd.concat([X_train, X_val], axis=0)
y_cv_full = pd.concat([y_train_raw, y_val_raw], axis=0)

# Get participant IDs - need to use the original merged_df indices
train_indices = X_train.index
val_indices = X_val.index
all_indices = train_indices.union(val_indices)

# Get participant IDs from merged_df using these indices
pid_cv_full = merged_df.loc[all_indices, 'participant_id'].astype(str).values

# Verify alignment
if len(X_cv_full) != len(y_cv_full) or len(X_cv_full) != len(pid_cv_full):
    print(f"⚠ Warning: Length mismatch - X: {len(X_cv_full)}, y: {len(y_cv_full)}, pid: {len(pid_cv_full)}")
    # Re-align by resetting indices
    X_cv_full = X_cv_full.reset_index(drop=True)
    y_cv_full = y_cv_full.reset_index(drop=True)
    # Re-extract participant IDs
    all_indices_aligned = list(train_indices) + list(val_indices)
    pid_cv_full = merged_df.loc[all_indices_aligned, 'participant_id'].astype(str).values

print(f"✓ CV data prepared:")
print(f"  X shape: {X_cv_full.shape}")
print(f"  y shape: {y_cv_full.shape if hasattr(y_cv_full, 'shape') else len(y_cv_full)}")
print(f"  pid shape: {pid_cv_full.shape}")
print(f"  Unique participants: {len(np.unique(pid_cv_full))}")

# Run cross-validation
cv_results_dict = participant_level_cross_validation(
    X_full=X_cv_full,
    y_full=y_cv_full,
    pid_full=pid_cv_full,
    n_splits=5,
    epochs=40,
    lr=6e-4,
    weight_decay=8e-3,
    use_data_augmentation=True,
    noise_std=0.01,
    label_smoothing=0.1,
    patience=6,
    verbose=True
)

# Save CV results
cv_results_df = pd.DataFrame(cv_results_dict['results'])
cv_results_df.to_csv(OUTPUT_DIR / 'cv_results.csv', index=False)
print(f"\n✓ Saved CV results to: {OUTPUT_DIR / 'cv_results.csv'}")

# Display summary
print("\n" + "=" * 60)
print("CROSS-VALIDATION SUMMARY STATISTICS")
print("=" * 60)
print("\nTest Set Performance (CV):")
test_metrics = ['test_acc', 'test_roc_auc', 'test_f1']
for metric in test_metrics:
    values = np.array(cv_results_dict['results'][metric])
    print(f"  {metric}: {np.mean(values):.4f} ± {np.std(values):.4f} (range: {np.min(values):.4f} - {np.max(values):.4f})")
# Out:
# ✓ CV data prepared:
#   X shape: (3903, 14)
#   y shape: (3903,)
#   pid shape: (3903,)
#   Unique participants: 100
# ============================================================
# PARTICIPANT-LEVEL 5-FOLD CROSS-VALIDATION
# ============================================================
# ✓ Found 100 unique participants
#   Label distribution: {0: 50, 1: 50}
#
# ============================================================
# FOLD 1/5
# ============================================================
# Train: 2457 samples (1146 Control, 1311 PD)
# Val (for early stopping): 663 samples (404 Control, 259 PD)
# Test (CV fold): 783 samples (375 Control, 408 PD)
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7126, val_loss=0.6906, train_acc=0.494, val_acc=0.563, val_roc_auc=0.5417
# Epoch  10/40: train_loss=0.6012, val_loss=0.6836, train_acc=0.714, val_acc=0.575, val_roc_auc=0.6427
#
# ⏹ Early stopping at epoch 19. Best epoch: 13 (AUC 0.6638)
#
# ✓ Loaded best model from epoch 13 (Val ROC-AUC: 0.6638)
#
# Fold 1 Results:
#   Validation - Acc: 0.4977, ROC-AUC: 0.6638, F1: 0.5924
#   Test (CV)   - Acc: 0.6169, ROC-AUC: 0.7434, F1: 0.7148
#   Best epoch: 13, Best threshold: 0.300
#
# ============================================================
# FOLD 2/5
# ============================================================
# Train: 2452 samples (1071 Control, 1381 PD)
# Val (for early stopping): 664 samples (405 Control, 259 PD)
# Test (CV fold): 787 samples (449 Control, 338 PD)
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7114, val_loss=0.6846, train_acc=0.499, val_acc=0.631, val_roc_auc=0.5567
# Epoch  10/40: train_loss=0.6005, val_loss=0.6702, train_acc=0.717, val_acc=0.590, val_roc_auc=0.6521
# Epoch  20/40: train_loss=0.5701, val_loss=0.7386, train_acc=0.765, val_acc=0.572, val_roc_auc=0.6439
#
# ⏹ Early stopping at epoch 29. Best epoch: 23 (AUC 0.6619)
#
# ✓ Loaded best model from epoch 23 (Val ROC-AUC: 0.6619)
#
# Fold 2 Results:
#   Validation - Acc: 0.5497, ROC-AUC: 0.6619, F1: 0.5932
#   Test (CV)   - Acc: 0.5642, ROC-AUC: 0.6834, F1: 0.6243
#   Best epoch: 23, Best threshold: 0.350
#
# ============================================================
# FOLD 3/5
# ============================================================
# Train: 2494 samples (1280 Control, 1214 PD)
# Val (for early stopping): 593 samples (275 Control, 318 PD)
# Test (CV fold): 816 samples (370 Control, 446 PD)
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7210, val_loss=0.6848, train_acc=0.503, val_acc=0.556, val_roc_auc=0.6505
# Epoch  10/40: train_loss=0.6117, val_loss=0.5889, train_acc=0.711, val_acc=0.646, val_roc_auc=0.7344
#
# ⏹ Early stopping at epoch 14. Best epoch: 8 (AUC 0.7556)
#
# ✓ Loaded best model from epoch 8 (Val ROC-AUC: 0.7556)
#
# Fold 3 Results:
#   Validation - Acc: 0.6408, ROC-AUC: 0.7556, F1: 0.7367
#   Test (CV)   - Acc: 0.5931, ROC-AUC: 0.6591, F1: 0.6943
#   Best epoch: 8, Best threshold: 0.300
#
# ============================================================
# FOLD 4/5
# ============================================================
# Train: 2512 samples (1182 Control, 1330 PD)
# Val (for early stopping): 619 samples (389 Control, 230 PD)
# Test (CV fold): 772 samples (354 Control, 418 PD)
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7064, val_loss=0.6982, train_acc=0.525, val_acc=0.375, val_roc_auc=0.6550
# Epoch  10/40: train_loss=0.6122, val_loss=0.6370, train_acc=0.701, val_acc=0.646, val_roc_auc=0.6972
#
# ⏹ Early stopping at epoch 19. Best epoch: 13 (AUC 0.7440)
#
# ✓ Loaded best model from epoch 13 (Val ROC-AUC: 0.7440)
#
# Fold 4 Results:
#   Validation - Acc: 0.6220, ROC-AUC: 0.7440, F1: 0.6034
#   Test (CV)   - Acc: 0.6503, ROC-AUC: 0.7015, F1: 0.6966
#   Best epoch: 13, Best threshold: 0.500
#
# ============================================================
# FOLD 5/5
# ============================================================
# Train: 2503 samples (1223 Control, 1280 PD)
# Val (for early stopping): 655 samples (325 Control, 330 PD)
# Test (CV fold): 745 samples (377 Control, 368 PD)
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7132, val_loss=0.6880, train_acc=0.505, val_acc=0.527, val_roc_auc=0.6556
# Epoch  10/40: train_loss=0.6169, val_loss=0.6499, train_acc=0.691, val_acc=0.646, val_roc_auc=0.6797
#
# ⏹ Early stopping at epoch 11. Best epoch: 5 (AUC 0.7123)
#
# ✓ Loaded best model from epoch 5 (Val ROC-AUC: 0.7123)
#
# Fold 5 Results:
#   Validation - Acc: 0.6092, ROC-AUC: 0.7123, F1: 0.6930
#   Test (CV)   - Acc: 0.6255, ROC-AUC: 0.7476, F1: 0.7029
#   Best epoch: 5, Best threshold: 0.400
#
# ============================================================
# CROSS-VALIDATION SUMMARY
# ============================================================
#
# Validation Set Metrics:
#      metric     mean      std      min      max
#     val_acc 0.583875 0.052763 0.497738 0.640809
# val_roc_auc 0.707528 0.039133 0.661919 0.755597
#      val_f1 0.643751 0.059820 0.592411 0.736712
#
# Test Set (CV) Metrics:
#       metric     mean      std      min      max
#     test_acc 0.609985 0.029302 0.564168 0.650259
# test_roc_auc 0.706999 0.034205 0.659102 0.747578
#      test_f1 0.686588 0.031940 0.624315 0.714829
#
# ✓ Saved CV results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/cv_results.csv
#
# ============================================================
# CROSS-VALIDATION SUMMARY STATISTICS
# ============================================================
#
# Test Set Performance (CV):
#   test_acc: 0.6100 ± 0.0293 (range: 0.5642 - 0.6503)
#   test_roc_auc: 0.7070 ± 0.0342 (range: 0.6591 - 0.7476)
#   test_f1: 0.6866 ± 0.0319 (range: 0.6243 - 0.7148)

# %% [markdown]
# ### 8.2.2. Neural Network: Feature Importance Analysis

# %%
# ============================================================
# Compute Feature Importance on Best Model
# ============================================================

# Use the baseline model trained on full training data
X_train_val_combined = np.vstack([X_train_np_real, X_val_np_real])
y_train_val_combined = np.concatenate([y_train_np_real, y_val_np_real])

# Compute feature importance
importance_df = compute_feature_importance(
    model_real_baseline,
    X_train_val_combined,
    y_train_val_combined,
    feature_cols,
    n_iterations=10
)

# Save feature importance
importance_df.to_csv(OUTPUT_DIR / 'feature_importance.csv', index=False)
print(f"\n✓ Saved feature importance to: {OUTPUT_DIR / 'feature_importance.csv'}")

# Plot top features
plt.figure(figsize=(12, 8))
top_n = 20
top_features = importance_df.head(top_n)
plt.barh(range(len(top_features)), top_features['importance'], color='steelblue')
plt.yticks(range(len(top_features)), top_features['feature'])
plt.xlabel('Importance (AUC Drop)', fontsize=12, fontweight='bold')
plt.title(f'Top {top_n} Most Important Features', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'feature_importance.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved feature importance plot to: {OUTPUT_DIR / 'feature_importance.png'}")
# Out:
# ============================================================
# COMPUTING FEATURE IMPORTANCE (Permutation Importance)
# ============================================================
#   Processing feature 1/14: cluster_1
#
# ✓ Computed importance for 14 features
#   Baseline AUC: 0.8519
#
# Top 10 Most Important Features:
#    feature  importance
# cluster_12    0.114954
#  cluster_4    0.095937
#  cluster_6    0.085494
# cluster_11    0.065712
#  cluster_9    0.055551
# cluster_14    0.053808
#  cluster_7    0.052487
# cluster_13    0.052186
# cluster_10    0.050015
#  cluster_2    0.030204
#
# ✓ Saved feature importance to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/feature_importance.csv
# ✓ Saved feature importance plot to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/feature_importance.png

# %%
# ============================================================
# Standardized CV Results Visualization Function
# ============================================================

def plot_cv_results_standardized(cv_results_df, model_name, save_path=None):
    """
    Create standardized cross-validation visualization with box plots and line plots.
    
    Parameters:
    -----------
    cv_results_df : pd.DataFrame
        DataFrame containing CV results with columns: fold, test_acc, test_roc_auc, test_f1
    model_name : str
        Name of the model for title
    save_path : Path, optional
        Path to save the figure
    """
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle(f'{model_name}: 5-Fold Cross-Validation Results', fontsize=16, fontweight='bold')
    
    folds = cv_results_df['fold'].values
    
    # Prepare data for box plots
    test_metrics = {
        'Accuracy': cv_results_df['test_acc'].values,
        'ROC-AUC': cv_results_df['test_roc_auc'].values,
        'F1 Score': cv_results_df['test_f1'].values
    }
    
    # 1. Box plot: Test metrics distribution
    ax1 = axes[0, 0]
    metrics_data = [test_metrics['Accuracy'], test_metrics['ROC-AUC'], test_metrics['F1 Score']]
    bp = ax1.boxplot(metrics_data, labels=['Accuracy', 'ROC-AUC', 'F1'], patch_artist=True)
    colors_box = ['steelblue', 'darkorange', 'forestgreen']
    for patch, color in zip(bp['boxes'], colors_box):
        patch.set_facecolor(color)
        patch.set_alpha(0.7)
    ax1.set_ylabel('Score', fontsize=12, fontweight='bold')
    ax1.set_title('Test Metrics Distribution Across Folds', fontsize=13, fontweight='bold')
    ax1.set_ylim([0, 1.05])
    ax1.grid(True, alpha=0.3, axis='y')
    
    # Add mean values as text
    for i, (metric_name, values) in enumerate(test_metrics.items(), 1):
        mean_val = np.mean(values)
        ax1.text(i, mean_val + 0.02, f'{mean_val:.3f}', ha='center', va='bottom', 
                fontsize=10, fontweight='bold')
    
    # 2. Line plot: Test Accuracy across folds
    ax2 = axes[0, 1]
    ax2.plot(folds, test_metrics['Accuracy'], 'o-', linewidth=2.5, markersize=10, 
             color='steelblue', label='Test Accuracy', markerfacecolor='white', markeredgewidth=2)
    ax2.axhline(y=np.mean(test_metrics['Accuracy']), color='r', linestyle='--', linewidth=2,
                label=f'Mean: {np.mean(test_metrics["Accuracy"]):.4f}')
    ax2.fill_between(folds, 
                     np.mean(test_metrics['Accuracy']) - np.std(test_metrics['Accuracy']),
                     np.mean(test_metrics['Accuracy']) + np.std(test_metrics['Accuracy']),
                     alpha=0.2, color='gray', label=f'±1 std: {np.std(test_metrics["Accuracy"]):.4f}')
    ax2.set_xlabel('Fold', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Accuracy', fontsize=12, fontweight='bold')
    ax2.set_title('Test Accuracy Across Folds', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    ax2.set_xticks(folds)
    ax2.set_ylim([0, 1.05])
    
    # 3. Line plot: Test ROC-AUC across folds
    ax3 = axes[1, 0]
    ax3.plot(folds, test_metrics['ROC-AUC'], 'o-', linewidth=2.5, markersize=10,
             color='darkorange', label='Test ROC-AUC', markerfacecolor='white', markeredgewidth=2)
    ax3.axhline(y=np.mean(test_metrics['ROC-AUC']), color='r', linestyle='--', linewidth=2,
                label=f'Mean: {np.mean(test_metrics["ROC-AUC"]):.4f}')
    ax3.fill_between(folds,
                     np.mean(test_metrics['ROC-AUC']) - np.std(test_metrics['ROC-AUC']),
                     np.mean(test_metrics['ROC-AUC']) + np.std(test_metrics['ROC-AUC']),
                     alpha=0.2, color='gray', label=f'±1 std: {np.std(test_metrics["ROC-AUC"]):.4f}')
    ax3.set_xlabel('Fold', fontsize=12, fontweight='bold')
    ax3.set_ylabel('ROC-AUC', fontsize=12, fontweight='bold')
    ax3.set_title('Test ROC-AUC Across Folds', fontsize=13, fontweight='bold')
    ax3.legend(fontsize=10)
    ax3.grid(True, alpha=0.3)
    ax3.set_xticks(folds)
    ax3.set_ylim([0, 1.05])
    
    # 4. Line plot: Test F1 Score across folds
    ax4 = axes[1, 1]
    ax4.plot(folds, test_metrics['F1 Score'], 'o-', linewidth=2.5, markersize=10,
             color='forestgreen', label='Test F1 Score', markerfacecolor='white', markeredgewidth=2)
    ax4.axhline(y=np.mean(test_metrics['F1 Score']), color='r', linestyle='--', linewidth=2,
                label=f'Mean: {np.mean(test_metrics["F1 Score"]):.4f}')
    ax4.fill_between(folds,
                     np.mean(test_metrics['F1 Score']) - np.std(test_metrics['F1 Score']),
                     np.mean(test_metrics['F1 Score']) + np.std(test_metrics['F1 Score']),
                     alpha=0.2, color='gray', label=f'±1 std: {np.std(test_metrics["F1 Score"]):.4f}')
    ax4.set_xlabel('Fold', fontsize=12, fontweight='bold')
    ax4.set_ylabel('F1 Score', fontsize=12, fontweight='bold')
    ax4.set_title('Test F1 Score Across Folds', fontsize=13, fontweight='bold')
    ax4.legend(fontsize=10)
    ax4.grid(True, alpha=0.3)
    ax4.set_xticks(folds)
    ax4.set_ylim([0, 1.05])
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"✓ Saved CV visualization to: {save_path}")
    
    plt.show()
    
    # Print summary statistics
    print(f"\n{model_name} - CV Summary Statistics:")
    print(f"  Test Accuracy: {np.mean(test_metrics['Accuracy']):.4f} ± {np.std(test_metrics['Accuracy']):.4f}")
    print(f"  Test ROC-AUC:  {np.mean(test_metrics['ROC-AUC']):.4f} ± {np.std(test_metrics['ROC-AUC']):.4f}")
    print(f"  Test F1 Score: {np.mean(test_metrics['F1 Score']):.4f} ± {np.std(test_metrics['F1 Score']):.4f}")

print("✓ Standardized CV visualization function defined")
# Out:
# ✓ Standardized CV visualization function defined

# %% [markdown]
# ### 8.3. Neural Network: CV Results Visualization

# %%
# ============================================================
# Neural Network: CV Results Visualization
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: CV RESULTS VISUALIZATION")
print("=" * 60)

if 'cv_results_dict' in globals() and 'results' in cv_results_dict:
    # Convert to DataFrame for standardized function
    cv_results_nn_df = pd.DataFrame(cv_results_dict['results'])
    
    plot_cv_results_standardized(
        cv_results_nn_df,
        model_name='Neural Network',
        save_path=OUTPUT_DIR / 'nn_cv_results_visualization.png'
    )
else:
    print("⚠ cv_results_dict not found. Run CV section first.")
print("=" * 60)
# Out:
# ============================================================
# NEURAL NETWORK: CV RESULTS VISUALIZATION
# ============================================================
# ✓ Saved CV visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/nn_cv_results_visualization.png
# Neural Network - CV Summary Statistics:
#   Test Accuracy: 0.6100 ± 0.0293
#   Test ROC-AUC:  0.7070 ± 0.0342
#   Test F1 Score: 0.6866 ± 0.0319
# ============================================================

# %% [markdown]
# ### 8.4. Neural Network: Final Training on Full Training Set

# %%
# ============================================================
# Neural Network: Final Training on Full Training Set
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: FINAL TRAINING ON FULL TRAINING SET")
print("=" * 60)

# Check that grid search has been run
if 'nn_best_params' not in globals() or nn_best_params is None:
    print("⚠ Grid search not run yet. Using default parameters.")
    nn_best_params = {
        'lr': 6e-4,
        'weight_decay': 8e-3,
        'noise_std': 0.01,
        'label_smoothing': 0.1,
        'gradient_clip': 0.5
    }
else:
    print(f"✓ Using grid search parameters: {nn_best_params}")

# Combine train and val for final training
X_train_full = np.vstack([X_train_np_real, X_val_np_real])
y_train_full = np.concatenate([y_train_np_real, y_val_np_real])

# Create final training data loader
train_full_dataset = TensorDataset(
    torch.tensor(X_train_full, dtype=torch.float32),
    torch.tensor(y_train_full.reshape(-1, 1), dtype=torch.float32)
)
train_full_loader = DataLoader(train_full_dataset, batch_size=128, shuffle=True)

# Keep validation loader for threshold tuning
val_loader_final = val_loader_real

# Create and train final model
print("\nTraining final model on full training set...")
model_final_nn = RegularizedHybridNet(input_dim).to(DEVICE)

model_final_nn, hist_final_nn, best_epoch_final_nn = train_model_with_checkpointing(
    model_final_nn,
    train_loader=train_full_loader,
    val_loader=val_loader_final,
    epochs=40,
    lr=nn_best_params['lr'],
    weight_decay=nn_best_params['weight_decay'],
    use_data_augmentation=True,
    noise_std=nn_best_params['noise_std'],
    label_smoothing=nn_best_params['label_smoothing'],
    gradient_clip=nn_best_params['gradient_clip'],
    patience=6
)

# Find best threshold on validation set
print("\n" + "=" * 60)
print("TUNING THRESHOLD ON VALIDATION SET")
print("=" * 60)
best_threshold_nn, best_val_f1_nn = find_best_threshold(model_final_nn, val_loader_final)
print(f"Best threshold on validation: {best_threshold_nn:.3f} (val F1={best_val_f1_nn:.4f})")

# Evaluate on test set
print("\n" + "=" * 60)
print("EVALUATING ON TEST DATA")
print("=" * 60)
metrics_final_nn = evaluate_on_real(model_final_nn, test_loader, threshold=best_threshold_nn)

print("\nPerformance on test data (final model trained on full training set):")
for k, v in metrics_final_nn.items():
    print(f"  {k}: {v:.4f}")
print(f"  (using threshold: {best_threshold_nn:.3f})")
print("=" * 60)

# Store for visualization
metrics_real_baseline = metrics_final_nn
# Out:
# ============================================================
# NEURAL NETWORK: FINAL TRAINING ON FULL TRAINING SET
# ============================================================
# ✓ Using grid search parameters: {'lr': 0.0006, 'weight_decay': 0.008, 'noise_std': 0.01, 'label_smoothing': 0.1, 'gradient_clip': 0.5}
#
# Training final model on full training set...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7119, val_loss=0.6749, train_acc=0.523, val_acc=0.637, val_roc_auc=0.6897
# Epoch  10/40: train_loss=0.6161, val_loss=0.5150, train_acc=0.704, val_acc=0.727, val_roc_auc=0.8343
# Epoch  20/40: train_loss=0.5862, val_loss=0.4758, train_acc=0.742, val_acc=0.772, val_roc_auc=0.8708
# Epoch  30/40: train_loss=0.5719, val_loss=0.4576, train_acc=0.755, val_acc=0.791, val_roc_auc=0.8891
# Epoch  40/40: train_loss=0.5620, val_loss=0.4432, train_acc=0.778, val_acc=0.798, val_roc_auc=0.8954
#
# ✓ Loaded best model from epoch 40 (Val ROC-AUC: 0.8954)
#
# ============================================================
# TUNING THRESHOLD ON VALIDATION SET
# ============================================================
# Best threshold on validation: 0.550 (val F1=0.8117)
#
# ============================================================
# EVALUATING ON TEST DATA
# ============================================================
#
# Performance on test data (final model trained on full training set):
#   accuracy: 0.7295
#   roc_auc: 0.7988
#   f1: 0.7067
#   precision: 0.7277
#   recall: 0.6868
#   (using threshold: 0.550)
# ============================================================

# %% [markdown]
# ### 8.5. Neural Network: Performance Visualizations

# %%
# ============================================================
# Neural Network: Performance Visualizations
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: PERFORMANCE VISUALIZATIONS")
print("=" * 60)

# Check that final model exists
if 'model_final_nn' not in globals():
    print("⚠ Final model not found. Please run final training section first.")
else:
    # Use final model for visualizations
    model_viz = model_final_nn
    hist_viz = hist_final_nn
    threshold_viz = best_threshold_nn

def plot_training_curves(history, title, save_path=None):
    """Plot training curves."""
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(title, fontsize=16, fontweight='bold')
    
    epochs = range(1, len(history['train_loss']) + 1)
    
    # Loss curves
    ax1 = axes[0]
    ax1.plot(epochs, history['train_loss'], label='Train Loss', linewidth=2, marker='o', markersize=3)
    ax1.plot(epochs, history['val_loss'], label='Validation Loss', linewidth=2, marker='s', markersize=3)
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.set_title('Loss Curves', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=11)
    ax1.grid(True, alpha=0.3)
    
    # Accuracy curves
    ax2 = axes[1]
    ax2.plot(epochs, history['train_acc'], label='Train Accuracy', linewidth=2, marker='o', markersize=3)
    ax2.plot(epochs, history['val_acc'], label='Validation Accuracy', linewidth=2, marker='s', markersize=3)
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.set_title('Accuracy Curves', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=11)
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()
    return avg_precision

def plot_roc_curve(model, loader, threshold=0.5, title="ROC Curve", save_path=None):
    """Plot ROC curve."""
    model.eval()
    all_probs = []
    all_labels = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            logits = model(xb)
            probs = torch.sigmoid(logits).cpu().numpy().flatten()
            all_probs.extend(probs)
            all_labels.extend(yb.numpy().flatten())
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels).astype(int)
    
    # Calculate ROC curve
    fpr, tpr, roc_thresholds = roc_curve(all_labels, all_probs)
    roc_auc = roc_auc_score(all_labels, all_probs)
    
    # Plot
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random (AUC = 0.5000)')
    
    # Mark the chosen threshold point
    preds_at_threshold = (all_probs >= threshold).astype(int)
    from sklearn.metrics import confusion_matrix
    tn, fp, fn, tp = confusion_matrix(all_labels, preds_at_threshold).ravel()
    tpr_at_threshold = tp / (tp + fn) if (tp + fn) > 0 else 0
    fpr_at_threshold = fp / (fp + tn) if (fp + tn) > 0 else 0
    plt.plot(fpr_at_threshold, tpr_at_threshold, 'ro', markersize=10, 
             label=f'Threshold {threshold:.3f}')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.legend(loc="lower right", fontsize=11)
    plt.grid(True, alpha=0.3)
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()
    
    return roc_auc

def plot_precision_recall_curve(model, loader, threshold=0.5, title="Precision-Recall Curve", save_path=None):
    """Plot Precision-Recall curve."""
    model.eval()
    all_probs = []
    all_labels = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            logits = model(xb)
            probs = torch.sigmoid(logits).cpu().numpy().flatten()
            all_probs.extend(probs)
            all_labels.extend(yb.numpy().flatten())
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels).astype(int)
    
    # Calculate Precision-Recall curve
    precision, recall, pr_thresholds = precision_recall_curve(all_labels, all_probs)
    avg_precision = average_precision_score(all_labels, all_probs)
    
    # Plot
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, color='darkblue', lw=2, 
             label=f'PR curve (AP = {avg_precision:.4f})')
    
    # Mark the chosen threshold point
    preds_at_threshold = (all_probs >= threshold).astype(int)
    from sklearn.metrics import precision_score, recall_score
    prec_at_threshold = precision_score(all_labels, preds_at_threshold)
    rec_at_threshold = recall_score(all_labels, preds_at_threshold)
    plt.plot(rec_at_threshold, prec_at_threshold, 'ro', markersize=10,
             label=f'Threshold {threshold:.3f}')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall', fontsize=12)
    plt.ylabel('Precision', fontsize=12)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.legend(loc="lower left", fontsize=11)
    plt.grid(True, alpha=0.3)
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()
    
    return avg_precision

def plot_confusion_matrix(model, loader, threshold=0.5, title="Confusion Matrix", save_path=None):
    """Plot confusion matrix."""
    model.eval()
    all_probs = []
    all_labels = []
    
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            logits = model(xb)
            probs = torch.sigmoid(logits).cpu().numpy().flatten()
            all_probs.extend(probs)
            all_labels.extend(yb.numpy().flatten())
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels).astype(int)
    preds = (all_probs >= threshold).astype(int)
    
    # Calculate confusion matrix
    cm = confusion_matrix(all_labels, preds)
    
    # Plot
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
                xticklabels=['Control', 'Parkinson\'s'],
                yticklabels=['Control', 'Parkinson\'s'],
                square=True, linewidths=2, linecolor='gray')
    plt.ylabel('True Label', fontsize=12, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    
    # Add text annotations
    tn, fp, fn, tp = cm.ravel()
    accuracy = (tn + tp) / (tn + fp + fn + tp)
    plt.text(0.5, -0.15, f'Accuracy: {accuracy:.4f}', 
             ha='center', transform=plt.gca().transAxes, fontsize=11)
    plt.text(0.5, -0.20, f'Threshold: {threshold:.3f}', 
             ha='center', transform=plt.gca().transAxes, fontsize=11)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    
    plt.show()
    
    return cm

    print("\n" + "=" * 60)
    print("VISUALIZING TRAINING CURVES")
    print("=" * 60)
    
    plot_training_curves(
        hist_viz,
        "Neural Network: Final Model Training Curves",
        save_path=OUTPUT_DIR / 'nn_final_training_curves.png'
    )
    print(f"✓ Saved training curves to: {OUTPUT_DIR / 'nn_final_training_curves.png'}")
    
    print("\n" + "=" * 60)
    print("VISUALIZING ROC CURVE")
    print("=" * 60)
    
    roc_auc = plot_roc_curve(
        model_viz,
        test_loader,
        threshold=threshold_viz,
        title="ROC Curve - Neural Network Classification",
        save_path=OUTPUT_DIR / 'nn_final_roc_curve.png'
    )
    print(f"✓ ROC-AUC: {roc_auc:.4f}")
    print(f"✓ Saved ROC curve to: {OUTPUT_DIR / 'nn_final_roc_curve.png'}")
    
    print("\n" + "=" * 60)
    print("VISUALIZING PRECISION-RECALL CURVE")
    print("=" * 60)
    
    avg_precision = plot_precision_recall_curve(
        model_viz,
        test_loader,
        threshold=threshold_viz,
        title="Precision-Recall Curve - Neural Network Classification",
        save_path=OUTPUT_DIR / 'nn_final_pr_curve.png'
    )
    print(f"✓ Average Precision: {avg_precision:.4f}")
    print(f"✓ Saved PR curve to: {OUTPUT_DIR / 'nn_final_pr_curve.png'}")
    
    print("\n" + "=" * 60)
    print("VISUALIZING CONFUSION MATRIX")
    print("=" * 60)
    
    cm = plot_confusion_matrix(
        model_viz,
        test_loader,
        threshold=threshold_viz,
        title="Confusion Matrix - Neural Network Classification",
        save_path=OUTPUT_DIR / 'nn_final_confusion_matrix.png'
    )
    print(f"✓ Confusion Matrix:")
    print(f"  True Negatives (TN): {cm[0, 0]}")
    print(f"  False Positives (FP): {cm[0, 1]}")
    print(f"  False Negatives (FN): {cm[1, 0]}")
    print(f"  True Positives (TP): {cm[1, 1]}")
    print(f"✓ Saved confusion matrix to: {OUTPUT_DIR / 'nn_final_confusion_matrix.png'}")
    
    print("=" * 60)
# Out:
# ============================================================
# NEURAL NETWORK: PERFORMANCE VISUALIZATIONS
# ============================================================

# %% [markdown]
# ## 9. Random Forest Classifier

# %% [markdown]
# ### 9.1. Random Forest: Hyperparameter Grid Search

# %%
# ============================================================
# Random Forest: Default Parameters
# ============================================================

print("=" * 60)
print("RANDOM FOREST: DEFAULT PARAMETERS")
print("=" * 60)

# Set default parameters for Random Forest
rf_best_params = {
    'n_estimators': 150,
    'max_depth': 10,
    'min_samples_split': 20,
    'min_samples_leaf': 10,
    'max_features': 'sqrt',
    'random_state': SEED,
    'n_jobs': -1,
    'class_weight': 'balanced'
}

print(f"\nUsing default parameters: {rf_best_params}")
print(f"\n✓ Parameters stored in 'rf_best_params' for use in 5-fold CV and final training")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: DEFAULT PARAMETERS
# ============================================================
#
# Using default parameters: {'n_estimators': 150, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'random_state': 42, 'n_jobs': -1, 'class_weight': 'balanced'}
#
# ✓ Parameters stored in 'rf_best_params' for use in 5-fold CV and final training
# ============================================================

# %%
# ============================================================
# Random Forest Classifier Setup
# ============================================================

from sklearn.ensemble import RandomForestClassifier

print("=" * 60)
print("RANDOM FOREST CLASSIFIER")
print("=" * 60)

# Prepare data for Random Forest (use same train/val/test splits)
X_train_rf = X_train.values.astype(np.float32)
X_val_rf = X_val.values.astype(np.float32)
X_test_rf = X_test.values.astype(np.float32)

y_train_rf = y_train_raw.values.astype(int)
y_val_rf = y_val_raw.values.astype(int)
y_test_rf = y_test_raw.values.astype(int)

print(f"Training samples: {len(X_train_rf)} ({np.sum(y_train_rf == 0)} Control, {np.sum(y_train_rf == 1)} PD)")
print(f"Validation samples: {len(X_val_rf)} ({np.sum(y_val_rf == 0)} Control, {np.sum(y_val_rf == 1)} PD)")
print(f"Test samples: {len(X_test_rf)} ({np.sum(y_test_rf == 0)} Control, {np.sum(y_test_rf == 1)} PD)")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST CLASSIFIER
# ============================================================
# Training samples: 3071 (1514 Control, 1557 PD)
# Validation samples: 832 (411 Control, 421 PD)
# Test samples: 976 (513 Control, 463 PD)
# ============================================================

# %% [markdown]
# ### 9.1. Random Forest: 5-Fold Cross-Validation

# %%
# ============================================================
# Random Forest: 5-Fold Cross-Validation
# ============================================================

print("=" * 60)
print("RANDOM FOREST: 5-FOLD CROSS-VALIDATION")
print("=" * 60)

# rf_best_params should be set by grid search in section 9.0
# If grid search hasn't been run, use default parameters as fallback
if 'rf_best_params' not in globals() or rf_best_params is None:
    print("⚠ Grid search not run yet. Using default parameters.")
    rf_best_params = {
        'n_estimators': 150,
        'max_depth': 10,
        'min_samples_split': 20,
        'min_samples_leaf': 10,
        'max_features': 'sqrt',
    }
    rf_best_params['random_state'] = SEED
    rf_best_params['n_jobs'] = -1
    rf_best_params['class_weight'] = 'balanced'
else:
    # Add fixed parameters that aren't in grid search
    if 'random_state' not in rf_best_params:
        rf_best_params['random_state'] = SEED
    if 'n_jobs' not in rf_best_params:
        rf_best_params['n_jobs'] = -1
    if 'class_weight' not in rf_best_params:
        rf_best_params['class_weight'] = 'balanced'
    print(f"✓ Using grid search parameters: {rf_best_params}")

# Prepare data for CV (combine train and val)
X_cv_rf = np.vstack([X_train_rf, X_val_rf])
y_cv_rf = np.concatenate([y_train_rf, y_val_rf])

# Get participant IDs for CV
try:
    pid_train_array = np.array(pid_train) if isinstance(pid_train, (list, pd.Series)) else pid_train
    pid_val_array = np.array(pid_val) if isinstance(pid_val, (list, pd.Series)) else pid_val
    pid_cv_rf = np.concatenate([pid_train_array, pid_val_array])
    
    unique_pids = len(np.unique(pid_cv_rf))
    use_group_kfold = unique_pids >= 5
    
    if use_group_kfold:
        print(f"✓ Found {unique_pids} unique participants")
        print("✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)")
    else:
        print(f"⚠ Only {unique_pids} unique participants")
        print("⚠ Falling back to StratifiedKFold (sample-level CV - RISK OF DATA LEAKAGE)")
        pid_cv_rf = None
except Exception as e:
    print(f"⚠ Error extracting participant IDs: {e}")
    use_group_kfold = False
    pid_cv_rf = None

# Setup CV
try:
    from sklearn.model_selection import StratifiedGroupKFold
    if use_group_kfold and pid_cv_rf is not None:
        skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    else:
        from sklearn.model_selection import StratifiedKFold
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
        pid_cv_rf = None
except ImportError:
    from sklearn.model_selection import StratifiedKFold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    pid_cv_rf = None
    use_group_kfold = False

# Helper function for threshold tuning
def find_best_threshold_rf_cv(model, X, y):
    """Find optimal threshold for Random Forest based on F1-score."""
    probs = model.predict_proba(X)[:, 1]
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# Perform cross-validation
cv_results_rf = {
    'fold': [],
    'train_acc': [],
    'val_acc': [],
    'test_acc': [],
    'train_roc_auc': [],
    'val_roc_auc': [],
    'test_roc_auc': [],
    'train_f1': [],
    'val_f1': [],
    'test_f1': [],
    'best_threshold': []
}

print("\nStarting 5-fold cross-validation...")
if use_group_kfold and pid_cv_rf is not None:
    splits = skf.split(X_cv_rf, y_cv_rf, pid_cv_rf)
else:
    splits = skf.split(X_cv_rf, y_cv_rf)

for fold, (train_idx, test_idx) in enumerate(splits, 1):
    print(f"\n{'=' * 60}")
    print(f"FOLD {fold}/5")
    print(f"{'=' * 60}")
    
    # Split data
    X_train_cv = X_cv_rf[train_idx]
    X_test_cv = X_cv_rf[test_idx]
    y_train_cv = y_cv_rf[train_idx]
    y_test_cv = y_cv_rf[test_idx]
    
    # Further split train into train/val for threshold tuning
    from sklearn.model_selection import train_test_split
    
    if use_group_kfold and pid_cv_rf is not None:
        train_pids = pid_cv_rf[train_idx]
        unique_train_pids = np.unique(train_pids)
        pid_to_label = {}
        for pid, label in zip(train_pids, y_train_cv):
            if pid not in pid_to_label:
                pid_to_label[pid] = label
        participant_labels_fold = np.array([pid_to_label[pid] for pid in unique_train_pids])
        
        pids_train_fold, pids_val_fold, y_p_train_fold, y_p_val_fold = train_test_split(
            unique_train_pids, participant_labels_fold,
            test_size=0.2, random_state=SEED + fold, stratify=participant_labels_fold
        )
        
        train_fold_mask = np.isin(train_pids, pids_train_fold)
        val_fold_mask = np.isin(train_pids, pids_val_fold)
        
        X_train_fold = X_train_cv[train_fold_mask]
        X_val_fold = X_train_cv[val_fold_mask]
        y_train_fold = y_train_cv[train_fold_mask]
        y_val_fold = y_train_cv[val_fold_mask]
    else:
        X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(
            X_train_cv, y_train_cv, test_size=0.2, random_state=SEED + fold, stratify=y_train_cv
        )
    
    print(f"Train: {X_train_fold.shape[0]} samples ({np.sum(y_train_fold == 0)} Control, {np.sum(y_train_fold == 1)} PD)")
    print(f"Val: {X_val_fold.shape[0]} samples ({np.sum(y_val_fold == 0)} Control, {np.sum(y_val_fold == 1)} PD)")
    print(f"Test: {X_test_cv.shape[0]} samples ({np.sum(y_test_cv == 0)} Control, {np.sum(y_test_cv == 1)} PD)")
    
    # Train model
    rf_model = RandomForestClassifier(**rf_best_params)
    rf_model.fit(X_train_fold, y_train_fold)
    
    # Evaluate on train, val, and test
    for split_name, X_split, y_split in [('train', X_train_fold, y_train_fold),
                                          ('val', X_val_fold, y_val_fold),
                                          ('test', X_test_cv, y_test_cv)]:
        y_pred = rf_model.predict(X_split)
        y_proba = rf_model.predict_proba(X_split)[:, 1]
        
        acc = accuracy_score(y_split, y_pred)
        auc = roc_auc_score(y_split, y_proba)
        f1 = f1_score(y_split, y_pred)
        
        cv_results_rf[f'{split_name}_acc'].append(acc)
        cv_results_rf[f'{split_name}_roc_auc'].append(auc)
        cv_results_rf[f'{split_name}_f1'].append(f1)
    
    # Find best threshold on validation set
    best_thresh, best_val_f1 = find_best_threshold_rf_cv(rf_model, X_val_fold, y_val_fold)
    cv_results_rf['best_threshold'].append(best_thresh)
    
    print(f"\nFold {fold} Results:")
    print(f"  Train - Acc: {cv_results_rf['train_acc'][-1]:.4f}, ROC-AUC: {cv_results_rf['train_roc_auc'][-1]:.4f}, F1: {cv_results_rf['train_f1'][-1]:.4f}")
    print(f"  Val   - Acc: {cv_results_rf['val_acc'][-1]:.4f}, ROC-AUC: {cv_results_rf['val_roc_auc'][-1]:.4f}, F1: {cv_results_rf['val_f1'][-1]:.4f}")
    print(f"  Test  - Acc: {cv_results_rf['test_acc'][-1]:.4f}, ROC-AUC: {cv_results_rf['test_roc_auc'][-1]:.4f}, F1: {cv_results_rf['test_f1'][-1]:.4f}")
    print(f"  Best Threshold: {best_thresh:.3f} (Val F1={best_val_f1:.4f})")
    
    cv_results_rf['fold'].append(fold)

# Summary
print("\n" + "=" * 60)
print("CROSS-VALIDATION SUMMARY")
print("=" * 60)
print(f"Test Accuracy: {np.mean(cv_results_rf['test_acc']):.4f} ± {np.std(cv_results_rf['test_acc']):.4f}")
print(f"Test ROC-AUC: {np.mean(cv_results_rf['test_roc_auc']):.4f} ± {np.std(cv_results_rf['test_roc_auc']):.4f}")
print(f"Test F1: {np.mean(cv_results_rf['test_f1']):.4f} ± {np.std(cv_results_rf['test_f1']):.4f}")

# Save CV results
cv_results_rf_df = pd.DataFrame(cv_results_rf)
cv_results_rf_df.to_csv(OUTPUT_DIR / 'rf_cv_results.csv', index=False)
print(f"\n✓ Saved CV results to: {OUTPUT_DIR / 'rf_cv_results.csv'}")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: 5-FOLD CROSS-VALIDATION
# ============================================================
# ✓ Using grid search parameters: {'n_estimators': 150, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'random_state': 42, 'n_jobs': -1, 'class_weight': 'balanced'}
# ✓ Found 100 unique participants
# ✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)
#
# Starting 5-fold cross-validation...
#
# ============================================================
# FOLD 1/5
# ============================================================
# Train: 2522 samples (1288 Control, 1234 PD)
# Val: 640 samples (310 Control, 330 PD)
# Test: 741 samples (327 Control, 414 PD)
#
# Fold 1 Results:
#   Train - Acc: 0.8997, ROC-AUC: 0.9700, F1: 0.8959
#   Val   - Acc: 0.6750, ROC-AUC: 0.7312, F1: 0.6677
#   Test  - Acc: 0.5870, ROC-AUC: 0.6538, F1: 0.5995
#   Best Threshold: 0.400 (Val F1=0.7116)
#
# ============================================================
# FOLD 2/5
# ============================================================
# Train: 2424 samples (1187 Control, 1237 PD)
# Val: 620 samples (303 Control, 317 PD)
# Test: 859 samples (435 Control, 424 PD)
#
# Fold 2 Results:
#   Train - Acc: 0.8919, ROC-AUC: 0.9632, F1: 0.8932
#   Val   - Acc: 0.6452, ROC-AUC: 0.7027, F1: 0.6584
#   Test  - Acc: 0.6717, ROC-AUC: 0.7433, F1: 0.6894
#   Best Threshold: 0.400 (Val F1=0.7110)
#
# ============================================================
# FOLD 3/5
# ============================================================
# Train: 2572 samples (1333 Control, 1239 PD)
# Val: 604 samples (274 Control, 330 PD)
# Test: 727 samples (318 Control, 409 PD)
#
# Fold 3 Results:
#   Train - Acc: 0.9063, ROC-AUC: 0.9709, F1: 0.9017
#   Val   - Acc: 0.6358, ROC-AUC: 0.6697, F1: 0.6358
#   Test  - Acc: 0.6424, ROC-AUC: 0.7183, F1: 0.6243
#   Best Threshold: 0.150 (Val F1=0.7068)
#
# ============================================================
# FOLD 4/5
# ============================================================
# Train: 2537 samples (1217 Control, 1320 PD)
# Val: 621 samples (279 Control, 342 PD)
# Test: 745 samples (429 Control, 316 PD)
#
# Fold 4 Results:
#   Train - Acc: 0.9101, ROC-AUC: 0.9709, F1: 0.9142
#   Val   - Acc: 0.7359, ROC-AUC: 0.7915, F1: 0.7772
#   Test  - Acc: 0.5745, ROC-AUC: 0.6078, F1: 0.5276
#   Best Threshold: 0.500 (Val F1=0.7772)
#
# ============================================================
# FOLD 5/5
# ============================================================
# Train: 2439 samples (1220 Control, 1219 PD)
# Val: 633 samples (289 Control, 344 PD)
# Test: 831 samples (416 Control, 415 PD)
#
# Fold 5 Results:
#   Train - Acc: 0.8963, ROC-AUC: 0.9660, F1: 0.8934
#   Val   - Acc: 0.6872, ROC-AUC: 0.7701, F1: 0.6827
#   Test  - Acc: 0.5981, ROC-AUC: 0.6699, F1: 0.5835
#   Best Threshold: 0.350 (Val F1=0.7529)
#
# ============================================================
# CROSS-VALIDATION SUMMARY
# ============================================================
# Test Accuracy: 0.6147 ± 0.0365
# Test ROC-AUC: 0.6786 ± 0.0479
# Test F1: 0.6049 ± 0.0529
#
# ✓ Saved CV results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_cv_results.csv
# ============================================================

# %% [markdown]
# ### 9.2. Random Forest: CV Results Visualization

# %%
# ============================================================
# Random Forest: CV Results Visualization
# ============================================================

print("=" * 60)
print("RANDOM FOREST: CV RESULTS VISUALIZATION")
print("=" * 60)

if 'cv_results_rf_df' in globals():
    plot_cv_results_standardized(
        cv_results_rf_df,
        model_name='Random Forest',
        save_path=OUTPUT_DIR / 'rf_cv_results_visualization.png'
    )
else:
    print(f"⚠ cv_results_rf_df not found. Run CV section first.")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: CV RESULTS VISUALIZATION
# ============================================================
# ✓ Saved CV visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_cv_results_visualization.png
# Random Forest - CV Summary Statistics:
#   Test Accuracy: 0.6147 ± 0.0365
#   Test ROC-AUC:  0.6786 ± 0.0479
#   Test F1 Score: 0.6049 ± 0.0529
# ============================================================

# %% [markdown]
# ### 9.3. Random Forest: Train and Evaluate

# %%
# ============================================================
# Random Forest: Train on Full Training Data and Evaluate
# ============================================================

print("=" * 60)
print("RANDOM FOREST: TRAINING AND EVALUATION")
print("=" * 60)

# Helper function for threshold tuning (Random Forest version)
def find_best_threshold_rf(model, X, y):
    """Find optimal threshold for Random Forest based on F1-score."""
    probs = model.predict_proba(X)[:, 1]
    
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# Train on full training data (train + val combined)
X_train_val_rf = np.vstack([X_train_rf, X_val_rf])
y_train_val_rf = np.concatenate([y_train_rf, y_val_rf])

print("\nTraining Random Forest on full training data...")
rf_final = RandomForestClassifier(**rf_best_params)

rf_final.fit(X_train_val_rf, y_train_val_rf)

# Get predictions and probabilities
y_train_pred_rf = rf_final.predict(X_train_val_rf)
y_train_proba_rf = rf_final.predict_proba(X_train_val_rf)[:, 1]

y_test_pred_rf = rf_final.predict(X_test_rf)
y_test_proba_rf = rf_final.predict_proba(X_test_rf)[:, 1]

# Find best threshold on validation data
print("\n" + "=" * 60)
print("TUNING THRESHOLD ON VALIDATION DATA")
print("=" * 60)

best_threshold_rf, best_val_f1_rf = find_best_threshold_rf(
    rf_final, X_val_rf, y_val_rf
)
print(f"Best threshold: {best_threshold_rf:.3f} (val F1={best_val_f1_rf:.4f})")

# Evaluate on test data with optimal threshold
y_test_pred_rf_thresh = (y_test_proba_rf >= best_threshold_rf).astype(int)

metrics_rf = {
    'accuracy': accuracy_score(y_test_rf, y_test_pred_rf_thresh),
    'roc_auc': roc_auc_score(y_test_rf, y_test_proba_rf),
    'f1': f1_score(y_test_rf, y_test_pred_rf_thresh),
    'precision': precision_score(y_test_rf, y_test_pred_rf_thresh),
    'recall': recall_score(y_test_rf, y_test_pred_rf_thresh)
}

print("\n" + "=" * 60)
print("RANDOM FOREST PERFORMANCE ON TEST DATA")
print("=" * 60)
for k, v in metrics_rf.items():
    print(f"  {k}: {v:.4f}")
print(f"  (using threshold: {best_threshold_rf:.3f})")
print("=" * 60)

# Helper function for threshold tuning (Random Forest version)
def find_best_threshold_rf(model, X, y):
    """Find optimal threshold for Random Forest based on F1-score."""
    probs = model.predict_proba(X)[:, 1]
    
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1
# Out:
# ============================================================
# RANDOM FOREST: TRAINING AND EVALUATION
# ============================================================
#
# Training Random Forest on full training data...
#
# ============================================================
# TUNING THRESHOLD ON VALIDATION DATA
# ============================================================
# Best threshold: 0.500 (val F1=0.8993)
#
# ============================================================
# RANDOM FOREST PERFORMANCE ON TEST DATA
# ============================================================
#   accuracy: 0.7234
#   roc_auc: 0.8009
#   f1: 0.7052
#   precision: 0.7130
#   recall: 0.6976
#   (using threshold: 0.500)
# ============================================================

# %% [markdown]
# ### 9.4. Random Forest: Feature Importance

# %%
# ============================================================
# Random Forest: Feature Importance Analysis
# ============================================================

print("=" * 60)
print("RANDOM FOREST: FEATURE IMPORTANCE")
print("=" * 60)

# Get feature importance from Random Forest
rf_importance = rf_final.feature_importances_

# Create DataFrame
rf_importance_df = pd.DataFrame({
    'feature': feature_cols,
    'importance': rf_importance
}).sort_values('importance', ascending=False)

print(f"\n✓ Computed feature importance for {len(feature_cols)} features")
print(f"\nTop 20 Most Important Features (Random Forest):")
print(rf_importance_df.head(20)[['feature', 'importance']].to_string(index=False))

# Save feature importance
rf_importance_df.to_csv(OUTPUT_DIR / 'rf_feature_importance.csv', index=False)
print(f"\n✓ Saved RF feature importance to: {OUTPUT_DIR / 'rf_feature_importance.csv'}")

# Plot feature importance
plt.figure(figsize=(12, 8))
top_n = 20
top_features_rf = rf_importance_df.head(top_n)
plt.barh(range(len(top_features_rf)), top_features_rf['importance'], color='forestgreen')
plt.yticks(range(len(top_features_rf)), top_features_rf['feature'])
plt.xlabel('Importance', fontsize=12, fontweight='bold')
plt.title(f'Top {top_n} Most Important Features (Random Forest)', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'rf_feature_importance.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved RF feature importance plot to: {OUTPUT_DIR / 'rf_feature_importance.png'}")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: FEATURE IMPORTANCE
# ============================================================
#
# ✓ Computed feature importance for 14 features
#
# Top 20 Most Important Features (Random Forest):
#    feature  importance
#  cluster_4    0.134874
# cluster_12    0.118034
# cluster_11    0.090474
#  cluster_9    0.075179
#  cluster_6    0.069162
# cluster_14    0.065107
# cluster_13    0.064100
#  cluster_2    0.061644
#  cluster_5    0.057576
#  cluster_1    0.054540
#  cluster_7    0.054336
# cluster_10    0.053598
#  cluster_8    0.051748
#  cluster_3    0.049627
#
# ✓ Saved RF feature importance to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_feature_importance.csv
# ✓ Saved RF feature importance plot to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_feature_importance.png
# ============================================================

# %% [markdown]
# ### 9.5. Random Forest: Performance Visualizations

# %%
# ============================================================
# Random Forest: Performance Visualizations
# ============================================================

print("=" * 60)
print("RANDOM FOREST: PERFORMANCE VISUALIZATIONS")
print("=" * 60)

# Get predictions and probabilities
y_test_proba_rf_viz = rf_final.predict_proba(X_test_rf)[:, 1]
y_test_pred_rf_viz = (y_test_proba_rf_viz >= best_threshold_rf).astype(int)

# ROC Curve
print("\n" + "=" * 60)
print("VISUALIZING ROC CURVE")
print("=" * 60)

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
fpr_rf, tpr_rf, _ = roc_curve(y_test_rf, y_test_proba_rf_viz)
roc_auc_rf = roc_auc_score(y_test_rf, y_test_proba_rf_viz)

plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc_rf:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random (AUC = 0.5000)')

# Mark threshold point
tn, fp, fn, tp = confusion_matrix(y_test_rf, y_test_pred_rf_viz).ravel()
tpr_at_threshold = tp / (tp + fn) if (tp + fn) > 0 else 0
fpr_at_threshold = fp / (fp + tn) if (fp + tn) > 0 else 0
plt.plot(fpr_at_threshold, tpr_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_rf:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - Random Forest Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'rf_roc_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ ROC-AUC: {roc_auc_rf:.4f}")
print(f"✓ Saved ROC curve to: {OUTPUT_DIR / 'rf_roc_curve.png'}")

# Precision-Recall Curve
print("\n" + "=" * 60)
print("VISUALIZING PRECISION-RECALL CURVE")
print("=" * 60)

from sklearn.metrics import precision_recall_curve, average_precision_score, precision_score, recall_score
precision_rf, recall_rf, _ = precision_recall_curve(y_test_rf, y_test_proba_rf_viz)
avg_precision_rf = average_precision_score(y_test_rf, y_test_proba_rf_viz)

plt.figure(figsize=(8, 6))
plt.plot(recall_rf, precision_rf, color='darkblue', lw=2, label=f'PR curve (AP = {avg_precision_rf:.4f})')

# Mark threshold point
prec_at_threshold = precision_score(y_test_rf, y_test_pred_rf_viz)
rec_at_threshold = recall_score(y_test_rf, y_test_pred_rf_viz)
plt.plot(rec_at_threshold, prec_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_rf:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.title('Precision-Recall Curve - Random Forest Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower left", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'rf_pr_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Average Precision: {avg_precision_rf:.4f}")
print(f"✓ Saved PR curve to: {OUTPUT_DIR / 'rf_pr_curve.png'}")

# Confusion Matrix
print("\n" + "=" * 60)
print("VISUALIZING CONFUSION MATRIX")
print("=" * 60)

cm_rf = confusion_matrix(y_test_rf, y_test_pred_rf_viz)
tn, fp, fn, tp = cm_rf.ravel()
accuracy_rf = (tn + tp) / (tn + fp + fn + tp)

plt.figure(figsize=(8, 6))
import seaborn as sns
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=['Control', "Parkinson's"],
            yticklabels=['Control', "Parkinson's"],
            square=True, linewidths=2, linecolor='gray')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.title('Confusion Matrix - Random Forest Classification', fontsize=14, fontweight='bold')
plt.text(0.5, -0.15, f'Accuracy: {accuracy_rf:.4f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.text(0.5, -0.20, f'Threshold: {best_threshold_rf:.3f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'rf_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Confusion Matrix:")
print(f"  True Negatives (TN): {tn}")
print(f"  False Positives (FP): {fp}")
print(f"  False Negatives (FN): {fn}")
print(f"  True Positives (TP): {tp}")
print(f"✓ Saved confusion matrix to: {OUTPUT_DIR / 'rf_confusion_matrix.png'}")

print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: PERFORMANCE VISUALIZATIONS
# ============================================================
#
# ============================================================
# VISUALIZING ROC CURVE
# ============================================================
# ✓ ROC-AUC: 0.8009
# ✓ Saved ROC curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_roc_curve.png
#
# ============================================================
# VISUALIZING PRECISION-RECALL CURVE
# ============================================================
# ✓ Average Precision: 0.7871
# ✓ Saved PR curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_pr_curve.png
#
# ============================================================
# VISUALIZING CONFUSION MATRIX
# ============================================================
# ✓ Confusion Matrix:
#   True Negatives (TN): 383
#   False Positives (FP): 130
#   False Negatives (FN): 140
#   True Positives (TP): 323
# ✓ Saved confusion matrix to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_confusion_matrix.png
# ============================================================

# %% [markdown]
# ## 10. XGBoost Classifier

# %% [markdown]
# ### 10.1. XGBoost: Data Setup

# %%
# ============================================================
# XGBoost Classifier Setup
# ============================================================

print("=" * 60)
print("XGBOOST CLASSIFIER SETUP")
print("=" * 60)

try:
    import xgboost as xgb
    XGBOOST_AVAILABLE = True
    print("✓ XGBoost available")
except ImportError:
    XGBOOST_AVAILABLE = False
    print("⚠ XGBoost not available. Install with: pip install xgboost")
    raise ImportError("XGBoost is required. Please install with: pip install xgboost")

# Prepare data for XGBoost (use same train/val/test splits)
X_train_xgb = X_train.values.astype(np.float32)
X_val_xgb = X_val.values.astype(np.float32)
X_test_xgb = X_test.values.astype(np.float32)

y_train_xgb = y_train_rf.copy()
y_val_xgb = y_val_rf.copy()
y_test_xgb = y_test_rf.copy()

print(f"\n✓ Data prepared for XGBoost:")
print(f"  Training: {X_train_xgb.shape}, {y_train_xgb.shape}")
print(f"  Validation: {X_val_xgb.shape}, {y_val_xgb.shape}")
print(f"  Test: {X_test_xgb.shape}, {y_test_xgb.shape}")

# Combine train and val for hyperparameter tuning
X_train_val_xgb = np.vstack([X_train_xgb, X_val_xgb])
y_train_val_xgb = np.concatenate([y_train_xgb, y_val_xgb])

print(f"  Train+Val (for tuning): {X_train_val_xgb.shape}, {y_train_val_xgb.shape}")
print("=" * 60)
# Out:
# ============================================================
# XGBOOST CLASSIFIER SETUP
# ============================================================
# ✓ XGBoost available
#
# ✓ Data prepared for XGBoost:
#   Training: (3071, 14), (3071,)
#   Validation: (832, 14), (832,)
#   Test: (976, 14), (976,)
#   Train+Val (for tuning): (3903, 14), (3903,)
# ============================================================

# %%
# ============================================================
# XGBoost: Default Parameters
# ============================================================

import xgboost as xgb

print("=" * 60)
print("XGBOOST: DEFAULT PARAMETERS")
print("=" * 60)

# Set default parameters for XGBoost (only hyperparameters, fixed params added separately)
xgb_best_params = {
    'n_estimators': 200,
    'max_depth': 5,
    'learning_rate': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'min_child_weight': 1,
    'gamma': 0,
    'reg_alpha': 0,
    'reg_lambda': 1.0
}

print(f"\nUsing default parameters: {xgb_best_params}")
print(f"\n✓ Parameters stored in 'xgb_best_params' for use in 5-fold CV and final training")
print("=" * 60)
# Out:
# ============================================================
# XGBOOST: DEFAULT PARAMETERS
# ============================================================
#
# Using default parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1, 'gamma': 0, 'reg_alpha': 0, 'reg_lambda': 1.0}
#
# ✓ Parameters stored in 'xgb_best_params' for use in 5-fold CV and final training
# ============================================================

# %% [markdown]
# ### 10.2. XGBoost: Hyperparameter Grid Search

# %%
# ============================================================
# XGBoost: Parameters Check
# ============================================================

print("=" * 60)
print("XGBOOST: PARAMETERS")
print("=" * 60)

# xgb_best_params should be set in the previous cell
if 'xgb_best_params' not in globals() or xgb_best_params is None:
    print("⚠ xgb_best_params not set. Please run the default parameters cell first.")
else:
    print(f"✓ Using parameters: {xgb_best_params}")
    print("\nNote: Fixed parameters (random_state, n_jobs, eval_metric, use_label_encoder, tree_method)")
    print("      are passed directly to XGBClassifier, not included in xgb_best_params")

print("=" * 60)
# Out:
# ============================================================
# XGBOOST: PARAMETERS
# ============================================================
# ✓ Using parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1, 'gamma': 0, 'reg_alpha': 0, 'reg_lambda': 1.0}
#
# Note: Fixed parameters (random_state, n_jobs, eval_metric, use_label_encoder, tree_method)
#       are passed directly to XGBClassifier, not included in xgb_best_params
# ============================================================

# %% [markdown]
# ### 10.3. XGBoost: 5-Fold Cross-Validation

# %%
# ============================================================
# XGBoost: 5-Fold Cross-Validation
# ============================================================

print("=" * 60)
print("XGBOOST: 5-FOLD CROSS-VALIDATION")
print("=" * 60)

from sklearn.model_selection import StratifiedGroupKFold, StratifiedKFold

# Prepare data for CV (combine train and val)
X_cv_xgb = X_train_val_xgb.copy()
y_cv_xgb = y_train_val_xgb.copy()

# Get participant IDs for CV (CRITICAL for preventing data leakage)
if 'pid_train' in globals() and 'pid_val' in globals():
    try:
        # Ensure participant IDs are available
        pid_train_array = np.array(pid_train) if isinstance(pid_train, (list, pd.Series)) else pid_train
        pid_val_array = np.array(pid_val) if isinstance(pid_val, (list, pd.Series)) else pid_val
        
        # Concatenate participant IDs
        pid_cv_xgb = np.concatenate([pid_train_array, pid_val_array])
        
        # Check if we have enough unique participants for 5-fold CV
        unique_pids = len(np.unique(pid_cv_xgb))
        use_group_kfold = unique_pids >= 5
        
        if use_group_kfold:
            print(f"✓ Found {unique_pids} unique participants")
            print("✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)")
        else:
            print(f"⚠ Only {unique_pids} unique participants (need at least 5 for participant-level CV)")
            print("⚠ Falling back to StratifiedKFold (sample-level CV - RISK OF DATA LEAKAGE)")
            pid_cv_xgb = None
    except Exception as e:
        print(f"⚠ Error extracting participant IDs: {e}")
        print("⚠ Falling back to StratifiedKFold (sample-level CV - RISK OF DATA LEAKAGE)")
        use_group_kfold = False
        pid_cv_xgb = None
else:
    print("⚠ Participant IDs (pid_train, pid_val) not found in globals()")
    print("⚠ Falling back to StratifiedKFold (sample-level CV - RISK OF DATA LEAKAGE)")
    use_group_kfold = False
    pid_cv_xgb = None

# Setup CV
if use_group_kfold and pid_cv_xgb is not None:
    skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
else:
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    pid_cv_xgb = None  # Ensure it's None for sample-level CV

# Helper function for threshold tuning
def find_best_threshold_xgb_cv(model, X, y, verbose=False):
    """Find optimal threshold for XGBoost based on F1-score with conservative bounds."""
    probs = model.predict_proba(X)[:, 1]
    
    # Diagnostics: Check probability distribution
    if verbose:
        print(f"  Probability stats: min={probs.min():.4f}, max={probs.max():.4f}, mean={probs.mean():.4f}, median={np.median(probs):.4f}")
        print(f"  Class distribution: {np.sum(y == 0)} Control, {np.sum(y == 1)} PD")
        high_prob_ratio = np.sum(probs > 0.9) / len(probs)
        low_prob_ratio = np.sum(probs < 0.1) / len(probs)
        print(f"  Probabilities > 0.9: {high_prob_ratio:.2%}, < 0.1: {low_prob_ratio:.2%}")
    
    # Conservative threshold search: restrict to reasonable range [0.2, 0.8]
    # This prevents extreme thresholds that don't make practical sense
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.2, 0.8, 25):  # More granular search in reasonable range
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    
    # Also compute Youden's J for reference (but constrained to reasonable range)
    from sklearn.metrics import roc_curve
    fpr, tpr, thresholds = roc_curve(y, probs)
    # Only consider thresholds in reasonable range
    reasonable_mask = (thresholds >= 0.2) & (thresholds <= 0.8)
    if np.any(reasonable_mask):
        reasonable_thresholds = thresholds[reasonable_mask]
        reasonable_tpr = tpr[reasonable_mask]
        reasonable_fpr = fpr[reasonable_mask]
        youden_j = reasonable_tpr - reasonable_fpr
        best_idx_youden = np.argmax(youden_j)
        best_thresh_youden = reasonable_thresholds[best_idx_youden]
    else:
        # Fallback: use median probability if all thresholds are outside range
        best_thresh_youden = np.median(probs)
        if verbose:
            print(f"  ⚠ Warning: All Youden's J thresholds outside reasonable range, using median")
    
    if verbose:
        print(f"  F1-based threshold (constrained to [0.2, 0.8]): {best_t:.3f} (F1={best_f1:.4f})")
        print(f"  Youden's J threshold (constrained to [0.2, 0.8]): {best_thresh_youden:.3f}")
    
    return best_t, best_f1

# Perform cross-validation
cv_results_xgb = {
    'fold': [],
    'train_acc': [],
    'val_acc': [],
    'test_acc': [],
    'train_roc_auc': [],
    'val_roc_auc': [],
    'test_roc_auc': [],
    'train_f1': [],
    'val_f1': [],
    'test_f1': [],
    'best_threshold': []
}

print("\nStarting 5-fold cross-validation...")
if use_group_kfold:
    splits = skf.split(X_cv_xgb, y_cv_xgb, pid_cv_xgb)
else:
    splits = skf.split(X_cv_xgb, y_cv_xgb)

for fold, (train_idx, test_idx) in enumerate(splits, 1):
    print(f"\n{'=' * 60}")
    print(f"FOLD {fold}/5")
    print(f"{'=' * 60}")
    
    # Split data
    X_train_cv = X_cv_xgb[train_idx]
    X_test_cv = X_cv_xgb[test_idx]
    y_train_cv = y_cv_xgb[train_idx]
    y_test_cv = y_cv_xgb[test_idx]
    
    # Further split train into train/val for threshold tuning
    # IMPORTANT: Use participant-level split to prevent leakage
    from sklearn.model_selection import train_test_split
    
    if use_group_kfold and pid_cv_xgb is not None:
        # Participant-level split for train/val
        train_pids = pid_cv_xgb[train_idx]
        unique_train_pids = np.unique(train_pids)
        
        # Get labels for each participant
        pid_to_label = {}
        for pid, label in zip(train_pids, y_train_cv):
            if pid not in pid_to_label:
                pid_to_label[pid] = label
        
        participant_labels_fold = np.array([pid_to_label[pid] for pid in unique_train_pids])
        
        # Split participants (not samples)
        pids_train_fold, pids_val_fold, y_p_train_fold, y_p_val_fold = train_test_split(
            unique_train_pids,
            participant_labels_fold,
            test_size=0.2,
            random_state=SEED + fold,  # Different seed per fold
            stratify=participant_labels_fold
        )
        
        # Map back to sample level
        train_fold_mask = np.isin(train_pids, pids_train_fold)
        val_fold_mask = np.isin(train_pids, pids_val_fold)
        
        X_train_fold = X_train_cv[train_fold_mask]
        X_val_fold = X_train_cv[val_fold_mask]
        y_train_fold = y_train_cv[train_fold_mask]
        y_val_fold = y_train_cv[val_fold_mask]
    else:
        # Sample-level split (fallback, but should not be used)
        print("  ⚠ WARNING: Using sample-level split (risk of data leakage)")
        X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(
            X_train_cv, y_train_cv, test_size=0.2, random_state=SEED + fold, stratify=y_train_cv
        )
    
    print(f"Train: {X_train_fold.shape[0]} samples ({np.sum(y_train_fold == 0)} Control, {np.sum(y_train_fold == 1)} PD)")
    print(f"Val: {X_val_fold.shape[0]} samples ({np.sum(y_val_fold == 0)} Control, {np.sum(y_val_fold == 1)} PD)")
    print(f"Test: {X_test_cv.shape[0]} samples ({np.sum(y_test_cv == 0)} Control, {np.sum(y_test_cv == 1)} PD)")
    
    # Train XGBoost
    xgb_model = xgb.XGBClassifier(
        **xgb_best_params,
        random_state=SEED,
        n_jobs=-1,
        eval_metric='logloss',
        use_label_encoder=False,
        tree_method='hist'
    )
    
    xgb_model.fit(X_train_fold, y_train_fold)
    
    # Find best threshold on validation set (with diagnostics for first fold)
    best_thresh, best_val_f1 = find_best_threshold_xgb_cv(
        xgb_model, X_val_fold, y_val_fold, 
        verbose=(fold == 1)  # Show diagnostics for first fold only
    )
    
    # Evaluate on all sets
    def evaluate_xgb_cv(model, X, y, threshold=0.5):
        probs = model.predict_proba(X)[:, 1]
        preds = (probs >= threshold).astype(int)
        return {
            'acc': accuracy_score(y, preds),
            'roc_auc': roc_auc_score(y, probs),
            'f1': f1_score(y, preds)
        }
    
    train_metrics = evaluate_xgb_cv(xgb_model, X_train_fold, y_train_fold, best_thresh)
    val_metrics = evaluate_xgb_cv(xgb_model, X_val_fold, y_val_fold, best_thresh)
    test_metrics = evaluate_xgb_cv(xgb_model, X_test_cv, y_test_cv, best_thresh)
    
    # Store results
    cv_results_xgb['fold'].append(fold)
    cv_results_xgb['train_acc'].append(train_metrics['acc'])
    cv_results_xgb['val_acc'].append(val_metrics['acc'])
    cv_results_xgb['test_acc'].append(test_metrics['acc'])
    cv_results_xgb['train_roc_auc'].append(train_metrics['roc_auc'])
    cv_results_xgb['val_roc_auc'].append(val_metrics['roc_auc'])
    cv_results_xgb['test_roc_auc'].append(test_metrics['roc_auc'])
    cv_results_xgb['train_f1'].append(train_metrics['f1'])
    cv_results_xgb['val_f1'].append(val_metrics['f1'])
    cv_results_xgb['test_f1'].append(test_metrics['f1'])
    cv_results_xgb['best_threshold'].append(best_thresh)
    
    print(f"\nFold {fold} Results:")
    print(f"  Validation - Acc: {val_metrics['acc']:.4f}, ROC-AUC: {val_metrics['roc_auc']:.4f}, F1: {val_metrics['f1']:.4f}")
    print(f"  Test (CV)   - Acc: {test_metrics['acc']:.4f}, ROC-AUC: {test_metrics['roc_auc']:.4f}, F1: {test_metrics['f1']:.4f}")
    print(f"  Best threshold: {best_thresh:.3f}")

# Summary
print("\n" + "=" * 60)
print("CROSS-VALIDATION SUMMARY")
print("=" * 60)

cv_summary = pd.DataFrame({
    'Metric': ['Test Accuracy', 'Test ROC-AUC', 'Test F1'],
    'Mean': [
        np.mean(cv_results_xgb['test_acc']),
        np.mean(cv_results_xgb['test_roc_auc']),
        np.mean(cv_results_xgb['test_f1'])
    ],
    'Std': [
        np.std(cv_results_xgb['test_acc']),
        np.std(cv_results_xgb['test_roc_auc']),
        np.std(cv_results_xgb['test_f1'])
    ],
    'Min': [
        np.min(cv_results_xgb['test_acc']),
        np.min(cv_results_xgb['test_roc_auc']),
        np.min(cv_results_xgb['test_f1'])
    ],
    'Max': [
        np.max(cv_results_xgb['test_acc']),
        np.max(cv_results_xgb['test_roc_auc']),
        np.max(cv_results_xgb['test_f1'])
    ]
})

print("\nTest Set Performance (CV):")
print(cv_summary.to_string(index=False))

# Save CV results
cv_results_df_xgb = pd.DataFrame(cv_results_xgb)
cv_results_df_xgb.to_csv(OUTPUT_DIR / 'xgb_cv_results.csv', index=False)
print(f"\n✓ Saved CV results to: {OUTPUT_DIR / 'xgb_cv_results.csv'}")

print("=" * 60)
# Out:
# ============================================================
# XGBOOST: 5-FOLD CROSS-VALIDATION
# ============================================================
# ✓ Found 100 unique participants
# ✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)
#
# Starting 5-fold cross-validation...
#
# ============================================================
# FOLD 1/5
# ============================================================
# Train: 2522 samples (1288 Control, 1234 PD)
# Val: 640 samples (310 Control, 330 PD)
# Test: 741 samples (327 Control, 414 PD)
#   Probability stats: min=0.0018, max=0.9956, mean=0.5129, median=0.5091
#   Class distribution: 310 Control, 330 PD
#   Probabilities > 0.9: 12.19%, < 0.1: 8.75%
#   F1-based threshold (constrained to [0.2, 0.8]): 0.225 (F1=0.7082)
#   Youden's J threshold (constrained to [0.2, 0.8]): 0.462
#
# Fold 1 Results:
#   Validation - Acc: 0.6266, ROC-AUC: 0.7203, F1: 0.7082
#   Test (CV)   - Acc: 0.5857, ROC-AUC: 0.6407, F1: 0.6939
#   Best threshold: 0.225
#
# ============================================================
# FOLD 2/5
# ============================================================
# Train: 2424 samples (1187 Control, 1237 PD)
# Val: 620 samples (303 Control, 317 PD)
# Test: 859 samples (435 Control, 424 PD)
#
# Fold 2 Results:
#   Validation - Acc: 0.6500, ROC-AUC: 0.7041, F1: 0.7250
#   Test (CV)   - Acc: 0.6170, ROC-AUC: 0.7463, F1: 0.7033
#   Best threshold: 0.250
#
# ============================================================
# FOLD 3/5
# ============================================================
# Train: 2572 samples (1333 Control, 1239 PD)
# Val: 604 samples (274 Control, 330 PD)
# Test: 727 samples (318 Control, 409 PD)
#
# Fold 3 Results:
#   Validation - Acc: 0.5894, ROC-AUC: 0.6717, F1: 0.6861
#   Test (CV)   - Acc: 0.6410, ROC-AUC: 0.7001, F1: 0.7071
#   Best threshold: 0.200
#
# ============================================================
# FOLD 4/5
# ============================================================
# Train: 2537 samples (1217 Control, 1320 PD)
# Val: 621 samples (279 Control, 342 PD)
# Test: 745 samples (429 Control, 316 PD)
#
# Fold 4 Results:
#   Validation - Acc: 0.7037, ROC-AUC: 0.7697, F1: 0.7683
#   Test (CV)   - Acc: 0.5664, ROC-AUC: 0.6306, F1: 0.5821
#   Best threshold: 0.400
#
# ============================================================
# FOLD 5/5
# ============================================================
# Train: 2439 samples (1220 Control, 1219 PD)
# Val: 633 samples (289 Control, 344 PD)
# Test: 831 samples (416 Control, 415 PD)
#
# Fold 5 Results:
#   Validation - Acc: 0.6619, ROC-AUC: 0.7451, F1: 0.7345
#   Test (CV)   - Acc: 0.6029, ROC-AUC: 0.6372, F1: 0.6851
#   Best threshold: 0.200
#
# ============================================================
# CROSS-VALIDATION SUMMARY
# ============================================================
#
# Test Set Performance (CV):
#        Metric     Mean      Std      Min      Max
# Test Accuracy 0.602603 0.025590 0.566443 0.640990
#  Test ROC-AUC 0.670962 0.045172 0.630595 0.746270
#       Test F1 0.674317 0.046714 0.582147 0.707071
#
# ✓ Saved CV results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_cv_results.csv
# ============================================================

# %% [markdown]
# ### 10.4. XGBoost: CV Results Visualization

# %%
# ============================================================
# XGB: CV Results Visualization
# ============================================================

print("=" * 60)
print("XGB: CV RESULTS VISUALIZATION")
print("=" * 60)

if 'cv_results_xgb_df' in globals():
    plot_cv_results_standardized(
        cv_results_xgb_df,
        model_name='XGB',
        save_path=OUTPUT_DIR / 'xgb_cv_results_visualization.png'
    )
else:
    print(f"⚠ cv_results_xgb_df not found. Run CV section first.")
print("=" * 60)
# Out:
# ============================================================
# XGB: CV RESULTS VISUALIZATION
# ============================================================
# ⚠ cv_results_xgb_df not found. Run CV section first.
# ============================================================

# %% [markdown]
# ### 10.5. XGBoost: Final Training on Full Training Set

# %%
# ============================================================
# XGBoost: Train on Full Training Data and Evaluate
# ============================================================

print("=" * 60)
print("XGBOOST: TRAIN AND EVALUATE")
print("=" * 60)

# Helper function for threshold tuning (XGBoost version)
def find_best_threshold_xgb(model, X, y):
    """Find optimal threshold for XGBoost based on F1-score with conservative bounds."""
    probs = model.predict_proba(X)[:, 1]
    
    # Conservative threshold search: restrict to reasonable range [0.2, 0.8]
    # This prevents extreme thresholds that don't make practical sense
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.2, 0.8, 25):  # More granular search in reasonable range
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    
    return best_t, best_f1

print("\nTraining XGBoost on full training data...")
xgb_final = xgb.XGBClassifier(
    **xgb_best_params,
    random_state=SEED,
    n_jobs=-1,
    eval_metric='logloss',
    use_label_encoder=False,
    tree_method='hist'
)

# Train on combined train+val data
xgb_final.fit(X_train_val_xgb, y_train_val_xgb)

print("✓ XGBoost training complete")

# Find best threshold on validation set
print("\nFinding optimal threshold on validation set...")
best_threshold_xgb, best_val_f1_xgb = find_best_threshold_xgb(xgb_final, X_val_xgb, y_val_xgb)
print(f"  Best threshold: {best_threshold_xgb:.3f}")
print(f"  Validation F1: {best_val_f1_xgb:.4f}")

# Evaluate on test set
print("\nEvaluating on test set...")
y_test_proba_xgb = xgb_final.predict_proba(X_test_xgb)[:, 1]
y_test_pred_xgb_thresh = (y_test_proba_xgb >= best_threshold_xgb).astype(int)

metrics_xgb = {
    'accuracy': accuracy_score(y_test_xgb, y_test_pred_xgb_thresh),
    'roc_auc': roc_auc_score(y_test_xgb, y_test_proba_xgb),
    'f1': f1_score(y_test_xgb, y_test_pred_xgb_thresh),
    'precision': precision_score(y_test_xgb, y_test_pred_xgb_thresh, zero_division=0),
    'recall': recall_score(y_test_xgb, y_test_pred_xgb_thresh, zero_division=0)
}

print("\n" + "=" * 60)
print("XGBOOST PERFORMANCE ON TEST DATA")
print("=" * 60)
for k, v in metrics_xgb.items():
    print(f"  {k}: {v:.4f}")
print(f"  (using threshold: {best_threshold_xgb:.3f})")
print("=" * 60)
# Out:
# ============================================================
# XGBOOST: TRAIN AND EVALUATE
# ============================================================
#
# Training XGBoost on full training data...
# ✓ XGBoost training complete
#
# Finding optimal threshold on validation set...
#   Best threshold: 0.525
#   Validation F1: 0.9775
#
# Evaluating on test set...
#
# ============================================================
# XGBOOST PERFORMANCE ON TEST DATA
# ============================================================
#   accuracy: 0.7090
#   roc_auc: 0.7862
#   f1: 0.6972
#   precision: 0.6884
#   recall: 0.7063
#   (using threshold: 0.525)
# ============================================================

# %% [markdown]
# ### 10.6. XGBoost: Feature Importance

# %%
# ============================================================
# XGBoost: Feature Importance Analysis
# ============================================================

print("=" * 60)
print("XGBOOST: FEATURE IMPORTANCE")
print("=" * 60)

# Get feature importance from XGBoost
xgb_importance = xgb_final.feature_importances_

# Create DataFrame
xgb_importance_df = pd.DataFrame({
    'feature': feature_cols,
    'importance': xgb_importance
}).sort_values('importance', ascending=False)

print(f"\nTop 20 Most Important Features (XGBoost):")
print(xgb_importance_df.head(20)[['feature', 'importance']].to_string(index=False))

# Save feature importance
xgb_importance_df.to_csv(OUTPUT_DIR / 'xgb_feature_importance.csv', index=False)
print(f"\n✓ Saved feature importance to: {OUTPUT_DIR / 'xgb_feature_importance.csv'}")

# Visualize top features
top_n = 20
top_xgb_features = xgb_importance_df.head(top_n)

plt.figure(figsize=(10, 8))
plt.barh(range(len(top_xgb_features)), top_xgb_features['importance'].values, color='darkorange')
plt.yticks(range(len(top_xgb_features)), top_xgb_features['feature'].values)
plt.xlabel('Feature Importance', fontsize=12)
plt.title(f'Top {top_n} Most Important Features (XGBoost)', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'xgb_feature_importance.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved feature importance plot to: {OUTPUT_DIR / 'xgb_feature_importance.png'}")
print("=" * 60)
# Out:
# ============================================================
# XGBOOST: FEATURE IMPORTANCE
# ============================================================
#
# Top 20 Most Important Features (XGBoost):
#    feature  importance
#  cluster_4    0.091765
# cluster_12    0.089202
# cluster_11    0.079683
#  cluster_6    0.074563
#  cluster_7    0.074190
#  cluster_2    0.073095
#  cluster_9    0.070318
# cluster_14    0.069587
#  cluster_8    0.066602
#  cluster_5    0.064382
# cluster_13    0.064049
#  cluster_1    0.061870
# cluster_10    0.061391
#  cluster_3    0.059304
#
# ✓ Saved feature importance to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_feature_importance.csv
# ✓ Saved feature importance plot to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_feature_importance.png
# ============================================================

# %% [markdown]
# ### 10.7. XGBoost: Performance Visualizations

# %%
# ============================================================
# XGBoost: Performance Visualizations
# ============================================================

print("=" * 60)
print("RANDOM FOREST: PEXGBOOSTORMANCE VISUALIZATIONS")
print("=" * 60)

# Get predictions and probabilities
y_test_proba_xgb_viz = xgb_final.predict_proba(X_test_xgb)[:, 1]
y_test_pred_xgb_viz = (y_test_proba_xgb_viz >= best_threshold_xgb).astype(int)

# ROC Curve
print("\n" + "=" * 60)
print("VISUALIZING ROC CURVE")
print("=" * 60)

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
fpr_rf, tpr_rf, _ = roc_curve(y_test_xgb, y_test_proba_xgb_viz)
roc_auc_rf = roc_auc_score(y_test_xgb, y_test_proba_xgb_viz)

plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc_rf:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random (AUC = 0.5000)')

# Mark threshold point
tn, fp, fn, tp = confusion_matrix(y_test_xgb, y_test_pred_xgb_viz).ravel()
tpr_at_threshold = tp / (tp + fn) if (tp + fn) > 0 else 0
fpr_at_threshold = fp / (fp + tn) if (fp + tn) > 0 else 0
plt.plot(fpr_at_threshold, tpr_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_xgb:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - XGBoost Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'xgb_roc_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ ROC-AUC: {roc_auc_rf:.4f}")
print(f"✓ Saved ROC curve to: {OUTPUT_DIR / 'xgb_roc_curve.png'}")

# Precision-Recall Curve
print("\n" + "=" * 60)
print("VISUALIZING PRECISION-RECALL CURVE")
print("=" * 60)

from sklearn.metrics import precision_recall_curve, average_precision_score, precision_score, recall_score
precision_rf, recall_rf, _ = precision_recall_curve(y_test_xgb, y_test_proba_xgb_viz)
avg_precision_rf = average_precision_score(y_test_xgb, y_test_proba_xgb_viz)

plt.figure(figsize=(8, 6))
plt.plot(recall_rf, precision_rf, color='darkblue', lw=2, label=f'PR curve (AP = {avg_precision_rf:.4f})')

# Mark threshold point
prec_at_threshold = precision_score(y_test_xgb, y_test_pred_xgb_viz)
rec_at_threshold = recall_score(y_test_xgb, y_test_pred_xgb_viz)
plt.plot(rec_at_threshold, prec_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_xgb:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.title('Precision-Recall Curve - XGBoost Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower left", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'xgb_pr_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Average Precision: {avg_precision_rf:.4f}")
print(f"✓ Saved PR curve to: {OUTPUT_DIR / 'xgb_pr_curve.png'}")

# Confusion Matrix
print("\n" + "=" * 60)
print("VISUALIZING CONFUSION MATRIX")
print("=" * 60)

cm_rf = confusion_matrix(y_test_xgb, y_test_pred_xgb_viz)
tn, fp, fn, tp = cm_rf.ravel()
accuracy_rf = (tn + tp) / (tn + fp + fn + tp)

plt.figure(figsize=(8, 6))
import seaborn as sns
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=['Control', "Parkinson's"],
            yticklabels=['Control', "Parkinson's"],
            square=True, linewidths=2, linecolor='gray')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.title('Confusion Matrix - XGBoost Classification', fontsize=14, fontweight='bold')
plt.text(0.5, -0.15, f'Accuracy: {accuracy_rf:.4f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.text(0.5, -0.20, f'Threshold: {best_threshold_xgb:.3f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'xgb_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Confusion Matrix:")
print(f"  True Negatives (TN): {tn}")
print(f"  False Positives (FP): {fp}")
print(f"  False Negatives (FN): {fn}")
print(f"  True Positives (TP): {tp}")
print(f"✓ Saved confusion matrix to: {OUTPUT_DIR / 'xgb_confusion_matrix.png'}")

print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: PEXGBOOSTORMANCE VISUALIZATIONS
# ============================================================
#
# ============================================================
# VISUALIZING ROC CURVE
# ============================================================
# ✓ ROC-AUC: 0.7862
# ✓ Saved ROC curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_roc_curve.png
#
# ============================================================
# VISUALIZING PRECISION-RECALL CURVE
# ============================================================
# ✓ Average Precision: 0.7787
# ✓ Saved PR curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_pr_curve.png
#
# ============================================================
# VISUALIZING CONFUSION MATRIX
# ============================================================
# ✓ Confusion Matrix:
#   True Negatives (TN): 365
#   False Positives (FP): 148
#   False Negatives (FN): 136
#   True Positives (TP): 327
# ✓ Saved confusion matrix to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_confusion_matrix.png
# ============================================================

# %% [markdown]
# ## 11. Logistic Regression Classifier

# %% [markdown]
# ### 11.1. Logistic Regression: Hyperparameter Grid Search

# %%
# ============================================================
# Logistic Regression: Default Parameters
# ============================================================

from sklearn.linear_model import LogisticRegression

print("=" * 60)
print("LOGISTIC REGRESSION: DEFAULT PARAMETERS")
print("=" * 60)

# Set default parameters for Logistic Regression
lr_best_params = {
    'C': 1.0,
    'penalty': 'l2',
    'solver': 'lbfgs',
    'class_weight': 'balanced',
    'random_state': SEED,
    'max_iter': 1000
}

print(f"\nUsing default parameters: {lr_best_params}")
print(f"\n✓ Parameters stored in 'lr_best_params' for use in 5-fold CV and final training")
print("=" * 60)
# Out:
# ============================================================
# LOGISTIC REGRESSION: DEFAULT PARAMETERS
# ============================================================
#
# Using default parameters: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs', 'class_weight': 'balanced', 'random_state': 42, 'max_iter': 1000}
#
# ✓ Parameters stored in 'lr_best_params' for use in 5-fold CV and final training
# ============================================================

# %% [markdown]
# ### 11.1. Logistic Regression: 5-Fold Cross-Validation

# %%
# ============================================================
# Logistic Regression: 5-Fold Cross-Validation
# ============================================================

print("=" * 60)
print("LOGISTIC REGRESSION: 5-FOLD CROSS-VALIDATION")
print("=" * 60)

from sklearn.linear_model import LogisticRegression

# lr_best_params should be set by grid search in section 11.0
# If grid search hasn't been run, use default parameters as fallback
if 'lr_best_params' not in globals() or lr_best_params is None:
    print("⚠ Grid search not run yet. Using default parameters.")
    lr_best_params = {
        'C': 1.0,
        'penalty': 'l2',
        'solver': 'lbfgs',
        'class_weight': 'balanced'
    }
    lr_best_params['random_state'] = SEED
    lr_best_params['max_iter'] = 1000
else:
    # Add fixed parameters that aren't in grid search
    if 'random_state' not in lr_best_params:
        lr_best_params['random_state'] = SEED
    if 'max_iter' not in lr_best_params:
        lr_best_params['max_iter'] = 1000
    print(f"✓ Using grid search parameters: {lr_best_params}")

# Prepare data for CV (combine train and val)
X_cv_lr = np.vstack([X_train_rf, X_val_rf])
y_cv_lr = np.concatenate([y_train_rf, y_val_rf])

# Get participant IDs for CV
try:
    pid_train_array = np.array(pid_train) if isinstance(pid_train, (list, pd.Series)) else pid_train
    pid_val_array = np.array(pid_val) if isinstance(pid_val, (list, pd.Series)) else pid_val
    pid_cv_lr = np.concatenate([pid_train_array, pid_val_array])
    
    unique_pids = len(np.unique(pid_cv_lr))
    use_group_kfold = unique_pids >= 5
    
    if use_group_kfold:
        print(f"✓ Found {unique_pids} unique participants")
        print("✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)")
    else:
        print(f"⚠ Only {unique_pids} unique participants")
        print("⚠ Falling back to StratifiedKFold (sample-level CV - RISK OF DATA LEAKAGE)")
        pid_cv_lr = None
except Exception as e:
    print(f"⚠ Error extracting participant IDs: {e}")
    use_group_kfold = False
    pid_cv_lr = None

# Setup CV
try:
    from sklearn.model_selection import StratifiedGroupKFold
    if use_group_kfold and pid_cv_lr is not None:
        skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    else:
        from sklearn.model_selection import StratifiedKFold
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
        pid_cv_lr = None
except ImportError:
    from sklearn.model_selection import StratifiedKFold
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    pid_cv_lr = None
    use_group_kfold = False

# Helper function for threshold tuning
def find_best_threshold_lr_cv(model, X, y):
    """Find optimal threshold for Logistic Regression based on F1-score."""
    probs = model.predict_proba(X)[:, 1]
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# Perform cross-validation
cv_results_lr = {
    'fold': [],
    'train_acc': [],
    'val_acc': [],
    'test_acc': [],
    'train_roc_auc': [],
    'val_roc_auc': [],
    'test_roc_auc': [],
    'train_f1': [],
    'val_f1': [],
    'test_f1': [],
    'best_threshold': []
}

print("\nStarting 5-fold cross-validation...")
if use_group_kfold and pid_cv_lr is not None:
    splits = skf.split(X_cv_lr, y_cv_lr, pid_cv_lr)
else:
    splits = skf.split(X_cv_lr, y_cv_lr)

for fold, (train_idx, test_idx) in enumerate(splits, 1):
    print(f"\n{'=' * 60}")
    print(f"FOLD {fold}/5")
    print(f"{'=' * 60}")
    
    # Split data
    X_train_cv = X_cv_lr[train_idx]
    X_test_cv = X_cv_lr[test_idx]
    y_train_cv = y_cv_lr[train_idx]
    y_test_cv = y_cv_lr[test_idx]
    
    # Further split train into train/val for threshold tuning (participant-level)
    from sklearn.model_selection import train_test_split
    
    if use_group_kfold and pid_cv_lr is not None:
        train_pids = pid_cv_lr[train_idx]
        unique_train_pids = np.unique(train_pids)
        pid_to_label = {}
        for pid, label in zip(train_pids, y_train_cv):
            if pid not in pid_to_label:
                pid_to_label[pid] = label
        participant_labels_fold = np.array([pid_to_label[pid] for pid in unique_train_pids])
        
        pids_train_fold, pids_val_fold, y_p_train_fold, y_p_val_fold = train_test_split(
            unique_train_pids, participant_labels_fold,
            test_size=0.2, random_state=SEED + fold, stratify=participant_labels_fold
        )
        
        train_fold_mask = np.isin(train_pids, pids_train_fold)
        val_fold_mask = np.isin(train_pids, pids_val_fold)
        
        X_train_fold = X_train_cv[train_fold_mask]
        X_val_fold = X_train_cv[val_fold_mask]
        y_train_fold = y_train_cv[train_fold_mask]
        y_val_fold = y_train_cv[val_fold_mask]
    else:
        X_train_fold, X_val_fold, y_train_fold, y_val_fold = train_test_split(
            X_train_cv, y_train_cv, test_size=0.2, random_state=SEED + fold, stratify=y_train_cv
        )
    
    print(f"Train: {X_train_fold.shape[0]} samples ({np.sum(y_train_fold == 0)} Control, {np.sum(y_train_fold == 1)} PD)")
    print(f"Val: {X_val_fold.shape[0]} samples ({np.sum(y_val_fold == 0)} Control, {np.sum(y_val_fold == 1)} PD)")
    print(f"Test: {X_test_cv.shape[0]} samples ({np.sum(y_test_cv == 0)} Control, {np.sum(y_test_cv == 1)} PD)")
    
    # Train model
    lr_model = LogisticRegression(**lr_best_params)
    lr_model.fit(X_train_fold, y_train_fold)
    
    # Evaluate on train, val, and test
    for split_name, X_split, y_split in [('train', X_train_fold, y_train_fold),
                                          ('val', X_val_fold, y_val_fold),
                                          ('test', X_test_cv, y_test_cv)]:
        y_pred = lr_model.predict(X_split)
        y_proba = lr_model.predict_proba(X_split)[:, 1]
        
        acc = accuracy_score(y_split, y_pred)
        auc = roc_auc_score(y_split, y_proba)
        f1 = f1_score(y_split, y_pred)
        
        cv_results_lr[f'{split_name}_acc'].append(acc)
        cv_results_lr[f'{split_name}_roc_auc'].append(auc)
        cv_results_lr[f'{split_name}_f1'].append(f1)
    
    # Find best threshold on validation set
    best_thresh, best_val_f1 = find_best_threshold_lr_cv(lr_model, X_val_fold, y_val_fold)
    cv_results_lr['best_threshold'].append(best_thresh)
    
    print(f"\nFold {fold} Results:")
    print(f"  Train - Acc: {cv_results_lr['train_acc'][-1]:.4f}, ROC-AUC: {cv_results_lr['train_roc_auc'][-1]:.4f}, F1: {cv_results_lr['train_f1'][-1]:.4f}")
    print(f"  Val   - Acc: {cv_results_lr['val_acc'][-1]:.4f}, ROC-AUC: {cv_results_lr['val_roc_auc'][-1]:.4f}, F1: {cv_results_lr['val_f1'][-1]:.4f}")
    print(f"  Test  - Acc: {cv_results_lr['test_acc'][-1]:.4f}, ROC-AUC: {cv_results_lr['test_roc_auc'][-1]:.4f}, F1: {cv_results_lr['test_f1'][-1]:.4f}")
    print(f"  Best Threshold: {best_thresh:.3f} (Val F1={best_val_f1:.4f})")
    
    cv_results_lr['fold'].append(fold)

# Summary
print("\n" + "=" * 60)
print("CROSS-VALIDATION SUMMARY")
print("=" * 60)
print(f"Test Accuracy: {np.mean(cv_results_lr['test_acc']):.4f} ± {np.std(cv_results_lr['test_acc']):.4f}")
print(f"Test ROC-AUC: {np.mean(cv_results_lr['test_roc_auc']):.4f} ± {np.std(cv_results_lr['test_roc_auc']):.4f}")
print(f"Test F1: {np.mean(cv_results_lr['test_f1']):.4f} ± {np.std(cv_results_lr['test_f1']):.4f}")

# Save CV results
cv_results_lr_df = pd.DataFrame(cv_results_lr)
cv_results_lr_df.to_csv(OUTPUT_DIR / 'lr_cv_results.csv', index=False)
print(f"\n✓ Saved CV results to: {OUTPUT_DIR / 'lr_cv_results.csv'}")
print("=" * 60)
# Out:
# ============================================================
# LOGISTIC REGRESSION: 5-FOLD CROSS-VALIDATION
# ============================================================
# ✓ Using grid search parameters: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs', 'class_weight': 'balanced', 'random_state': 42, 'max_iter': 1000}
# ✓ Found 100 unique participants
# ✓ Using StratifiedGroupKFold (participant-level CV - NO DATA LEAKAGE)
#
# Starting 5-fold cross-validation...
#
# ============================================================
# FOLD 1/5
# ============================================================
# Train: 2522 samples (1288 Control, 1234 PD)
# Val: 640 samples (310 Control, 330 PD)
# Test: 741 samples (327 Control, 414 PD)
#
# Fold 1 Results:
#   Train - Acc: 0.6408, ROC-AUC: 0.6869, F1: 0.6203
#   Val   - Acc: 0.5828, ROC-AUC: 0.5919, F1: 0.5291
#   Test  - Acc: 0.5938, ROC-AUC: 0.6351, F1: 0.6076
#   Best Threshold: 0.150 (Val F1=0.6819)
#
# ============================================================
# FOLD 2/5
# ============================================================
# Train: 2424 samples (1187 Control, 1237 PD)
# Val: 620 samples (303 Control, 317 PD)
# Test: 859 samples (435 Control, 424 PD)
#
# Fold 2 Results:
#   Train - Acc: 0.6448, ROC-AUC: 0.6811, F1: 0.6417
#   Val   - Acc: 0.5871, ROC-AUC: 0.6419, F1: 0.5776
#   Test  - Acc: 0.5716, ROC-AUC: 0.6217, F1: 0.5691
#   Best Threshold: 0.200 (Val F1=0.6774)
#
# ============================================================
# FOLD 3/5
# ============================================================
# Train: 2572 samples (1333 Control, 1239 PD)
# Val: 604 samples (274 Control, 330 PD)
# Test: 727 samples (318 Control, 409 PD)
#
# Fold 3 Results:
#   Train - Acc: 0.6240, ROC-AUC: 0.6717, F1: 0.5928
#   Val   - Acc: 0.6109, ROC-AUC: 0.6330, F1: 0.5884
#   Test  - Acc: 0.6259, ROC-AUC: 0.6843, F1: 0.6103
#   Best Threshold: 0.050 (Val F1=0.7066)
#
# ============================================================
# FOLD 4/5
# ============================================================
# Train: 2537 samples (1217 Control, 1320 PD)
# Val: 621 samples (279 Control, 342 PD)
# Test: 745 samples (429 Control, 316 PD)
#
# Fold 4 Results:
#   Train - Acc: 0.6330, ROC-AUC: 0.6857, F1: 0.6208
#   Val   - Acc: 0.6586, ROC-AUC: 0.6989, F1: 0.7088
#   Test  - Acc: 0.5101, ROC-AUC: 0.4985, F1: 0.4179
#   Best Threshold: 0.350 (Val F1=0.7175)
#
# ============================================================
# FOLD 5/5
# ============================================================
# Train: 2439 samples (1220 Control, 1219 PD)
# Val: 633 samples (289 Control, 344 PD)
# Test: 831 samples (416 Control, 415 PD)
#
# Fold 5 Results:
#   Train - Acc: 0.6343, ROC-AUC: 0.6826, F1: 0.6198
#   Val   - Acc: 0.5956, ROC-AUC: 0.6581, F1: 0.5690
#   Test  - Acc: 0.5572, ROC-AUC: 0.5958, F1: 0.5411
#   Best Threshold: 0.150 (Val F1=0.7085)
#
# ============================================================
# CROSS-VALIDATION SUMMARY
# ============================================================
# Test Accuracy: 0.5717 ± 0.0386
# Test ROC-AUC: 0.6071 ± 0.0614
# Test F1: 0.5492 ± 0.0705
#
# ✓ Saved CV results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_cv_results.csv
# ============================================================

# %% [markdown]
# ### 11.2. Logistic Regression: CV Results Visualization

# %%
# ============================================================
# LR: CV Results Visualization
# ============================================================

print("=" * 60)
print("LR: CV RESULTS VISUALIZATION")
print("=" * 60)

if 'cv_results_lr_df' in globals():
    plot_cv_results_standardized(
        cv_results_lr_df,
        model_name='LR',
        save_path=OUTPUT_DIR / 'lr_cv_results_visualization.png'
    )
else:
    print(f"⚠ cv_results_lr_df not found. Run CV section first.")
print("=" * 60)
# Out:
# ============================================================
# LR: CV RESULTS VISUALIZATION
# ============================================================
# ✓ Saved CV visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_cv_results_visualization.png
# LR - CV Summary Statistics:
#   Test Accuracy: 0.5717 ± 0.0386
#   Test ROC-AUC:  0.6071 ± 0.0614
#   Test F1 Score: 0.5492 ± 0.0705
# ============================================================

# %% [markdown]
# ### 11.3. Logistic Regression: Train and Evaluate

# %%
# ============================================================
# Logistic Regression: Train on Full Training Data and Evaluate
# ============================================================

print("=" * 60)
print("LOGISTIC REGRESSION: TRAINING AND EVALUATION")
print("=" * 60)

# Helper function for threshold tuning
def find_best_threshold_lr(model, X, y):
    """Find optimal threshold for Logistic Regression based on F1-score."""
    probs = model.predict_proba(X)[:, 1]
    best_t, best_f1 = 0.5, -1
    for t in np.linspace(0.05, 0.95, 19):
        pred = (probs >= t).astype(int)
        f1 = f1_score(y, pred)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# Train on full training data
print("\nTraining Logistic Regression on full training data...")
lr_final = LogisticRegression(**lr_best_params)
lr_final.fit(X_train_val_rf, y_train_val_rf)

# Find best threshold on validation data
best_threshold_lr, best_val_f1_lr = find_best_threshold_lr(lr_final, X_val_rf, y_val_rf)
print(f"Best threshold: {best_threshold_lr:.3f} (val F1={best_val_f1_lr:.4f})")

# Evaluate on test data
y_test_proba_lr = lr_final.predict_proba(X_test_rf)[:, 1]
y_test_pred_lr = (y_test_proba_lr >= best_threshold_lr).astype(int)

metrics_lr = {
    'accuracy': accuracy_score(y_test_rf, y_test_pred_lr),
    'roc_auc': roc_auc_score(y_test_rf, y_test_proba_lr),
    'f1': f1_score(y_test_rf, y_test_pred_lr),
    'precision': precision_score(y_test_rf, y_test_pred_lr),
    'recall': recall_score(y_test_rf, y_test_pred_lr)
}

print("\n" + "=" * 60)
print("LOGISTIC REGRESSION PERFORMANCE ON TEST DATA")
print("=" * 60)
for k, v in metrics_lr.items():
    print(f"  {k}: {v:.4f}")
print(f"  (using threshold: {best_threshold_lr:.3f})")
print("=" * 60)
# Out:
# ============================================================
# LOGISTIC REGRESSION: TRAINING AND EVALUATION
# ============================================================
#
# Training Logistic Regression on full training data...
# Best threshold: 0.200 (val F1=0.6720)
#
# ============================================================
# LOGISTIC REGRESSION PERFORMANCE ON TEST DATA
# ============================================================
#   accuracy: 0.4805
#   roc_auc: 0.6677
#   f1: 0.6437
#   precision: 0.4771
#   recall: 0.9892
#   (using threshold: 0.200)
# ============================================================

# %% [markdown]
# ### 11.4. Logistic Regression: Performance Visualizations

# %%
# ============================================================
# Logistic Regression: Performance Visualizations
# ============================================================

print("=" * 60)
print("RANDOM FOREST: PELOGISTIC REGRESSIONORMANCE VISUALIZATIONS")
print("=" * 60)

# Get predictions and probabilities
y_test_proba_lr_viz = lr_final.predict_proba(X_test_rf)[:, 1]
y_test_pred_lr_viz = (y_test_proba_lr_viz >= best_threshold_lr).astype(int)

# ROC Curve
print("\n" + "=" * 60)
print("VISUALIZING ROC CURVE")
print("=" * 60)

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
fpr_rf, tpr_rf, _ = roc_curve(y_test_rf, y_test_proba_lr_viz)
roc_auc_rf = roc_auc_score(y_test_rf, y_test_proba_lr_viz)

plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc_rf:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random (AUC = 0.5000)')

# Mark threshold point
tn, fp, fn, tp = confusion_matrix(y_test_rf, y_test_pred_lr_viz).ravel()
tpr_at_threshold = tp / (tp + fn) if (tp + fn) > 0 else 0
fpr_at_threshold = fp / (fp + tn) if (fp + tn) > 0 else 0
plt.plot(fpr_at_threshold, tpr_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_lr:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curve - Logistic Regression Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower right", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'lr_roc_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ ROC-AUC: {roc_auc_rf:.4f}")
print(f"✓ Saved ROC curve to: {OUTPUT_DIR / 'lr_roc_curve.png'}")

# Precision-Recall Curve
print("\n" + "=" * 60)
print("VISUALIZING PRECISION-RECALL CURVE")
print("=" * 60)

from sklearn.metrics import precision_recall_curve, average_precision_score, precision_score, recall_score
precision_rf, recall_rf, _ = precision_recall_curve(y_test_rf, y_test_proba_lr_viz)
avg_precision_rf = average_precision_score(y_test_rf, y_test_proba_lr_viz)

plt.figure(figsize=(8, 6))
plt.plot(recall_rf, precision_rf, color='darkblue', lw=2, label=f'PR curve (AP = {avg_precision_rf:.4f})')

# Mark threshold point
prec_at_threshold = precision_score(y_test_rf, y_test_pred_lr_viz)
rec_at_threshold = recall_score(y_test_rf, y_test_pred_lr_viz)
plt.plot(rec_at_threshold, prec_at_threshold, 'ro', markersize=10, label=f'Threshold {best_threshold_lr:.3f}')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.title('Precision-Recall Curve - Logistic Regression Classification', fontsize=14, fontweight='bold')
plt.legend(loc="lower left", fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'lr_pr_curve.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Average Precision: {avg_precision_rf:.4f}")
print(f"✓ Saved PR curve to: {OUTPUT_DIR / 'lr_pr_curve.png'}")

# Confusion Matrix
print("\n" + "=" * 60)
print("VISUALIZING CONFUSION MATRIX")
print("=" * 60)

cm_rf = confusion_matrix(y_test_rf, y_test_pred_lr_viz)
tn, fp, fn, tp = cm_rf.ravel()
accuracy_rf = (tn + tp) / (tn + fp + fn + tp)

plt.figure(figsize=(8, 6))
import seaborn as sns
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=['Control', "Parkinson's"],
            yticklabels=['Control', "Parkinson's"],
            square=True, linewidths=2, linecolor='gray')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.title('Confusion Matrix - Logistic Regression Classification', fontsize=14, fontweight='bold')
plt.text(0.5, -0.15, f'Accuracy: {accuracy_rf:.4f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.text(0.5, -0.20, f'Threshold: {best_threshold_lr:.3f}', 
         ha='center', transform=plt.gca().transAxes, fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'lr_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Confusion Matrix:")
print(f"  True Negatives (TN): {tn}")
print(f"  False Positives (FP): {fp}")
print(f"  False Negatives (FN): {fn}")
print(f"  True Positives (TP): {tp}")
print(f"✓ Saved confusion matrix to: {OUTPUT_DIR / 'lr_confusion_matrix.png'}")

print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: PELOGISTIC REGRESSIONORMANCE VISUALIZATIONS
# ============================================================
#
# ============================================================
# VISUALIZING ROC CURVE
# ============================================================
# ✓ ROC-AUC: 0.6677
# ✓ Saved ROC curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_roc_curve.png
#
# ============================================================
# VISUALIZING PRECISION-RECALL CURVE
# ============================================================
# ✓ Average Precision: 0.6565
# ✓ Saved PR curve to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_pr_curve.png
#
# ============================================================
# VISUALIZING CONFUSION MATRIX
# ============================================================
# ✓ Confusion Matrix:
#   True Negatives (TN): 11
#   False Positives (FP): 502
#   False Negatives (FN): 5
#   True Positives (TP): 458
# ✓ Saved confusion matrix to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_confusion_matrix.png
# ============================================================

# %% [markdown]
# ## 12. Comprehensive Model Comparison

# %%
# ============================================================
# Model Comparison: Neural Network vs Random Forest vs XGBoost vs Logistic Regression
# ============================================================

print("=" * 60)
print("MODEL COMPARISON: ALL MODELS")
print("=" * 60)

# Get baseline neural network metrics
metrics_baseline_nn = metrics_real_baseline

# Handle case where precision/recall might not be in old metrics
if 'precision' not in metrics_baseline_nn:
    # Recalculate if missing
    print("⚠ Recalculating precision/recall for neural network...")
    y_test_probs_nn = []
    y_test_labels_nn = []
    model_real_baseline.eval()
    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(DEVICE)
            logits = model_real_baseline(xb)
            probs = torch.sigmoid(logits).cpu().numpy().flatten()
            y_test_probs_nn.extend(probs)
            y_test_labels_nn.extend(yb.numpy().flatten())
    
    y_test_probs_nn = np.array(y_test_probs_nn)
    y_test_labels_nn = np.array(y_test_labels_nn).astype(int)
    y_test_preds_nn = (y_test_probs_nn >= best_threshold).astype(int)
    
    metrics_baseline_nn['precision'] = precision_score(y_test_labels_nn, y_test_preds_nn, zero_division=0)
    metrics_baseline_nn['recall'] = recall_score(y_test_labels_nn, y_test_preds_nn, zero_division=0)

# Create comparison DataFrame
comparison_data = {
    'Model': ['Neural Network (Baseline)', 'Random Forest', 'XGBoost', 'Logistic Regression'],
    'Accuracy': [metrics_baseline_nn['accuracy'], metrics_rf['accuracy'], metrics_xgb['accuracy'], metrics_lr['accuracy']],
    'ROC-AUC': [metrics_baseline_nn['roc_auc'], metrics_rf['roc_auc'], metrics_xgb['roc_auc'], metrics_lr['roc_auc']],
    'F1 Score': [metrics_baseline_nn['f1'], metrics_rf['f1'], metrics_xgb['f1'], metrics_lr['f1']],
    'Precision': [metrics_baseline_nn.get('precision', np.nan), metrics_rf['precision'], metrics_xgb['precision'], metrics_lr['precision']],
    'Recall': [metrics_baseline_nn.get('recall', np.nan), metrics_rf['recall'], metrics_xgb['recall'], metrics_lr['recall']],
    'Threshold': [best_threshold, best_threshold_rf, best_threshold_xgb, best_threshold_lr]
}

comparison_df = pd.DataFrame(comparison_data)
print("\n" + comparison_df.to_string(index=False))

# Save comparison
comparison_df.to_csv(OUTPUT_DIR / 'model_comparison.csv', index=False)
print(f"\n✓ Saved model comparison to: {OUTPUT_DIR / 'model_comparison.csv'}")

# Visualize comparison
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('Model Comparison: Neural Network vs Random Forest vs XGBoost vs Logistic Regression', 
             fontsize=16, fontweight='bold')

metrics_to_plot = ['Accuracy', 'ROC-AUC', 'F1 Score']
colors = ['steelblue', 'forestgreen', 'darkorange', 'purple']

for idx, metric in enumerate(metrics_to_plot):
    ax = axes[idx]
    x_pos = np.arange(len(comparison_df))
    bars = ax.bar(x_pos, comparison_df[metric], color=colors, alpha=0.7, edgecolor='black', linewidth=1.5)
    
    # Add value labels on bars
    for i, (bar, val) in enumerate(zip(bars, comparison_df[metric])):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f'{val:.4f}', ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    ax.set_ylabel(metric, fontsize=12, fontweight='bold')
    ax.set_title(metric, fontsize=13, fontweight='bold')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(comparison_df['Model'], rotation=15, ha='right', fontsize=10)
    ax.set_ylim([0, 1.1])
    ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved model comparison plot to: {OUTPUT_DIR / 'model_comparison.png'}")

# Compare feature importance (top features)
print("\n" + "=" * 60)
print("FEATURE IMPORTANCE COMPARISON (Top 10)")
print("=" * 60)

# Get top 10 from each (if available)
if importance_df is not None:
    top_nn_features = importance_df.head(10)['feature'].values
    print("\nTop 10 Features - Neural Network (Permutation Importance):")
    for i, feat in enumerate(top_nn_features, 1):
        print(f"  {i:2d}. {feat}")

if rf_importance_df is not None:
    top_rf_features = rf_importance_df.head(10)['feature'].values
    print("\nTop 10 Features - Random Forest (Gini Importance):")
    for i, feat in enumerate(top_rf_features, 1):
        print(f"  {i:2d}. {feat}")

if xgb_importance_df is not None:
    top_xgb_features = xgb_importance_df.head(10)['feature'].values
    print("\nTop 10 Features - XGBoost (Gain Importance):")
    for i, feat in enumerate(top_xgb_features, 1):
        print(f"  {i:2d}. {feat}")

# Find common features across models
if importance_df is not None and rf_importance_df is not None and xgb_importance_df is not None:
    common_all = set(top_nn_features) & set(top_rf_features) & set(top_xgb_features)
    common_nn_rf = set(top_nn_features) & set(top_rf_features)
    common_nn_xgb = set(top_nn_features) & set(top_xgb_features)
    common_rf_xgb = set(top_rf_features) & set(top_xgb_features)
    
    print(f"\n✓ Common features in top 10 (all 3 models): {len(common_all)}")
    if len(common_all) > 0:
        print(f"  Common (all): {', '.join(list(common_all)[:5])}{'...' if len(common_all) > 5 else ''}")
    
    print(f"\n✓ Common features (NN & RF): {len(common_nn_rf)}")
    print(f"✓ Common features (NN & XGB): {len(common_nn_xgb)}")
    print(f"✓ Common features (RF & XGB): {len(common_rf_xgb)}")

print("=" * 60)
# Out:
# ============================================================
# MODEL COMPARISON: ALL MODELS
# ============================================================
#
#                     Model  Accuracy  ROC-AUC  F1 Score  Precision   Recall  Threshold
# Neural Network (Baseline)  0.729508 0.798778  0.706667   0.727689 0.686825      0.400
#             Random Forest  0.723361 0.800938  0.705240   0.713024 0.697624      0.500
#                   XGBoost  0.709016 0.786194  0.697228   0.688421 0.706263      0.525
#       Logistic Regression  0.480533 0.667690  0.643710   0.477083 0.989201      0.200
#
# ✓ Saved model comparison to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/model_comparison.csv
# ✓ Saved model comparison plot to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/model_comparison.png
#
# ============================================================
# FEATURE IMPORTANCE COMPARISON (Top 10)
# ============================================================
#
# Top 10 Features - Neural Network (Permutation Importance):
#    1. cluster_12
#    2. cluster_4
#    3. cluster_6
#    4. cluster_11
#    5. cluster_9
#    6. cluster_14
#    7. cluster_7
#    8. cluster_13
#    9. cluster_10
#   10. cluster_2
#
# Top 10 Features - Random Forest (Gini Importance):
#    1. cluster_4
#    2. cluster_12
#    3. cluster_11
#    4. cluster_9
#    5. cluster_6
#    6. cluster_14
#    7. cluster_13
#    8. cluster_2
#    9. cluster_5
#   10. cluster_1
#
# Top 10 Features - XGBoost (Gain Importance):
#    1. cluster_4
#    2. cluster_12
#    3. cluster_11
#    4. cluster_6
#    5. cluster_7
#    6. cluster_2
#    7. cluster_9
#    8. cluster_14
#    9. cluster_8
#   10. cluster_5
#
# ✓ Common features in top 10 (all 3 models): 7
#   Common (all): cluster_2, cluster_6, cluster_11, cluster_12, cluster_9...
#
# ✓ Common features (NN & RF): 8
# ✓ Common features (NN & XGB): 8
# ✓ Common features (RF & XGB): 8
# ============================================================

# %% [markdown]
# ## 13. Summary and Notes
#
# **Note:** Advanced feature analysis and clustering (correlation-based clustering, SHAP analysis, network graphs, etc.) have been moved to a separate notebook: `Advanced_Feature_Analysis_and_Clustering.ipynb`

# %%
# ============================================================
# Save Feature Data for Feature Analysis Notebook
# ============================================================

print("=" * 60)
print("SAVING FEATURE DATA FOR FEATURE ANALYSIS NOTEBOOK")
print("=" * 60)

# Save feature data for feature analysis notebook
# Try multiple variable names that might exist
X_train_data = None
y_train_data = None

# Check for X_train (DataFrame) or X_train_rf (numpy array)
# Priority: X_train_rf (most likely to exist after Random Forest section) > X_train (DataFrame) > X_train_np_real
if 'X_train_rf' in globals():
    X_train_data = X_train_rf
    print("✓ Using X_train_rf (numpy array)")
elif 'X_train' in globals() and hasattr(X_train, 'values'):
    X_train_data = X_train.values
    print("✓ Using X_train (DataFrame)")
elif 'X_train_np_real' in globals():
    X_train_data = X_train_np_real
    print("✓ Using X_train_np_real (numpy array)")
elif 'X_train_scaled' in globals():
    # Fallback: use scaled training data if available
    if hasattr(X_train_scaled, 'values'):
        X_train_data = X_train_scaled.values
    else:
        X_train_data = X_train_scaled
    print("✓ Using X_train_scaled")
else:
    print("⚠ X_train_rf, X_train, X_train_np_real, or X_train_scaled not found")

# Check for labels
if 'y_train_rf' in globals():
    y_train_data = y_train_rf
    print("✓ Using y_train_rf")
elif 'y_train' in globals():
    y_train_data = y_train.values if hasattr(y_train, 'values') else y_train
    print("✓ Using y_train")
else:
    print("⚠ y_train_rf or y_train not found")

# Save if we have the data
if X_train_data is not None and 'feature_cols' in globals():
    X_train_df = pd.DataFrame(X_train_data, columns=feature_cols)
    X_train_df.to_csv(OUTPUT_DIR / 'X_train_features.csv', index=False)
    print(f"✓ Saved feature data to: {OUTPUT_DIR / 'X_train_features.csv'}")
    print(f"  Shape: {X_train_df.shape}")
    
    # Save feature column names
    pd.Series(feature_cols).to_csv(OUTPUT_DIR / 'feature_cols.csv', index=False)
    print(f"✓ Saved feature column names to: {OUTPUT_DIR / 'feature_cols.csv'}")
    
    # Save labels if available
    if y_train_data is not None:
        pd.DataFrame(y_train_data, columns=['label']).to_csv(OUTPUT_DIR / 'y_train_labels.csv', index=False)
        print(f"✓ Saved labels to: {OUTPUT_DIR / 'y_train_labels.csv'}")
        print(f"  Shape: {len(y_train_data)} samples")
        print(f"  Class distribution: {np.bincount(y_train_data.astype(int))}")
    else:
        print("⚠ Labels not available, skipping label save")
else:
    print("⚠ Cannot save feature data:")
    if X_train_data is None:
        print("  - Feature data (X_train/X_train_rf) not found")
    if 'feature_cols' not in globals():
        print("  - feature_cols not found")
    print("  Make sure data preprocessing cells have been run.")

print("=" * 60)

# ============================================================
# Summary
# ============================================================

print("=" * 60)
print("NOTEBOOK SUMMARY")
print("=" * 60)

print(f"\nFeature Configuration:")
if 'USE_PHENOTYPE_FEATURES' in globals():
    if USE_PHENOTYPE_FEATURES:
        print("  ✓ Using: Phenotype/Demographic features + Acoustic features")
    else:
        print("  ✓ Using: Acoustic features only")
else:
    print("  ⚠ USE_PHENOTYPE_FEATURES not defined (configuration cell may not have been run)")

print(f"\nModels Trained and Evaluated:")
print("  1. Neural Network (Baseline)")
print("  2. Random Forest")
print("  3. XGBoost")
print("  4. Logistic Regression")

print(f"\nAll models use:")
print("  - 5-fold participant-level cross-validation")
print("  - Fixed best-practice hyperparameters (no grid search)")
print("  - Threshold tuning on validation set")
print("  - Evaluation on held-out test set")

print(f"\nResults saved to: {OUTPUT_DIR}")
print("=" * 60)
# Out:
# ============================================================
# SAVING FEATURE DATA FOR FEATURE ANALYSIS NOTEBOOK
# ============================================================
# ✓ Using X_train_rf (numpy array)
# ✓ Using y_train_rf
# ✓ Saved feature data to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/X_train_features.csv
#   Shape: (3071, 14)
# ✓ Saved feature column names to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/feature_cols.csv
# ✓ Saved labels to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/y_train_labels.csv
#   Shape: 3071 samples
#   Class distribution: [1514 1557]
# ============================================================
# ============================================================
# NOTEBOOK SUMMARY
# ============================================================
#
# Feature Configuration:
#   ✓ Using: Acoustic features only
#
# Models Trained and Evaluated:
#   1. Neural Network (Baseline)
#   2. Random Forest
#   3. XGBoost
#   4. Logistic Regression
#
# All models use:
#   - 5-fold participant-level cross-validation
#   - Fixed best-practice hyperparameters (no grid search)
#   - Threshold tuning on validation set
#   - Evaluation on held-out test set
#
# Results saved to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline
# ============================================================

# %% [markdown]
# ## 14. Patient-Level Prediction from Original Features
#
# This section aggregates recording-level features to create patient-level representations and trains models to predict PD vs Control at the patient level using conventional aggregation methods.
#
# **Approach:**
# 1. Use original features (not cluster-based features)
# 2. Aggregate recording-level features across all recordings for each patient using multiple methods (mean, median, max, min, std)
# 3. Create patient-level labels (one label per patient)
# 4. Train all 4 models (Neural Network, Random Forest, XGBoost, Logistic Regression) on patient-level data
# 5. Evaluate performance at patient level
#
# This allows us to leverage all recordings from each patient while making predictions at the patient level, which is more clinically relevant.

# %%
# ============================================================
# Patient-Level Prediction: Step 1 - Aggregate Recordings to Patient Level
# ============================================================

print("=" * 80)
print("PATIENT-LEVEL PREDICTION: STEP 1 - AGGREGATE RECORDINGS TO PATIENT LEVEL")
print("=" * 80)

def aggregate_recordings_to_patient_level(X_recording_features, participant_ids, aggregation_method='mean'):
    """
    Aggregate recording-level features to patient level.
    
    Parameters:
    -----------
    X_recording_features : np.ndarray, shape (n_recordings, n_features)
        Recording-level feature matrix
    participant_ids : np.ndarray, shape (n_recordings,)
        Participant ID for each recording
    aggregation_method : str
        Method to aggregate: 'mean', 'median', 'max', 'min', 'std'
    
    Returns:
    --------
    X_patient : np.ndarray, shape (n_patients, n_features)
        Patient-level aggregated feature matrix
    patient_ids : np.ndarray, shape (n_patients,)
        Unique participant IDs (sorted)
    """
    unique_patients = np.unique(participant_ids)
    n_patients = len(unique_patients)
    n_features = X_recording_features.shape[1]
    
    X_patient = np.zeros((n_patients, n_features))
    
    for i, patient_id in enumerate(unique_patients):
        # Get all recordings for this patient
        patient_mask = participant_ids == patient_id
        patient_recordings = X_recording_features[patient_mask]
        
        # Aggregate based on method
        if aggregation_method == 'mean':
            X_patient[i] = np.mean(patient_recordings, axis=0)
        elif aggregation_method == 'median':
            X_patient[i] = np.median(patient_recordings, axis=0)
        elif aggregation_method == 'max':
            X_patient[i] = np.max(patient_recordings, axis=0)
        elif aggregation_method == 'min':
            X_patient[i] = np.min(patient_recordings, axis=0)
        elif aggregation_method == 'std':
            X_patient[i] = np.std(patient_recordings, axis=0)
        else:
            raise ValueError(f"Unknown aggregation method: {aggregation_method}")
    
    return X_patient, unique_patients

def create_patient_labels(participant_ids, recording_labels):
    """
    Create patient-level labels from recording-level labels.
    Uses majority vote (or first label if all are same).
    
    Parameters:
    -----------
    participant_ids : np.ndarray, shape (n_recordings,)
        Participant ID for each recording
    recording_labels : pd.Series or np.ndarray, shape (n_recordings,)
        Labels for each recording
    
    Returns:
    --------
    patient_labels : np.ndarray, shape (n_patients,)
        Labels for each patient (sorted by participant_id)
    unique_patient_ids : np.ndarray, shape (n_patients,)
        Unique participant IDs (sorted)
    """
    # Convert to numpy if needed
    if isinstance(recording_labels, pd.Series):
        recording_labels = recording_labels.values
    
    unique_patients = np.unique(participant_ids)
    patient_labels = np.zeros(len(unique_patients))
    
    for i, patient_id in enumerate(unique_patients):
        # Get all labels for this patient
        patient_mask = participant_ids == patient_id
        patient_recording_labels = recording_labels[patient_mask]
        
        # Use majority vote
        patient_labels[i] = int(np.round(np.mean(patient_recording_labels)))
    
    return patient_labels, unique_patients

# Define aggregation methods to try
PATIENT_AGG_METHODS = ['mean', 'median', 'max', 'min', 'std']

print(f"\nAggregation methods to try: {PATIENT_AGG_METHODS}")
print(f"\nAggregating recordings to patient level for each method...")

# Store patient-level features for each aggregation method
patient_features_dict = {}

for agg_method in PATIENT_AGG_METHODS:
    print(f"\n  Processing {agg_method} aggregation...")
    
    # Aggregate train/val/test separately
    X_train_patient, pids_train_unique = aggregate_recordings_to_patient_level(
        X_train_scaled, pid_train, aggregation_method=agg_method
    )
    X_val_patient, pids_val_unique = aggregate_recordings_to_patient_level(
        X_val_scaled, pid_val, aggregation_method=agg_method
    )
    X_test_patient, pids_test_unique = aggregate_recordings_to_patient_level(
        X_test_scaled, pid_test, aggregation_method=agg_method
    )
    
    patient_features_dict[agg_method] = {
        'X_train': X_train_patient,
        'X_val': X_val_patient,
        'X_test': X_test_patient,
        'pids_train': pids_train_unique,
        'pids_val': pids_val_unique,
        'pids_test': pids_test_unique
    }
    
    print(f"    Train: {X_train_patient.shape} ({len(pids_train_unique)} patients)")
    print(f"    Val:   {X_val_patient.shape} ({len(pids_val_unique)} patients)")
    print(f"    Test:  {X_test_patient.shape} ({len(pids_test_unique)} patients)")

# Create patient-level labels
print(f"\nCreating patient-level labels...")
y_train_patient, pids_train_check = create_patient_labels(pid_train, y_train_raw)
y_val_patient, pids_val_check = create_patient_labels(pid_val, y_val_raw)
y_test_patient, pids_test_check = create_patient_labels(pid_test, y_test_raw)

print(f"\n✓ Patient-level labels created:")
print(f"  Train: {len(y_train_patient)} patients (Control: {(y_train_patient == 0).sum()}, PD: {(y_train_patient == 1).sum()})")
print(f"  Val:   {len(y_val_patient)} patients (Control: {(y_val_patient == 0).sum()}, PD: {(y_val_patient == 1).sum()})")
print(f"  Test:  {len(y_test_patient)} patients (Control: {(y_test_patient == 0).sum()}, PD: {(y_test_patient == 1).sum()})")

print(f"\n✓ Patient-level features created for all aggregation methods")
# Out:
# ================================================================================
# PATIENT-LEVEL PREDICTION: STEP 1 - AGGREGATE RECORDINGS TO PATIENT LEVEL
# ================================================================================
#
# Aggregation methods to try: ['mean', 'median', 'max', 'min', 'std']
#
# Aggregating recordings to patient level for each method...
#
#   Processing mean aggregation...
#     Train: (80, 131) (80 patients)
#     Val:   (20, 131) (20 patients)
#     Test:  (25, 131) (25 patients)
#
#   Processing median aggregation...
#     Train: (80, 131) (80 patients)
#     Val:   (20, 131) (20 patients)
#     Test:  (25, 131) (25 patients)
#
#   Processing max aggregation...
#     Train: (80, 131) (80 patients)
#     Val:   (20, 131) (20 patients)
#     Test:  (25, 131) (25 patients)
#
#   Processing min aggregation...
#     Train: (80, 131) (80 patients)
#     Val:   (20, 131) (20 patients)
#     Test:  (25, 131) (25 patients)
#
#   Processing std aggregation...
#     Train: (80, 131) (80 patients)
#     Val:   (20, 131) (20 patients)
#     Test:  (25, 131) (25 patients)
#
# Creating patient-level labels...
#
# ✓ Patient-level labels created:
#   Train: 80 patients (Control: 41, PD: 39)
#   Val:   20 patients (Control: 10, PD: 10)
#   Test:  25 patients (Control: 13, PD: 12)
#
# ✓ Patient-level features created for all aggregation methods

# %%
# ============================================================
# Patient-Level Prediction: Step 2 - Train Models on Patient-Level Data
# ============================================================

print("=" * 80)
print("PATIENT-LEVEL PREDICTION: STEP 2 - TRAIN MODELS")
print("=" * 80)
print(f"Models: Neural Network, Random Forest, XGBoost, Logistic Regression")
print(f"Patient-level aggregation methods: {PATIENT_AGG_METHODS}")
print("=" * 80)

from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# Store all patient-level results
patient_level_results = []

# Iterate over patient-level aggregation methods
for patient_agg_method in PATIENT_AGG_METHODS:
    print(f"\n{'='*80}")
    print(f"PATIENT-LEVEL AGGREGATION METHOD: {patient_agg_method.upper()}")
    print(f"{'='*80}")
    
    # Get patient-level features for this aggregation method
    X_train_patient = patient_features_dict[patient_agg_method]['X_train']
    X_val_patient = patient_features_dict[patient_agg_method]['X_val']
    X_test_patient = patient_features_dict[patient_agg_method]['X_test']
    
    # Standardize patient-level features
    scaler_patient = StandardScaler()
    X_train_patient_scaled = scaler_patient.fit_transform(X_train_patient)
    X_val_patient_scaled = scaler_patient.transform(X_val_patient)
    X_test_patient_scaled = scaler_patient.transform(X_test_patient)
    
    # Clip extreme values for neural network
    X_train_patient_scaled = np.clip(X_train_patient_scaled, -8.0, 8.0)
    X_val_patient_scaled = np.clip(X_val_patient_scaled, -8.0, 8.0)
    X_test_patient_scaled = np.clip(X_test_patient_scaled, -8.0, 8.0)
    
    input_dim = X_train_patient_scaled.shape[1]
    print(f"\n✓ Patient-level features shape: {X_train_patient_scaled.shape[0]} patients × {input_dim} features")
    
    # ========== Neural Network ==========
    print(f"\n  Training Neural Network...")
    try:
        from torch.utils.data import TensorDataset, DataLoader
        
        # Create data loaders
        # Reshape labels to 2D [n_samples, 1] to match expected format for find_best_threshold
        train_dataset = TensorDataset(
            torch.FloatTensor(X_train_patient_scaled),
            torch.FloatTensor(y_train_patient).unsqueeze(1)
        )
        val_dataset = TensorDataset(
            torch.FloatTensor(X_val_patient_scaled),
            torch.FloatTensor(y_val_patient).unsqueeze(1)
        )
        test_dataset = TensorDataset(
            torch.FloatTensor(X_test_patient_scaled),
            torch.FloatTensor(y_test_patient).unsqueeze(1)
        )
        
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
        
        # Train model
        nn_model_patient = RegularizedHybridNet(input_dim).to(DEVICE)
        nn_model_patient, nn_history_patient, nn_best_epoch_patient = train_model_with_checkpointing(
            nn_model_patient, train_loader, val_loader, epochs=40
        )
        
        # Find best threshold
        best_threshold_nn, best_val_f1_nn = find_best_threshold(nn_model_patient, val_loader)
        
        # Evaluate on test set
        nn_metrics_patient = evaluate_on_real(nn_model_patient, test_loader, threshold=best_threshold_nn)
        
        patient_level_results.append({
            'patient_aggregation': patient_agg_method,
            'model': 'Neural Network',
            'n_features': input_dim,
            'accuracy': nn_metrics_patient['accuracy'],
            'roc_auc': nn_metrics_patient['roc_auc'],
            'f1': nn_metrics_patient['f1'],
            'precision': nn_metrics_patient.get('precision', 0),
            'recall': nn_metrics_patient.get('recall', 0)
        })
        print(f"    ✓ NN - Test Acc: {nn_metrics_patient['accuracy']:.4f}, ROC-AUC: {nn_metrics_patient['roc_auc']:.4f}, F1: {nn_metrics_patient['f1']:.4f}")
    except Exception as e:
        print(f"    ✗ NN failed: {str(e)}")
        import traceback
        traceback.print_exc()
    
    # ========== Random Forest ==========
    print(f"  Training Random Forest...")
    try:
        rf_model_patient = RandomForestClassifier(**rf_best_params)
        rf_model_patient.fit(X_train_patient_scaled, y_train_patient)
        
        # Evaluate on test set
        rf_probs = rf_model_patient.predict_proba(X_test_patient_scaled)[:, 1]
        rf_preds = (rf_probs >= 0.5).astype(int)
        
        rf_metrics_patient = {
            'accuracy': accuracy_score(y_test_patient, rf_preds),
            'roc_auc': roc_auc_score(y_test_patient, rf_probs),
            'f1': f1_score(y_test_patient, rf_preds),
            'precision': precision_score(y_test_patient, rf_preds),
            'recall': recall_score(y_test_patient, rf_preds)
        }
        
        patient_level_results.append({
            'patient_aggregation': patient_agg_method,
            'model': 'Random Forest',
            'n_features': input_dim,
            'accuracy': rf_metrics_patient['accuracy'],
            'roc_auc': rf_metrics_patient['roc_auc'],
            'f1': rf_metrics_patient['f1'],
            'precision': rf_metrics_patient['precision'],
            'recall': rf_metrics_patient['recall']
        })
        print(f"    ✓ RF - Test Acc: {rf_metrics_patient['accuracy']:.4f}, ROC-AUC: {rf_metrics_patient['roc_auc']:.4f}, F1: {rf_metrics_patient['f1']:.4f}")
    except Exception as e:
        print(f"    ✗ RF failed: {str(e)}")
    
    # ========== XGBoost ==========
    print(f"  Training XGBoost...")
    try:
        xgb_model_patient = xgb.XGBClassifier(
            **xgb_best_params,
            random_state=SEED,
            n_jobs=-1,
            eval_metric='logloss',
            use_label_encoder=False,
            tree_method='hist'
        )
        xgb_model_patient.fit(X_train_patient_scaled, y_train_patient)
        
        # Evaluate on test set
        xgb_probs = xgb_model_patient.predict_proba(X_test_patient_scaled)[:, 1]
        xgb_preds = (xgb_probs >= 0.5).astype(int)
        
        xgb_metrics_patient = {
            'accuracy': accuracy_score(y_test_patient, xgb_preds),
            'roc_auc': roc_auc_score(y_test_patient, xgb_probs),
            'f1': f1_score(y_test_patient, xgb_preds),
            'precision': precision_score(y_test_patient, xgb_preds),
            'recall': recall_score(y_test_patient, xgb_preds)
        }
        
        patient_level_results.append({
            'patient_aggregation': patient_agg_method,
            'model': 'XGBoost',
            'n_features': input_dim,
            'accuracy': xgb_metrics_patient['accuracy'],
            'roc_auc': xgb_metrics_patient['roc_auc'],
            'f1': xgb_metrics_patient['f1'],
            'precision': xgb_metrics_patient['precision'],
            'recall': xgb_metrics_patient['recall']
        })
        print(f"    ✓ XGB - Test Acc: {xgb_metrics_patient['accuracy']:.4f}, ROC-AUC: {xgb_metrics_patient['roc_auc']:.4f}, F1: {xgb_metrics_patient['f1']:.4f}")
    except Exception as e:
        print(f"    ✗ XGB failed: {str(e)}")
    
    # ========== Logistic Regression ==========
    print(f"  Training Logistic Regression...")
    try:
        lr_model_patient = LogisticRegression(**lr_best_params)
        lr_model_patient.fit(X_train_patient_scaled, y_train_patient)
        
        # Evaluate on test set
        lr_probs = lr_model_patient.predict_proba(X_test_patient_scaled)[:, 1]
        lr_preds = (lr_probs >= 0.5).astype(int)
        
        lr_metrics_patient = {
            'accuracy': accuracy_score(y_test_patient, lr_preds),
            'roc_auc': roc_auc_score(y_test_patient, lr_probs),
            'f1': f1_score(y_test_patient, lr_preds),
            'precision': precision_score(y_test_patient, lr_preds),
            'recall': recall_score(y_test_patient, lr_preds)
        }
        
        patient_level_results.append({
            'patient_aggregation': patient_agg_method,
            'model': 'Logistic Regression',
            'n_features': input_dim,
            'accuracy': lr_metrics_patient['accuracy'],
            'roc_auc': lr_metrics_patient['roc_auc'],
            'f1': lr_metrics_patient['f1'],
            'precision': lr_metrics_patient['precision'],
            'recall': lr_metrics_patient['recall']
        })
        print(f"    ✓ LR - Test Acc: {lr_metrics_patient['accuracy']:.4f}, ROC-AUC: {lr_metrics_patient['roc_auc']:.4f}, F1: {lr_metrics_patient['f1']:.4f}")
    except Exception as e:
        print(f"    ✗ LR failed: {str(e)}")

print(f"\n{'='*80}")
print("PATIENT-LEVEL TRAINING COMPLETE")
print(f"{'='*80}")
# Out:
# ================================================================================
# PATIENT-LEVEL PREDICTION: STEP 2 - TRAIN MODELS
# ================================================================================
# Models: Neural Network, Random Forest, XGBoost, Logistic Regression
# Patient-level aggregation methods: ['mean', 'median', 'max', 'min', 'std']
# ================================================================================
#
# ================================================================================
# PATIENT-LEVEL AGGREGATION METHOD: MEAN
# ================================================================================
#
# ✓ Patient-level features shape: 80 patients × 131 features
#
#   Training Neural Network...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7034, val_loss=0.6942, train_acc=0.512, val_acc=0.500, val_roc_auc=0.3400
# Epoch  10/40: train_loss=0.5206, val_loss=0.4795, train_acc=0.787, val_acc=0.800, val_roc_auc=0.8700
# Epoch  20/40: train_loss=0.3749, val_loss=0.3202, train_acc=0.988, val_acc=0.800, val_roc_auc=0.9500
#
# ⏹ Early stopping at epoch 25. Best epoch: 19 (AUC 0.9600)
#
# ✓ Loaded best model from epoch 19 (Val ROC-AUC: 0.9600)
#     ✓ NN - Test Acc: 0.8400, ROC-AUC: 0.9231, F1: 0.8333
#   Training Random Forest...
#     ✓ RF - Test Acc: 0.8800, ROC-AUC: 0.9423, F1: 0.8800
#   Training XGBoost...
#     ✓ XGB - Test Acc: 0.8400, ROC-AUC: 0.9551, F1: 0.8571
#   Training Logistic Regression...
#     ✓ LR - Test Acc: 0.8800, ROC-AUC: 0.9167, F1: 0.8800
#
# ================================================================================
# PATIENT-LEVEL AGGREGATION METHOD: MEDIAN
# ================================================================================
#
# ✓ Patient-level features shape: 80 patients × 131 features
#
#   Training Neural Network...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7089, val_loss=0.6920, train_acc=0.463, val_acc=0.450, val_roc_auc=0.8400
# Epoch  10/40: train_loss=0.4733, val_loss=0.5077, train_acc=0.900, val_acc=0.850, val_roc_auc=0.8700
#
# ⏹ Early stopping at epoch 11. Best epoch: 5 (AUC 0.8800)
#
# ✓ Loaded best model from epoch 5 (Val ROC-AUC: 0.8800)
#     ✓ NN - Test Acc: 0.8400, ROC-AUC: 0.9231, F1: 0.8571
#   Training Random Forest...
#     ✓ RF - Test Acc: 0.8400, ROC-AUC: 0.9487, F1: 0.8571
#   Training XGBoost...
#     ✓ XGB - Test Acc: 0.8800, ROC-AUC: 0.9359, F1: 0.8889
#   Training Logistic Regression...
#     ✓ LR - Test Acc: 0.9200, ROC-AUC: 0.9487, F1: 0.9231
#
# ================================================================================
# PATIENT-LEVEL AGGREGATION METHOD: MAX
# ================================================================================
#
# ✓ Patient-level features shape: 80 patients × 131 features
#
#   Training Neural Network...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7339, val_loss=0.6935, train_acc=0.450, val_acc=0.500, val_roc_auc=0.4700
# Epoch  10/40: train_loss=0.4983, val_loss=0.5709, train_acc=0.925, val_acc=0.650, val_roc_auc=0.7400
#
# ⏹ Early stopping at epoch 15. Best epoch: 9 (AUC 0.7600)
#
# ✓ Loaded best model from epoch 9 (Val ROC-AUC: 0.7600)
#     ✓ NN - Test Acc: 0.4400, ROC-AUC: 0.8077, F1: 0.6111
#   Training Random Forest...
#     ✓ RF - Test Acc: 0.7200, ROC-AUC: 0.8397, F1: 0.7407
#   Training XGBoost...
#     ✓ XGB - Test Acc: 0.7600, ROC-AUC: 0.8333, F1: 0.7500
#   Training Logistic Regression...
#     ✓ LR - Test Acc: 0.7600, ROC-AUC: 0.8846, F1: 0.7857
#
# ================================================================================
# PATIENT-LEVEL AGGREGATION METHOD: MIN
# ================================================================================
#
# ✓ Patient-level features shape: 80 patients × 131 features
#
#   Training Neural Network...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.7040, val_loss=0.6934, train_acc=0.525, val_acc=0.500, val_roc_auc=0.4100
# Epoch  10/40: train_loss=0.5610, val_loss=0.5981, train_acc=0.775, val_acc=0.700, val_roc_auc=0.8000
# Epoch  20/40: train_loss=0.3785, val_loss=0.4217, train_acc=0.963, val_acc=0.800, val_roc_auc=0.8900
#
# ⏹ Early stopping at epoch 30. Best epoch: 24 (AUC 0.9100)
#
# ✓ Loaded best model from epoch 24 (Val ROC-AUC: 0.9100)
#     ✓ NN - Test Acc: 0.7200, ROC-AUC: 0.7692, F1: 0.7407
#   Training Random Forest...
#     ✓ RF - Test Acc: 0.6800, ROC-AUC: 0.7628, F1: 0.6923
#   Training XGBoost...
#     ✓ XGB - Test Acc: 0.6000, ROC-AUC: 0.7564, F1: 0.6429
#   Training Logistic Regression...
#     ✓ LR - Test Acc: 0.6400, ROC-AUC: 0.7885, F1: 0.6667
#
# ================================================================================
# PATIENT-LEVEL AGGREGATION METHOD: STD
# ================================================================================
#
# ✓ Patient-level features shape: 80 patients × 131 features
#
#   Training Neural Network...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.6940, val_loss=0.6934, train_acc=0.512, val_acc=0.500, val_roc_auc=0.5200
# Epoch  10/40: train_loss=0.4469, val_loss=0.4948, train_acc=0.938, val_acc=0.800, val_roc_auc=0.8600
# Epoch  20/40: train_loss=0.3512, val_loss=0.4680, train_acc=1.000, val_acc=0.850, val_roc_auc=0.8500
#
# ⏹ Early stopping at epoch 23. Best epoch: 17 (AUC 0.9000)
#
# ✓ Loaded best model from epoch 17 (Val ROC-AUC: 0.9000)
#     ✓ NN - Test Acc: 0.8000, ROC-AUC: 0.9231, F1: 0.8148
#   Training Random Forest...
#     ✓ RF - Test Acc: 0.7200, ROC-AUC: 0.8333, F1: 0.7407
#   Training XGBoost...
#     ✓ XGB - Test Acc: 0.6800, ROC-AUC: 0.8269, F1: 0.6667
#   Training Logistic Regression...
#     ✓ LR - Test Acc: 0.8000, ROC-AUC: 0.8910, F1: 0.8148
#
# ================================================================================
# PATIENT-LEVEL TRAINING COMPLETE
# ================================================================================

# %%
# ============================================================
# Patient-Level Prediction: Step 3 - Summarize and Save Results
# ============================================================

print("=" * 80)
print("PATIENT-LEVEL PREDICTION: STEP 3 - RESULTS SUMMARY")
print("=" * 80)

# Convert results to DataFrame
patient_level_df = pd.DataFrame(patient_level_results)

if len(patient_level_df) > 0:
    print("\n" + "=" * 80)
    print("PATIENT-LEVEL PREDICTION RESULTS")
    print("=" * 80)
    print(patient_level_df.to_string(index=False))
    print("=" * 80)
    
    # Find best configuration for each model
    print("\n" + "=" * 80)
    print("BEST CONFIGURATION FOR EACH MODEL (Patient-Level)")
    print("=" * 80)
    
    best_patient_results = []
    for model_name in patient_level_df['model'].unique():
        model_results = patient_level_df[patient_level_df['model'] == model_name]
        best_idx = model_results['roc_auc'].idxmax()
        best = model_results.loc[best_idx]
        
        best_patient_results.append({
            'Model': model_name,
            'Best Patient Aggregation': best['patient_aggregation'],
            'ROC-AUC': f"{best['roc_auc']:.4f}",
            'Accuracy': f"{best['accuracy']:.4f}",
            'F1 Score': f"{best['f1']:.4f}",
            'Precision': f"{best['precision']:.4f}",
            'Recall': f"{best['recall']:.4f}",
            'N Features': int(best['n_features'])
        })
    
    best_patient_df = pd.DataFrame(best_patient_results)
    print(best_patient_df.to_string(index=False))
    print("=" * 80)
    
    # Save results
    patient_level_df.to_csv(OUTPUT_DIR / 'patient_level_results.csv', index=False)
    best_patient_df.to_csv(OUTPUT_DIR / 'patient_level_best_configurations.csv', index=False)
    
    print(f"\n✓ Saved patient-level results to: {OUTPUT_DIR / 'patient_level_results.csv'}")
    print(f"✓ Saved best configurations to: {OUTPUT_DIR / 'patient_level_best_configurations.csv'}")
    
    # Summary statistics
    print(f"\n" + "=" * 80)
    print("SUMMARY STATISTICS")
    print("=" * 80)
    print(f"Total configurations tested: {len(patient_level_df)}")
    print(f"  - Models: {len(patient_level_df['model'].unique())}")
    print(f"  - Patient aggregation methods: {len(patient_level_df['patient_aggregation'].unique())}")
    print(f"\nBest overall ROC-AUC: {patient_level_df['roc_auc'].max():.4f}")
    best_overall_idx = patient_level_df['roc_auc'].idxmax()
    best_overall = patient_level_df.loc[best_overall_idx]
    print(f"  Model: {best_overall['model']}")
    print(f"  Patient Aggregation: {best_overall['patient_aggregation']}")
    print(f"  Accuracy: {best_overall['accuracy']:.4f}")
    print(f"  F1 Score: {best_overall['f1']:.4f}")
else:
    print("\n⚠ No results to display. Training may have failed.")

print("\n" + "=" * 80)
print("PATIENT-LEVEL PREDICTION ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# PATIENT-LEVEL PREDICTION: STEP 3 - RESULTS SUMMARY
# ================================================================================
#
# ================================================================================
# PATIENT-LEVEL PREDICTION RESULTS
# ================================================================================
# patient_aggregation               model  n_features  accuracy  roc_auc       f1  precision   recall
#                mean      Neural Network         131      0.84 0.923077 0.833333   0.833333 0.833333
#                mean       Random Forest         131      0.88 0.942308 0.880000   0.846154 0.916667
#                mean             XGBoost         131      0.84 0.955128 0.857143   0.750000 1.000000
#                mean Logistic Regression         131      0.88 0.916667 0.880000   0.846154 0.916667
#              median      Neural Network         131      0.84 0.923077 0.857143   0.750000 1.000000
#              median       Random Forest         131      0.84 0.948718 0.857143   0.750000 1.000000
#              median             XGBoost         131      0.88 0.935897 0.888889   0.800000 1.000000
#              median Logistic Regression         131      0.92 0.948718 0.923077   0.857143 1.000000
#                 max      Neural Network         131      0.44 0.807692 0.611111   0.458333 0.916667
#                 max       Random Forest         131      0.72 0.839744 0.740741   0.666667 0.833333
#                 max             XGBoost         131      0.76 0.833333 0.750000   0.750000 0.750000
#                 max Logistic Regression         131      0.76 0.884615 0.785714   0.687500 0.916667
#                 min      Neural Network         131      0.72 0.769231 0.740741   0.666667 0.833333
#                 min       Random Forest         131      0.68 0.762821 0.692308   0.642857 0.750000
#                 min             XGBoost         131      0.60 0.756410 0.642857   0.562500 0.750000
#                 min Logistic Regression         131      0.64 0.788462 0.666667   0.600000 0.750000
#                 std      Neural Network         131      0.80 0.923077 0.814815   0.733333 0.916667
#                 std       Random Forest         131      0.72 0.833333 0.740741   0.666667 0.833333
#                 std             XGBoost         131      0.68 0.826923 0.666667   0.666667 0.666667
#                 std Logistic Regression         131      0.80 0.891026 0.814815   0.733333 0.916667
# ================================================================================
#
# ================================================================================
# BEST CONFIGURATION FOR EACH MODEL (Patient-Level)
# ================================================================================
#               Model Best Patient Aggregation ROC-AUC Accuracy F1 Score Precision Recall  N Features
#      Neural Network                     mean  0.9231   0.8400   0.8333    0.8333 0.8333         131
#       Random Forest                   median  0.9487   0.8400   0.8571    0.7500 1.0000         131
#             XGBoost                     mean  0.9551   0.8400   0.8571    0.7500 1.0000         131
# Logistic Regression                   median  0.9487   0.9200   0.9231    0.8571 1.0000         131
# ================================================================================
#
# ✓ Saved patient-level results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/patient_level_results.csv
# ✓ Saved best configurations to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/patient_level_best_configurations.csv
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Total configurations tested: 20
#   - Models: 4
#   - Patient aggregation methods: 5
#
# Best overall ROC-AUC: 0.9551
#   Model: XGBoost
#   Patient Aggregation: mean
#   Accuracy: 0.8400
#   F1 Score: 0.8571
#
# ================================================================================
# PATIENT-LEVEL PREDICTION ANALYSIS COMPLETE
# ================================================================================

# %%
# ============================================================
# Visualization: Patient-Level Results by Aggregation Method
# ============================================================

if len(patient_level_df) > 0:
    metrics = ['accuracy', 'roc_auc', 'f1']
    metric_labels = ['Accuracy', 'ROC-AUC', 'F1 Score']
    models = ['Neural Network', 'Random Forest', 'XGBoost', 'Logistic Regression']
    colors = {'mean': 'blue', 'median': 'green', 'max': 'red', 'min': 'purple', 'std': 'orange'}
    
    # Create figure with 3 subplots (one for each metric)
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle('Patient-Level Performance: Metrics by Model and Aggregation Method', fontsize=16, fontweight='bold')
    
    # X-axis positions for models
    x_positions = np.arange(len(models))
    
    # Iterate over metrics
    for metric_idx, (metric, metric_label) in enumerate(zip(metrics, metric_labels)):
        ax = axes[metric_idx]
        
        # Plot a line for each aggregation method
        for agg_method in PATIENT_AGG_METHODS:
            agg_values = []
            for model_name in models:
                model_results = patient_level_df[patient_level_df['model'] == model_name]
                agg_results = model_results[model_results['patient_aggregation'] == agg_method]
                if len(agg_results) > 0:
                    agg_values.append(agg_results[metric].values[0])
                else:
                    agg_values.append(np.nan)
            
            # Plot line connecting all models for this aggregation method
            valid_mask = ~np.isnan(agg_values)
            if valid_mask.any():
                ax.plot(x_positions[valid_mask], np.array(agg_values)[valid_mask], 
                       marker='o', color=colors[agg_method], label=agg_method,
                       linewidth=2, markersize=8, zorder=5)
                
                # Add value labels on points
                for i, val in enumerate(agg_values):
                    if not np.isnan(val):
                        ax.text(i, val + 0.02, f'{val:.3f}', 
                               ha='center', va='bottom', fontsize=8, fontweight='bold')
        
        ax.set_xticks(x_positions)
        ax.set_xticklabels(models, fontsize=10, rotation=45, ha='right')
        ax.set_ylabel(metric_label, fontsize=12)
        ax.set_title(metric_label, fontsize=13, fontweight='bold')
        ax.grid(True, alpha=0.3, axis='y')
        ax.set_ylim([0, 1.05])
        ax.legend(loc='best', fontsize=9, ncol=1)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig(OUTPUT_DIR / 'patient_level_metrics_line_charts.png', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"✓ Saved line chart visualization to: {OUTPUT_DIR / 'patient_level_metrics_line_charts.png'}")
else:
    print("⚠ No results to visualize. Please run the training cell first.")
# Out:
# ✓ Saved line chart visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/patient_level_metrics_line_charts.png

# %% [markdown]
# ### 11.0. Prepare DataLoaders for Synthetic Training
#
# **Note: We use the same training functions (`train_model_with_checkpointing` for NN and direct sklearn `.fit()` for others) as used for real data.**

# %% [markdown]
# ## 11. Train Models on VAE Synthetic Data (Per-Class)
#
# **This section:**
# 1. Loads per-class VAE synthetic data
# 2. Trains all 4 models on full synthetic data
# 3. Validates and tests on real data (50/50 split of val+test)

# %%
# ============================================================
# Load Per-Class VAE Synthetic Data
# ============================================================

print("=" * 60)
print("LOADING PER-CLASS VAE SYNTHETIC DATA")
print("=" * 60)

# Path to VAE synthetic data (from VAE_Synthetic_Data_Generation notebook)
VAE_SYNTHETIC_FILE = ROOT / 'outputs' / 'vae_standalone' / 'synthetic_vae_data.csv'

if not VAE_SYNTHETIC_FILE.exists():
    raise FileNotFoundError(
        f"VAE synthetic data file not found: {VAE_SYNTHETIC_FILE}\n"
        f"Please run the VAE_Synthetic_Data_Generation_Standalone_v2 notebook first."
    )

# Load synthetic data
syn_df = pd.read_csv(VAE_SYNTHETIC_FILE)
print(f"✓ Loaded synthetic data: {syn_df.shape}")

# Check if it has a 'label' column
if 'label' not in syn_df.columns:
    # If no label column, assume it's structured like the VAE notebook output
    # The VAE notebook saves synthetic data with features only, labels are implicit
    # We need to reconstruct labels based on the generation process
    # For per-class VAE: first half is Control (0), second half is PD (1)
    n_samples = len(syn_df)
    n_ctrl = n_samples // 2
    syn_df['label'] = [0] * n_ctrl + [1] * (n_samples - n_ctrl)
    print(f"  ⚠ No label column found. Assumed structure: {n_ctrl} Control, {n_samples - n_ctrl} PD")

# Extract features and labels
syn_feature_cols = [col for col in syn_df.columns if col != 'label']
X_syn = syn_df[syn_feature_cols].values
y_syn = syn_df['label'].values

print(f"\n✓ Synthetic data prepared:")
print(f"  Features: {X_syn.shape}")
print(f"  Labels: {np.bincount(y_syn.astype(int))} (Control: {(y_syn == 0).sum()}, PD: {(y_syn == 1).sum()})")

# IMPORTANT: Aggregate synthetic features using the same cluster mapping
print("\n" + "=" * 60)
print("AGGREGATING SYNTHETIC FEATURES BY CLUSTER")
print("=" * 60)

# Check if feature columns match
if set(syn_feature_cols) != set(original_feature_cols):
    print(f"  ⚠ Feature column mismatch. Synthetic has {len(syn_feature_cols)}, expected {len(original_feature_cols)}")
    # Use intersection
    common_features = list(set(syn_feature_cols) & set(original_feature_cols))
    print(f"  Using {len(common_features)} common features")
    X_syn = syn_df[common_features].values
    syn_feature_cols = common_features

# Aggregate synthetic features using the same cluster mapping
X_syn_agg, _ = aggregate_features_by_cluster(
    X_syn, syn_feature_cols, cluster_to_features, aggregation='mean'
)

print(f"✓ Synthetic features aggregated: {X_syn.shape[1]} → {X_syn_agg.shape[1]}")

# Standardize synthetic data using the AGGREGATED scaler (fitted on aggregated real data)
print("\n" + "=" * 60)
print("STANDARDIZING SYNTHETIC DATA")
print("=" * 60)

# Check if global_scaler_agg exists, if not create it from aggregated training data
if 'global_scaler_agg' not in globals():
    print("  ⚠ global_scaler_agg not found. Creating from aggregated training data...")
    
    # Try to get the raw aggregated training data
    if 'X_train_agg' in globals():
        # Fit scaler on aggregated training data (before scaling)
        global_scaler_agg = StandardScaler()
        global_scaler_agg.fit(X_train_agg.astype(np.float32))
        print("  ✓ Created global_scaler_agg from X_train_agg")
    elif 'X_train' in globals() and hasattr(X_train, 'values'):
        # X_train is already aggregated and scaled, we need to recreate aggregation
        # This is a fallback - ideally X_train_agg should exist
        print("  ⚠ X_train_agg not found. Attempting to recreate from X_train_raw...")
        if 'X_train_raw' in globals() and 'cluster_to_features' in globals() and 'original_feature_cols' in globals():
            # Re-aggregate training data
            X_train_agg_recreated, _ = aggregate_features_by_cluster(
                X_train_raw.values, original_feature_cols, cluster_to_features, aggregation='mean'
            )
            global_scaler_agg = StandardScaler()
            global_scaler_agg.fit(X_train_agg_recreated.astype(np.float32))
            print("  ✓ Created global_scaler_agg from re-aggregated training data")
        else:
            raise NameError(
                "Cannot create global_scaler_agg. Missing required variables.\n"
                "Please run the data preprocessing cell (Cell 10) first."
            )
    else:
        raise NameError(
            "global_scaler_agg not found and cannot be recreated.\n"
            "Please run the data preprocessing cell (Cell 10) first."
        )

X_syn_scaled = global_scaler_agg.transform(X_syn_agg.astype(np.float32))
X_syn_scaled = np.clip(X_syn_scaled, -8.0, 8.0)

# Convert to DataFrame
X_syn_df = pd.DataFrame(X_syn_scaled, columns=agg_feature_names)

print(f"✓ Synthetic data standardized and ready for training")
print(f"  Shape: {X_syn_df.shape}")
print("=" * 60)
# Out:
# ============================================================
# LOADING PER-CLASS VAE SYNTHETIC DATA
# ============================================================
# ✓ Loaded synthetic data: (61420, 133)
#   ⚠ No label column found. Assumed structure: 30710 Control, 30710 PD
#
# ✓ Synthetic data prepared:
#   Features: (61420, 133)
#   Labels: [30710 30710] (Control: 30710, PD: 30710)
#
# ============================================================
# AGGREGATING SYNTHETIC FEATURES BY CLUSTER
# ============================================================
#   ⚠ Feature column mismatch. Synthetic has 133, expected 131
#   Using 131 common features
# ✓ Synthetic features aggregated: 131 → 14
#
# ============================================================
# STANDARDIZING SYNTHETIC DATA
# ============================================================
# ✓ Synthetic data standardized and ready for training
#   Shape: (61420, 14)
# ============================================================

# %%
# ============================================================
# Prepare DataLoaders for Synthetic Data Training
# ============================================================
# We use the SAME training functions as for real data:
# - train_model_with_checkpointing() for Neural Network
# - Direct sklearn .fit() for Random Forest, XGBoost, Logistic Regression
# - evaluate_on_real() for evaluation

print("=" * 60)
print("PREPARING DATALOADERS FOR SYNTHETIC DATA")
print("=" * 60)

# Create DataLoaders for Neural Network training (same format as real data)
from torch.utils.data import TensorDataset, DataLoader

# Synthetic training data
train_dataset_syn = TensorDataset(
    torch.FloatTensor(X_syn_df.values),
    torch.FloatTensor(y_syn.reshape(-1, 1))
)
train_loader_syn = DataLoader(train_dataset_syn, batch_size=32, shuffle=True)

# Real validation data (for NN training validation)
val_dataset_real = TensorDataset(
    torch.FloatTensor(X_val_real),
    torch.FloatTensor(y_val_real.reshape(-1, 1))
)
val_loader_real = DataLoader(val_dataset_real, batch_size=32, shuffle=False)

# Real test data (for final evaluation)
test_dataset_real = TensorDataset(
    torch.FloatTensor(X_test_real),
    torch.FloatTensor(y_test_real.reshape(-1, 1))
)
test_loader_real = DataLoader(test_dataset_real, batch_size=32, shuffle=False)

print(f"✓ Synthetic training DataLoader: {len(train_loader_syn)} batches")
print(f"✓ Real validation DataLoader: {len(val_loader_real)} batches")
print(f"✓ Real test DataLoader: {len(test_loader_real)} batches")
print("=" * 60)
# Out:
# ============================================================
# PREPARING DATALOADERS FOR SYNTHETIC DATA
# ============================================================
# ✓ Synthetic training DataLoader: 1920 batches
# ✓ Real validation DataLoader: 28 batches
# ✓ Real test DataLoader: 29 batches
# ============================================================

# %%
# ============================================================
# Prepare Real Data for Validation and Testing (50/50 split at PARTICIPANT LEVEL)
# ============================================================

print("=" * 60)
print("PREPARING REAL DATA FOR VALIDATION AND TESTING (50/50 - PARTICIPANT LEVEL)")
print("=" * 60)

# Combine val and test sets
X_val_test = pd.concat([X_val, X_test], axis=0)
y_val_test = pd.concat([y_val_raw, y_test_raw], axis=0)

# Get participant IDs for combined val+test data
pid_val_test = np.hstack([pid_val, pid_test])

print(f"Combined real data: {len(X_val_test)} samples")
print(f"  Unique participants: {len(np.unique(pid_val_test))}")
print(f"  Labels: {np.bincount(y_val_test.values.astype(int))}")

# Participant-level split (50/50) to prevent leakage
from sklearn.model_selection import train_test_split

# Get unique participants and their labels
unique_pids = np.unique(pid_val_test)
participant_labels_dict = {}
for pid in unique_pids:
    # Get label for this participant (use first occurrence)
    pid_mask = pid_val_test == pid
    participant_labels_dict[pid] = y_val_test.values[pid_mask][0]

participant_labels_array = np.array([participant_labels_dict[pid] for pid in unique_pids])

# Split at participant level (50/50)
pids_val_real, pids_test_real, y_p_val_real, y_p_test_real = train_test_split(
    unique_pids,
    participant_labels_array,
    test_size=0.5,
    random_state=SEED,
    stratify=participant_labels_array
)

# Map participant splits to recording level
val_mask_real = np.isin(pid_val_test, pids_val_real)
test_mask_real = np.isin(pid_val_test, pids_test_real)

X_val_real = X_val_test.values[val_mask_real]
X_test_real = X_val_test.values[test_mask_real]
y_val_real = y_val_test.values[val_mask_real]
y_test_real = y_val_test.values[test_mask_real]

# Store participant IDs for later use
pid_val_real = pid_val_test[val_mask_real]
pid_test_real = pid_val_test[test_mask_real]

print(f"\n✓ Participant-level splits (no leakage):")
print(f"  Validation: {len(X_val_real)} samples from {len(np.unique(pid_val_real))} participants")
print(f"    Labels: {np.bincount(y_val_real.astype(int))}")
print(f"  Test: {len(X_test_real)} samples from {len(np.unique(pid_test_real))} participants")
print(f"    Labels: {np.bincount(y_test_real.astype(int))}")

# Verify no participant overlap
assert len(set(pid_val_real) & set(pid_test_real)) == 0, "Val-Test participant overlap detected!"
print("\n✓ Verified: No participant overlap between validation and test sets")
print("=" * 60)
# Out:
# ============================================================
# PREPARING REAL DATA FOR VALIDATION AND TESTING (50/50 - PARTICIPANT LEVEL)
# ============================================================
# Combined real data: 1808 samples
#   Unique participants: 45
#   Labels: [924 884]
#
# ✓ Participant-level splits (no leakage):
#   Validation: 889 samples from 22 participants
#     Labels: [462 427]
#   Test: 919 samples from 23 participants
#     Labels: [462 457]
#
# ✓ Verified: No participant overlap between validation and test sets
# ============================================================

# %% [markdown]
# ### 11.1. Neural Network: Train on Synthetic, Evaluate on Real

# %%
# ============================================================
# Neural Network: Train on Synthetic Data, Evaluate on Real
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: TRAIN ON SYNTHETIC, EVALUATE ON REAL")
print("=" * 60)

# Create model (same architecture as used for real data)
model_nn_syn = RegularizedHybridNet(input_dim=feature_dim).to(DEVICE)

# Train on synthetic data using the SAME function as real data
print("\nTraining on synthetic data...")
model_nn_syn, history_nn_syn, best_epoch_nn_syn = train_model_with_checkpointing(
    model_nn_syn,
    train_loader=train_loader_syn,
    val_loader=val_loader_real,
    epochs=40,  # Same as used in CV
    lr=6e-4,
    weight_decay=8e-3
)

# Evaluate on real validation and test sets using the SAME function
print("\nEvaluating on real validation set...")
val_metrics_nn_syn = evaluate_on_real(model_nn_syn, val_loader_real, threshold=0.5)

print("\nEvaluating on real test set...")
test_metrics_nn_syn = evaluate_on_real(model_nn_syn, test_loader_real, threshold=0.5)

print("\n" + "=" * 60)
print("NEURAL NETWORK RESULTS (Trained on Synthetic)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_nn_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_nn_syn['roc_auc']:.4f}, F1: {val_metrics_nn_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_nn_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_nn_syn['roc_auc']:.4f}, F1: {test_metrics_nn_syn['f1']:.4f}")
print("=" * 60)

# Save results
nn_syn_results = {
    'model': 'Neural Network',
    'training_data': 'Synthetic (VAE per-class)',
    'val_acc': val_metrics_nn_syn['accuracy'],
    'val_roc_auc': val_metrics_nn_syn['roc_auc'],
    'val_f1': val_metrics_nn_syn['f1'],
    'test_acc': test_metrics_nn_syn['accuracy'],
    'test_roc_auc': test_metrics_nn_syn['roc_auc'],
    'test_f1': test_metrics_nn_syn['f1']
}
pd.DataFrame([nn_syn_results]).to_csv(OUTPUT_DIR / 'nn_synthetic_training_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'nn_synthetic_training_results.csv'}")
# Out:
# ============================================================
# NEURAL NETWORK: TRAIN ON SYNTHETIC, EVALUATE ON REAL
# ============================================================
#
# Training on synthetic data...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.4568, val_loss=1.1180, train_acc=0.900, val_acc=0.571, val_roc_auc=0.5489
# Epoch  10/40: train_loss=0.3469, val_loss=0.7883, train_acc=0.992, val_acc=0.585, val_roc_auc=0.5989
#
# ⏹ Early stopping at epoch 11. Best epoch: 5 (AUC 0.6015)
#
# ✓ Loaded best model from epoch 5 (Val ROC-AUC: 0.6015)
#
# Evaluating on real validation set...
#
# Evaluating on real test set...
#
# ============================================================
# NEURAL NETWORK RESULTS (Trained on Synthetic)
# ============================================================
# Validation - Acc: 0.5591, ROC-AUC: 0.6015, F1: 0.5231
# Test       - Acc: 0.6039, ROC-AUC: 0.6503, F1: 0.5687
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/nn_synthetic_training_results.csv

# %% [markdown]
# ### 11.2. Random Forest: Train on Synthetic, Evaluate on Real

# %%
# ============================================================
# Random Forest: Train on Synthetic Data, Evaluate on Real
# ============================================================

print("=" * 60)
print("RANDOM FOREST: TRAIN ON SYNTHETIC, EVALUATE ON REAL")
print("=" * 60)

# Train on synthetic data using the SAME parameters as real data
print("\nTraining on synthetic data...")
from sklearn.ensemble import RandomForestClassifier

model_rf_syn = RandomForestClassifier(**rf_best_params)
model_rf_syn.fit(X_syn_df.values, y_syn)

# Evaluate on real validation and test sets
print("\nEvaluating on real validation set...")
val_probs_rf_syn = model_rf_syn.predict_proba(X_val_real)[:, 1]
val_preds_rf_syn = (val_probs_rf_syn >= 0.5).astype(int)
val_metrics_rf_syn = {
    'accuracy': accuracy_score(y_val_real, val_preds_rf_syn),
    'roc_auc': roc_auc_score(y_val_real, val_probs_rf_syn),
    'f1': f1_score(y_val_real, val_preds_rf_syn, zero_division=0),
    'precision': precision_score(y_val_real, val_preds_rf_syn, zero_division=0),
    'recall': recall_score(y_val_real, val_preds_rf_syn, zero_division=0)
}

print("\nEvaluating on real test set...")
test_probs_rf_syn = model_rf_syn.predict_proba(X_test_real)[:, 1]
test_preds_rf_syn = (test_probs_rf_syn >= 0.5).astype(int)
test_metrics_rf_syn = {
    'accuracy': accuracy_score(y_test_real, test_preds_rf_syn),
    'roc_auc': roc_auc_score(y_test_real, test_probs_rf_syn),
    'f1': f1_score(y_test_real, test_preds_rf_syn, zero_division=0),
    'precision': precision_score(y_test_real, test_preds_rf_syn, zero_division=0),
    'recall': recall_score(y_test_real, test_preds_rf_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("RANDOM FOREST RESULTS (Trained on Synthetic)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_rf_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_rf_syn['roc_auc']:.4f}, F1: {val_metrics_rf_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_rf_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_rf_syn['roc_auc']:.4f}, F1: {test_metrics_rf_syn['f1']:.4f}")
print("=" * 60)

# Save results
rf_syn_results = {
    'model': 'Random Forest',
    'training_data': 'Synthetic (VAE per-class)',
    'val_acc': val_metrics_rf_syn['accuracy'],
    'val_roc_auc': val_metrics_rf_syn['roc_auc'],
    'val_f1': val_metrics_rf_syn['f1'],
    'test_acc': test_metrics_rf_syn['accuracy'],
    'test_roc_auc': test_metrics_rf_syn['roc_auc'],
    'test_f1': test_metrics_rf_syn['f1']
}
pd.DataFrame([rf_syn_results]).to_csv(OUTPUT_DIR / 'rf_synthetic_training_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'rf_synthetic_training_results.csv'}")
# Out:
# ============================================================
# RANDOM FOREST: TRAIN ON SYNTHETIC, EVALUATE ON REAL
# ============================================================
#
# Training on synthetic data...
#
# Evaluating on real validation set...
#
# Evaluating on real test set...
#
# ============================================================
# RANDOM FOREST RESULTS (Trained on Synthetic)
# ============================================================
# Validation - Acc: 0.5917, ROC-AUC: 0.6524, F1: 0.3795
# Test       - Acc: 0.6235, ROC-AUC: 0.7212, F1: 0.4773
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_synthetic_training_results.csv

# %% [markdown]
# ### 11.3. XGBoost: Train on Synthetic, Evaluate on Real

# %%
# ============================================================
# XGBoost: Train on Synthetic Data, Evaluate on Real
# ============================================================

print("=" * 60)
print("XGBOOST: TRAIN ON SYNTHETIC, EVALUATE ON REAL")
print("=" * 60)

# Train on synthetic data using the SAME parameters as real data
print("\nTraining on synthetic data...")
import xgboost as xgb

model_xgb_syn = xgb.XGBClassifier(**xgb_best_params)
model_xgb_syn.fit(X_syn_df.values, y_syn)

# Evaluate on real validation and test sets
print("\nEvaluating on real validation set...")
val_probs_xgb_syn = model_xgb_syn.predict_proba(X_val_real)[:, 1]
val_preds_xgb_syn = (val_probs_xgb_syn >= 0.5).astype(int)
val_metrics_xgb_syn = {
    'accuracy': accuracy_score(y_val_real, val_preds_xgb_syn),
    'roc_auc': roc_auc_score(y_val_real, val_probs_xgb_syn),
    'f1': f1_score(y_val_real, val_preds_xgb_syn, zero_division=0),
    'precision': precision_score(y_val_real, val_preds_xgb_syn, zero_division=0),
    'recall': recall_score(y_val_real, val_preds_xgb_syn, zero_division=0)
}

print("\nEvaluating on real test set...")
test_probs_xgb_syn = model_xgb_syn.predict_proba(X_test_real)[:, 1]
test_preds_xgb_syn = (test_probs_xgb_syn >= 0.5).astype(int)
test_metrics_xgb_syn = {
    'accuracy': accuracy_score(y_test_real, test_preds_xgb_syn),
    'roc_auc': roc_auc_score(y_test_real, test_probs_xgb_syn),
    'f1': f1_score(y_test_real, test_preds_xgb_syn, zero_division=0),
    'precision': precision_score(y_test_real, test_preds_xgb_syn, zero_division=0),
    'recall': recall_score(y_test_real, test_preds_xgb_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("XGBOOST RESULTS (Trained on Synthetic)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_xgb_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_xgb_syn['roc_auc']:.4f}, F1: {val_metrics_xgb_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_xgb_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_xgb_syn['roc_auc']:.4f}, F1: {test_metrics_xgb_syn['f1']:.4f}")
print("=" * 60)

# Save results
xgb_syn_results = {
    'model': 'XGBoost',
    'training_data': 'Synthetic (VAE per-class)',
    'val_acc': val_metrics_xgb_syn['accuracy'],
    'val_roc_auc': val_metrics_xgb_syn['roc_auc'],
    'val_f1': val_metrics_xgb_syn['f1'],
    'test_acc': test_metrics_xgb_syn['accuracy'],
    'test_roc_auc': test_metrics_xgb_syn['roc_auc'],
    'test_f1': test_metrics_xgb_syn['f1']
}
pd.DataFrame([xgb_syn_results]).to_csv(OUTPUT_DIR / 'xgb_synthetic_training_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'xgb_synthetic_training_results.csv'}")
# Out:
# ============================================================
# XGBOOST: TRAIN ON SYNTHETIC, EVALUATE ON REAL
# ============================================================
#
# Training on synthetic data...
#
# Evaluating on real validation set...
#
# Evaluating on real test set...
#
# ============================================================
# XGBOOST RESULTS (Trained on Synthetic)
# ============================================================
# Validation - Acc: 0.5692, ROC-AUC: 0.6152, F1: 0.3385
# Test       - Acc: 0.6017, ROC-AUC: 0.6678, F1: 0.4263
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_synthetic_training_results.csv

# %% [markdown]
# ### 11.4. Logistic Regression: Train on Synthetic, Evaluate on Real

# %%
# ============================================================
# Logistic Regression: Train on Synthetic Data, Evaluate on Real
# ============================================================

print("=" * 60)
print("LOGISTIC REGRESSION: TRAIN ON SYNTHETIC, EVALUATE ON REAL")
print("=" * 60)

# Train on synthetic data using the SAME parameters as real data
print("\nTraining on synthetic data...")
from sklearn.linear_model import LogisticRegression

model_lr_syn = LogisticRegression(**lr_best_params)
model_lr_syn.fit(X_syn_df.values, y_syn)

# Evaluate on real validation and test sets
print("\nEvaluating on real validation set...")
val_probs_lr_syn = model_lr_syn.predict_proba(X_val_real)[:, 1]
val_preds_lr_syn = (val_probs_lr_syn >= 0.5).astype(int)
val_metrics_lr_syn = {
    'accuracy': accuracy_score(y_val_real, val_preds_lr_syn),
    'roc_auc': roc_auc_score(y_val_real, val_probs_lr_syn),
    'f1': f1_score(y_val_real, val_preds_lr_syn, zero_division=0),
    'precision': precision_score(y_val_real, val_preds_lr_syn, zero_division=0),
    'recall': recall_score(y_val_real, val_preds_lr_syn, zero_division=0)
}

print("\nEvaluating on real test set...")
test_probs_lr_syn = model_lr_syn.predict_proba(X_test_real)[:, 1]
test_preds_lr_syn = (test_probs_lr_syn >= 0.5).astype(int)
test_metrics_lr_syn = {
    'accuracy': accuracy_score(y_test_real, test_preds_lr_syn),
    'roc_auc': roc_auc_score(y_test_real, test_probs_lr_syn),
    'f1': f1_score(y_test_real, test_preds_lr_syn, zero_division=0),
    'precision': precision_score(y_test_real, test_preds_lr_syn, zero_division=0),
    'recall': recall_score(y_test_real, test_preds_lr_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("LOGISTIC REGRESSION RESULTS (Trained on Synthetic)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_lr_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_lr_syn['roc_auc']:.4f}, F1: {val_metrics_lr_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_lr_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_lr_syn['roc_auc']:.4f}, F1: {test_metrics_lr_syn['f1']:.4f}")
print("=" * 60)

# Save results
lr_syn_results = {
    'model': 'Logistic Regression',
    'training_data': 'Synthetic (VAE per-class)',
    'val_acc': val_metrics_lr_syn['accuracy'],
    'val_roc_auc': val_metrics_lr_syn['roc_auc'],
    'val_f1': val_metrics_lr_syn['f1'],
    'test_acc': test_metrics_lr_syn['accuracy'],
    'test_roc_auc': test_metrics_lr_syn['roc_auc'],
    'test_f1': test_metrics_lr_syn['f1']
}
pd.DataFrame([lr_syn_results]).to_csv(OUTPUT_DIR / 'lr_synthetic_training_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'lr_synthetic_training_results.csv'}")
# Out:
# ============================================================
# LOGISTIC REGRESSION: TRAIN ON SYNTHETIC, EVALUATE ON REAL
# ============================================================
#
# Training on synthetic data...
#
# Evaluating on real validation set...
#
# Evaluating on real test set...
#
# ============================================================
# LOGISTIC REGRESSION RESULTS (Trained on Synthetic)
# ============================================================
# Validation - Acc: 0.4994, ROC-AUC: 0.5058, F1: 0.4972
# Test       - Acc: 0.5125, ROC-AUC: 0.5166, F1: 0.4909
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_synthetic_training_results.csv

# %% [markdown]
# ### 11.5. Summary: Synthetic Training Results

# %%
# ============================================================
# Summary: All Models Trained on Synthetic Data
# ============================================================

print("=" * 60)
print("SUMMARY: ALL MODELS TRAINED ON SYNTHETIC DATA (VAE Per-Class)")
print("=" * 60)

# Collect all results
all_syn_results = [
    nn_syn_results,
    rf_syn_results,
    xgb_syn_results,
    lr_syn_results
]

syn_summary_df = pd.DataFrame(all_syn_results)

print("\n" + "=" * 80)
print("PERFORMANCE SUMMARY (Trained on Synthetic, Evaluated on Real)")
print("=" * 80)
print(syn_summary_df.to_string(index=False))
print("=" * 80)

# Save summary
syn_summary_df.to_csv(OUTPUT_DIR / 'synthetic_training_summary.csv', index=False)
print(f"\n✓ Saved summary to: {OUTPUT_DIR / 'synthetic_training_summary.csv'}")

# Create visualization
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

models = syn_summary_df['model'].values
val_accs = syn_summary_df['val_acc'].values
test_accs = syn_summary_df['test_acc'].values
val_rocs = syn_summary_df['val_roc_auc'].values
test_rocs = syn_summary_df['test_roc_auc'].values
val_f1s = syn_summary_df['val_f1'].values
test_f1s = syn_summary_df['test_f1'].values

x = np.arange(len(models))
width = 0.35

# Accuracy
axes[0].bar(x - width/2, val_accs, width, label='Validation', alpha=0.8)
axes[0].bar(x + width/2, test_accs, width, label='Test', alpha=0.8)
axes[0].set_xlabel('Model', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Accuracy: Synthetic Training', fontsize=14, fontweight='bold')
axes[0].set_xticks(x)
axes[0].set_xticklabels(models, rotation=45, ha='right')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# ROC-AUC
axes[1].bar(x - width/2, val_rocs, width, label='Validation', alpha=0.8)
axes[1].bar(x + width/2, test_rocs, width, label='Test', alpha=0.8)
axes[1].set_xlabel('Model', fontsize=12)
axes[1].set_ylabel('ROC-AUC', fontsize=12)
axes[1].set_title('ROC-AUC: Synthetic Training', fontsize=14, fontweight='bold')
axes[1].set_xticks(x)
axes[1].set_xticklabels(models, rotation=45, ha='right')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# F1
axes[2].bar(x - width/2, val_f1s, width, label='Validation', alpha=0.8)
axes[2].bar(x + width/2, test_f1s, width, label='Test', alpha=0.8)
axes[2].set_xlabel('Model', fontsize=12)
axes[2].set_ylabel('F1 Score', fontsize=12)
axes[2].set_title('F1 Score: Synthetic Training', fontsize=14, fontweight='bold')
axes[2].set_xticks(x)
axes[2].set_xticklabels(models, rotation=45, ha='right')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'synthetic_training_results.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved visualization to: {OUTPUT_DIR / 'synthetic_training_results.png'}")
print("=" * 60)
# Out:
# ============================================================
# SUMMARY: ALL MODELS TRAINED ON SYNTHETIC DATA (VAE Per-Class)
# ============================================================
#
# ================================================================================
# PERFORMANCE SUMMARY (Trained on Synthetic, Evaluated on Real)
# ================================================================================
#               model             training_data  val_acc  val_roc_auc   val_f1  test_acc  test_roc_auc  test_f1
#      Neural Network Synthetic (VAE per-class) 0.559055     0.601483 0.523114  0.603917      0.650284 0.568720
#       Random Forest Synthetic (VAE per-class) 0.591676     0.652392 0.379487  0.623504      0.721168 0.477341
#             XGBoost Synthetic (VAE per-class) 0.569179     0.615165 0.338515  0.601741      0.667837 0.426332
# Logistic Regression Synthetic (VAE per-class) 0.499438     0.505776 0.497175  0.512514      0.516558 0.490909
# ================================================================================
#
# ✓ Saved summary to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/synthetic_training_summary.csv
# ✓ Saved visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/synthetic_training_results.png
# ============================================================

# %% [markdown]
# ## 12. Fine-Tuning on Real Data
#
# **This section:**
# 1. Re-splits real data at participant level (60/20/20) to prevent leakage
# 2. Fine-tunes all 4 models (trained on synthetic) on real training data
# 3. Compares synthetic-only vs fine-tuned performance

# %% [markdown]
# ### 12.1. Re-split Real Data at Participant Level (Prevent Leakage)

# %%
# ============================================================
# Re-split Real Data at Participant Level (60/20/20)
# ============================================================

print("=" * 60)
print("RE-SPLITTING REAL DATA AT PARTICIPANT LEVEL")
print("=" * 60)

# Combine val and test back together
X_val_test_combined = np.vstack([X_val_real, X_test_real])
y_val_test_combined = np.hstack([y_val_real, y_test_real])

# We need participant IDs for the combined val+test data
# Get participant IDs from original splits
# Note: We need to track which samples came from which participants
# Since we combined val and test, we need to reconstruct participant mapping

# Get participant IDs from original data
# The original val and test came from X_val and X_test DataFrames
# We need to get their indices to map back to participant IDs

# Get indices from original DataFrames
val_indices = X_val.index.tolist()
test_indices = X_test.index.tolist()
all_indices = val_indices + test_indices

# Get participant IDs for these indices from original merged_df
# We need to access the original participant_id column
# Let's get it from the original data loading section
# For now, we'll need to reconstruct from available data

# Alternative: Use the original pid_val and pid_test that we had
# But we need to combine them in the same order as X_val_test_combined
pid_val_test_combined = np.hstack([pid_val, pid_test])

print(f"Combined real data: {len(X_val_test_combined)} samples")
print(f"  Unique participants: {len(np.unique(pid_val_test_combined))}")
print(f"  Labels: {np.bincount(y_val_test_combined.astype(int))}")

# Participant-level split (60/20/20)
from sklearn.model_selection import train_test_split

# Get unique participants and their labels
unique_pids = np.unique(pid_val_test_combined)
participant_labels_dict = {}
for pid in unique_pids:
    # Get label for this participant (use first occurrence)
    pid_mask = pid_val_test_combined == pid
    participant_labels_dict[pid] = y_val_test_combined[pid_mask][0]

participant_labels_array = np.array([participant_labels_dict[pid] for pid in unique_pids])

# First split: 60% train, 40% temp (will be split into 20% val, 20% test)
pids_train_ft, pids_temp, y_p_train_ft, y_p_temp = train_test_split(
    unique_pids,
    participant_labels_array,
    test_size=0.4,
    random_state=SEED,
    stratify=participant_labels_array
)

# Second split: Split temp into 50/50 (val and test)
pids_val_ft, pids_test_ft, y_p_val_ft, y_p_test_ft = train_test_split(
    pids_temp,
    y_p_temp,
    test_size=0.5,
    random_state=SEED,
    stratify=y_p_temp
)

# Map participant splits to recording level
train_mask_ft = np.isin(pid_val_test_combined, pids_train_ft)
val_mask_ft = np.isin(pid_val_test_combined, pids_val_ft)
test_mask_ft = np.isin(pid_val_test_combined, pids_test_ft)

X_train_ft = X_val_test_combined[train_mask_ft]
X_val_ft = X_val_test_combined[val_mask_ft]
X_test_ft = X_val_test_combined[test_mask_ft]

y_train_ft = y_val_test_combined[train_mask_ft]
y_val_ft = y_val_test_combined[val_mask_ft]
y_test_ft = y_val_test_combined[test_mask_ft]

pid_train_ft = pid_val_test_combined[train_mask_ft]
pid_val_ft = pid_val_test_combined[val_mask_ft]
pid_test_ft = pid_val_test_combined[test_mask_ft]

print(f"\n✓ Participant-level splits (no leakage):")
print(f"  Train: {len(X_train_ft)} samples from {len(np.unique(pid_train_ft))} participants")
print(f"    Labels: {np.bincount(y_train_ft.astype(int))}")
print(f"  Val:   {len(X_val_ft)} samples from {len(np.unique(pid_val_ft))} participants")
print(f"    Labels: {np.bincount(y_val_ft.astype(int))}")
print(f"  Test:  {len(X_test_ft)} samples from {len(np.unique(pid_test_ft))} participants")
print(f"    Labels: {np.bincount(y_test_ft.astype(int))}")

# Verify no participant overlap
assert len(set(pid_train_ft) & set(pid_val_ft)) == 0, "Train-Val participant overlap!"
assert len(set(pid_train_ft) & set(pid_test_ft)) == 0, "Train-Test participant overlap!"
assert len(set(pid_val_ft) & set(pid_test_ft)) == 0, "Val-Test participant overlap!"
print("\n✓ Verified: No participant overlap between splits")
print("=" * 60)
# Out:
# ============================================================
# RE-SPLITTING REAL DATA AT PARTICIPANT LEVEL
# ============================================================
# Combined real data: 1808 samples
#   Unique participants: 45
#   Labels: [924 884]
#
# ✓ Participant-level splits (no leakage):
#   Train: 1099 samples from 27 participants
#     Labels: [723 376]
#   Val:   362 samples from 9 participants
#     Labels: [ 95 267]
#   Test:  347 samples from 9 participants
#     Labels: [106 241]
#
# ✓ Verified: No participant overlap between splits
# ============================================================

# %%
# ============================================================
# Fine-Tune Neural Network on Real Data
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: FINE-TUNING ON REAL DATA")
print("=" * 60)

# Create DataLoaders for fine-tuning
train_dataset_ft_nn = TensorDataset(
    torch.FloatTensor(X_train_ft),
    torch.FloatTensor(y_train_ft.reshape(-1, 1))
)
val_dataset_ft_nn = TensorDataset(
    torch.FloatTensor(X_val_ft),
    torch.FloatTensor(y_val_ft.reshape(-1, 1))
)

train_loader_ft_nn = DataLoader(train_dataset_ft_nn, batch_size=32, shuffle=True)
val_loader_ft_nn = DataLoader(val_dataset_ft_nn, batch_size=32, shuffle=False)

# Start with synthetic-trained model
model_nn_ft = copy.deepcopy(model_nn_syn)

# Fine-tune with lower learning rate (10x smaller)
print("\nFine-tuning on real data with reduced learning rate...")
model_nn_ft, history_nn_ft, best_epoch_nn_ft = train_model_with_checkpointing(
    model_nn_ft,
    train_loader=train_loader_ft_nn,
    val_loader=val_loader_ft_nn,
    epochs=20,  # Fewer epochs for fine-tuning
    lr=6e-5,    # 10x smaller learning rate
    weight_decay=8e-3
)

# Evaluate fine-tuned model
print("\nEvaluating fine-tuned model on validation set...")
val_metrics_nn_ft = evaluate_on_real(model_nn_ft, val_loader_ft_nn, threshold=0.5)

print("\nEvaluating fine-tuned model on test set...")
test_dataset_ft_nn = TensorDataset(
    torch.FloatTensor(X_test_ft),
    torch.FloatTensor(y_test_ft.reshape(-1, 1))
)
test_loader_ft_nn = DataLoader(test_dataset_ft_nn, batch_size=32, shuffle=False)
test_metrics_nn_ft = evaluate_on_real(model_nn_ft, test_loader_ft_nn, threshold=0.5)

print("\n" + "=" * 60)
print("NEURAL NETWORK: SYNTHETIC vs FINE-TUNED")
print("=" * 60)
print("Synthetic-only (on old val/test):")
print(f"  Val - Acc: {val_metrics_nn_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_nn_syn['roc_auc']:.4f}, F1: {val_metrics_nn_syn['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_nn_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_nn_syn['roc_auc']:.4f}, F1: {test_metrics_nn_syn['f1']:.4f}")
print("\nFine-tuned (on new val/test):")
print(f"  Val - Acc: {val_metrics_nn_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_nn_ft['roc_auc']:.4f}, F1: {val_metrics_nn_ft['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_nn_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_nn_ft['roc_auc']:.4f}, F1: {test_metrics_nn_ft['f1']:.4f}")
print("=" * 60)

# Save results
nn_ft_results = {
    'model': 'Neural Network',
    'stage': 'Fine-tuned',
    'val_acc': val_metrics_nn_ft['accuracy'],
    'val_roc_auc': val_metrics_nn_ft['roc_auc'],
    'val_f1': val_metrics_nn_ft['f1'],
    'test_acc': test_metrics_nn_ft['accuracy'],
    'test_roc_auc': test_metrics_nn_ft['roc_auc'],
    'test_f1': test_metrics_nn_ft['f1']
}
pd.DataFrame([nn_ft_results]).to_csv(OUTPUT_DIR / 'nn_finetuned_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'nn_finetuned_results.csv'}")
# Out:
# ============================================================
# NEURAL NETWORK: FINE-TUNING ON REAL DATA
# ============================================================
#
# Fine-tuning on real data with reduced learning rate...
# Training on device: cpu
# Epochs: 20, LR: 6e-05, Weight decay: 8e-03
# ============================================================
# Epoch   1/20: train_loss=1.0184, val_loss=0.8787, train_acc=0.562, val_acc=0.569, val_roc_auc=0.6185
# Epoch  10/20: train_loss=0.5976, val_loss=0.7201, train_acc=0.744, val_acc=0.547, val_roc_auc=0.7098
# Epoch  20/20: train_loss=0.5789, val_loss=0.7545, train_acc=0.768, val_acc=0.519, val_roc_auc=0.7109
#
# ✓ Loaded best model from epoch 18 (Val ROC-AUC: 0.7150)
#
# Evaluating fine-tuned model on validation set...
#
# Evaluating fine-tuned model on test set...
#
# ============================================================
# NEURAL NETWORK: SYNTHETIC vs FINE-TUNED
# ============================================================
# Synthetic-only (on old val/test):
#   Val - Acc: 0.5591, ROC-AUC: 0.6015, F1: 0.5231
#   Test - Acc: 0.6039, ROC-AUC: 0.6503, F1: 0.5687
#
# Fine-tuned (on new val/test):
#   Val - Acc: 0.5525, ROC-AUC: 0.7150, F1: 0.5950
#   Test - Acc: 0.6542, ROC-AUC: 0.7340, F1: 0.7101
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/nn_finetuned_results.csv

# %% [markdown]
# ### 12.3. Fine-Tune Random Forest on Real Data

# %%
# ============================================================
# Fine-Tune Random Forest on Real Data
# ============================================================

print("=" * 60)
print("RANDOM FOREST: FINE-TUNING ON REAL DATA")
print("=" * 60)

# Retrain on real data (RF doesn't support incremental training well)
print("\nRetraining on real data...")
model_rf_ft = RandomForestClassifier(**rf_best_params)
model_rf_ft.fit(X_train_ft, y_train_ft)

# Evaluate fine-tuned model
print("\nEvaluating fine-tuned model...")
val_probs_rf_ft = model_rf_ft.predict_proba(X_val_ft)[:, 1]
val_preds_rf_ft = (val_probs_rf_ft >= 0.5).astype(int)
val_metrics_rf_ft = {
    'accuracy': accuracy_score(y_val_ft, val_preds_rf_ft),
    'roc_auc': roc_auc_score(y_val_ft, val_probs_rf_ft),
    'f1': f1_score(y_val_ft, val_preds_rf_ft, zero_division=0),
    'precision': precision_score(y_val_ft, val_preds_rf_ft, zero_division=0),
    'recall': recall_score(y_val_ft, val_preds_rf_ft, zero_division=0)
}

test_probs_rf_ft = model_rf_ft.predict_proba(X_test_ft)[:, 1]
test_preds_rf_ft = (test_probs_rf_ft >= 0.5).astype(int)
test_metrics_rf_ft = {
    'accuracy': accuracy_score(y_test_ft, test_preds_rf_ft),
    'roc_auc': roc_auc_score(y_test_ft, test_probs_rf_ft),
    'f1': f1_score(y_test_ft, test_preds_rf_ft, zero_division=0),
    'precision': precision_score(y_test_ft, test_preds_rf_ft, zero_division=0),
    'recall': recall_score(y_test_ft, test_preds_rf_ft, zero_division=0)
}

print("\n" + "=" * 60)
print("RANDOM FOREST: SYNTHETIC vs FINE-TUNED")
print("=" * 60)
print("Synthetic-only:")
print(f"  Val - Acc: {val_metrics_rf_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_rf_syn['roc_auc']:.4f}, F1: {val_metrics_rf_syn['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_rf_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_rf_syn['roc_auc']:.4f}, F1: {test_metrics_rf_syn['f1']:.4f}")
print("\nFine-tuned:")
print(f"  Val - Acc: {val_metrics_rf_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_rf_ft['roc_auc']:.4f}, F1: {val_metrics_rf_ft['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_rf_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_rf_ft['roc_auc']:.4f}, F1: {test_metrics_rf_ft['f1']:.4f}")
print("=" * 60)

# Save results
rf_ft_results = {
    'model': 'Random Forest',
    'stage': 'Fine-tuned',
    'val_acc': val_metrics_rf_ft['accuracy'],
    'val_roc_auc': val_metrics_rf_ft['roc_auc'],
    'val_f1': val_metrics_rf_ft['f1'],
    'test_acc': test_metrics_rf_ft['accuracy'],
    'test_roc_auc': test_metrics_rf_ft['roc_auc'],
    'test_f1': test_metrics_rf_ft['f1']
}
pd.DataFrame([rf_ft_results]).to_csv(OUTPUT_DIR / 'rf_finetuned_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'rf_finetuned_results.csv'}")
# Out:
# ============================================================
# RANDOM FOREST: FINE-TUNING ON REAL DATA
# ============================================================
#
# Retraining on real data...
#
# Evaluating fine-tuned model...
#
# ============================================================
# RANDOM FOREST: SYNTHETIC vs FINE-TUNED
# ============================================================
# Synthetic-only:
#   Val - Acc: 0.5917, ROC-AUC: 0.6524, F1: 0.3795
#   Test - Acc: 0.6235, ROC-AUC: 0.7212, F1: 0.4773
#
# Fine-tuned:
#   Val - Acc: 0.5028, ROC-AUC: 0.7716, F1: 0.5187
#   Test - Acc: 0.6225, ROC-AUC: 0.7888, F1: 0.6525
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/rf_finetuned_results.csv

# %% [markdown]
# ### 12.4. Fine-Tune XGBoost on Real Data

# %%
# ============================================================
# Fine-Tune XGBoost on Real Data
# ============================================================

print("=" * 60)
print("XGBOOST: FINE-TUNING ON REAL DATA")
print("=" * 60)

# Continue training on real data (incremental)
print("\nContinuing training on real data...")
# XGBoost supports incremental training via fit with xgb_model parameter
model_xgb_ft = xgb.XGBClassifier(**xgb_best_params)
# Start from synthetic model
model_xgb_ft.fit(X_train_ft, y_train_ft, xgb_model=model_xgb_syn.get_booster())

# Evaluate fine-tuned model
print("\nEvaluating fine-tuned model...")
val_probs_xgb_ft = model_xgb_ft.predict_proba(X_val_ft)[:, 1]
val_preds_xgb_ft = (val_probs_xgb_ft >= 0.5).astype(int)
val_metrics_xgb_ft = {
    'accuracy': accuracy_score(y_val_ft, val_preds_xgb_ft),
    'roc_auc': roc_auc_score(y_val_ft, val_probs_xgb_ft),
    'f1': f1_score(y_val_ft, val_preds_xgb_ft, zero_division=0),
    'precision': precision_score(y_val_ft, val_preds_xgb_ft, zero_division=0),
    'recall': recall_score(y_val_ft, val_preds_xgb_ft, zero_division=0)
}

test_probs_xgb_ft = model_xgb_ft.predict_proba(X_test_ft)[:, 1]
test_preds_xgb_ft = (test_probs_xgb_ft >= 0.5).astype(int)
test_metrics_xgb_ft = {
    'accuracy': accuracy_score(y_test_ft, test_preds_xgb_ft),
    'roc_auc': roc_auc_score(y_test_ft, test_probs_xgb_ft),
    'f1': f1_score(y_test_ft, test_preds_xgb_ft, zero_division=0),
    'precision': precision_score(y_test_ft, test_preds_xgb_ft, zero_division=0),
    'recall': recall_score(y_test_ft, test_preds_xgb_ft, zero_division=0)
}

print("\n" + "=" * 60)
print("XGBOOST: SYNTHETIC vs FINE-TUNED")
print("=" * 60)
print("Synthetic-only:")
print(f"  Val - Acc: {val_metrics_xgb_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_xgb_syn['roc_auc']:.4f}, F1: {val_metrics_xgb_syn['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_xgb_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_xgb_syn['roc_auc']:.4f}, F1: {test_metrics_xgb_syn['f1']:.4f}")
print("\nFine-tuned:")
print(f"  Val - Acc: {val_metrics_xgb_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_xgb_ft['roc_auc']:.4f}, F1: {val_metrics_xgb_ft['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_xgb_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_xgb_ft['roc_auc']:.4f}, F1: {test_metrics_xgb_ft['f1']:.4f}")
print("=" * 60)

# Save results
xgb_ft_results = {
    'model': 'XGBoost',
    'stage': 'Fine-tuned',
    'val_acc': val_metrics_xgb_ft['accuracy'],
    'val_roc_auc': val_metrics_xgb_ft['roc_auc'],
    'val_f1': val_metrics_xgb_ft['f1'],
    'test_acc': test_metrics_xgb_ft['accuracy'],
    'test_roc_auc': test_metrics_xgb_ft['roc_auc'],
    'test_f1': test_metrics_xgb_ft['f1']
}
pd.DataFrame([xgb_ft_results]).to_csv(OUTPUT_DIR / 'xgb_finetuned_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'xgb_finetuned_results.csv'}")
# Out:
# ============================================================
# XGBOOST: FINE-TUNING ON REAL DATA
# ============================================================
#
# Continuing training on real data...
#
# Evaluating fine-tuned model...
#
# ============================================================
# XGBOOST: SYNTHETIC vs FINE-TUNED
# ============================================================
# Synthetic-only:
#   Val - Acc: 0.5692, ROC-AUC: 0.6152, F1: 0.3385
#   Test - Acc: 0.6017, ROC-AUC: 0.6678, F1: 0.4263
#
# Fine-tuned:
#   Val - Acc: 0.5193, ROC-AUC: 0.7214, F1: 0.5515
#   Test - Acc: 0.6282, ROC-AUC: 0.7603, F1: 0.6560
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/xgb_finetuned_results.csv

# %% [markdown]
# ### 12.5. Fine-Tune Logistic Regression on Real Data

# %%
# ============================================================
# Fine-Tune Logistic Regression on Real Data
# ============================================================

print("=" * 60)
print("LOGISTIC REGRESSION: FINE-TUNING ON REAL DATA")
print("=" * 60)

# Retrain on real data (LR doesn't support incremental training well)
print("\nRetraining on real data...")
model_lr_ft = LogisticRegression(**lr_best_params)
model_lr_ft.fit(X_train_ft, y_train_ft)

# Evaluate fine-tuned model
print("\nEvaluating fine-tuned model...")
val_probs_lr_ft = model_lr_ft.predict_proba(X_val_ft)[:, 1]
val_preds_lr_ft = (val_probs_lr_ft >= 0.5).astype(int)
val_metrics_lr_ft = {
    'accuracy': accuracy_score(y_val_ft, val_preds_lr_ft),
    'roc_auc': roc_auc_score(y_val_ft, val_probs_lr_ft),
    'f1': f1_score(y_val_ft, val_preds_lr_ft, zero_division=0),
    'precision': precision_score(y_val_ft, val_preds_lr_ft, zero_division=0),
    'recall': recall_score(y_val_ft, val_preds_lr_ft, zero_division=0)
}

test_probs_lr_ft = model_lr_ft.predict_proba(X_test_ft)[:, 1]
test_preds_lr_ft = (test_probs_lr_ft >= 0.5).astype(int)
test_metrics_lr_ft = {
    'accuracy': accuracy_score(y_test_ft, test_preds_lr_ft),
    'roc_auc': roc_auc_score(y_test_ft, test_probs_lr_ft),
    'f1': f1_score(y_test_ft, test_preds_lr_ft, zero_division=0),
    'precision': precision_score(y_test_ft, test_preds_lr_ft, zero_division=0),
    'recall': recall_score(y_test_ft, test_preds_lr_ft, zero_division=0)
}

print("\n" + "=" * 60)
print("LOGISTIC REGRESSION: SYNTHETIC vs FINE-TUNED")
print("=" * 60)
print("Synthetic-only:")
print(f"  Val - Acc: {val_metrics_lr_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_lr_syn['roc_auc']:.4f}, F1: {val_metrics_lr_syn['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_lr_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_lr_syn['roc_auc']:.4f}, F1: {test_metrics_lr_syn['f1']:.4f}")
print("\nFine-tuned:")
print(f"  Val - Acc: {val_metrics_lr_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_lr_ft['roc_auc']:.4f}, F1: {val_metrics_lr_ft['f1']:.4f}")
print(f"  Test - Acc: {test_metrics_lr_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_lr_ft['roc_auc']:.4f}, F1: {test_metrics_lr_ft['f1']:.4f}")
print("=" * 60)

# Save results
lr_ft_results = {
    'model': 'Logistic Regression',
    'stage': 'Fine-tuned',
    'val_acc': val_metrics_lr_ft['accuracy'],
    'val_roc_auc': val_metrics_lr_ft['roc_auc'],
    'val_f1': val_metrics_lr_ft['f1'],
    'test_acc': test_metrics_lr_ft['accuracy'],
    'test_roc_auc': test_metrics_lr_ft['roc_auc'],
    'test_f1': test_metrics_lr_ft['f1']
}
pd.DataFrame([lr_ft_results]).to_csv(OUTPUT_DIR / 'lr_finetuned_results.csv', index=False)
print(f"✓ Saved results to: {OUTPUT_DIR / 'lr_finetuned_results.csv'}")
# Out:
# ============================================================
# LOGISTIC REGRESSION: FINE-TUNING ON REAL DATA
# ============================================================
#
# Retraining on real data...
#
# Evaluating fine-tuned model...
#
# ============================================================
# LOGISTIC REGRESSION: SYNTHETIC vs FINE-TUNED
# ============================================================
# Synthetic-only:
#   Val - Acc: 0.4994, ROC-AUC: 0.5058, F1: 0.4972
#   Test - Acc: 0.5125, ROC-AUC: 0.5166, F1: 0.4909
#
# Fine-tuned:
#   Val - Acc: 0.5276, ROC-AUC: 0.6911, F1: 0.5757
#   Test - Acc: 0.6225, ROC-AUC: 0.6725, F1: 0.6843
# ============================================================
# ✓ Saved results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/lr_finetuned_results.csv

# %% [markdown]
# ### 12.6. Fine-Tuning Results Summary

# %%
# ============================================================
# Fine-Tuning Results Summary
# ============================================================

print("=" * 60)
print("FINE-TUNING RESULTS SUMMARY")
print("=" * 60)

# Collect all fine-tuned results
all_ft_results = [
    nn_ft_results,
    rf_ft_results,
    xgb_ft_results,
    lr_ft_results
]

ft_summary_df = pd.DataFrame(all_ft_results)

print("\n" + "=" * 80)
print("FINE-TUNED MODELS PERFORMANCE")
print("=" * 80)
print(ft_summary_df.to_string(index=False))
print("=" * 80)

# Save summary
ft_summary_df.to_csv(OUTPUT_DIR / 'finetuning_summary.csv', index=False)
print(f"\n✓ Saved summary to: {OUTPUT_DIR / 'finetuning_summary.csv'}")

# Create comparison visualization
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

models = ft_summary_df['model'].values
val_accs = ft_summary_df['val_acc'].values
test_accs = ft_summary_df['test_acc'].values
val_rocs = ft_summary_df['val_roc_auc'].values
test_rocs = ft_summary_df['test_roc_auc'].values
val_f1s = ft_summary_df['val_f1'].values
test_f1s = ft_summary_df['test_f1'].values

x = np.arange(len(models))
width = 0.35

# Accuracy
axes[0].bar(x - width/2, val_accs, width, label='Validation', alpha=0.8)
axes[0].bar(x + width/2, test_accs, width, label='Test', alpha=0.8)
axes[0].set_xlabel('Model', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Accuracy: Fine-Tuned Models', fontsize=14, fontweight='bold')
axes[0].set_xticks(x)
axes[0].set_xticklabels(models, rotation=45, ha='right')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# ROC-AUC
axes[1].bar(x - width/2, val_rocs, width, label='Validation', alpha=0.8)
axes[1].bar(x + width/2, test_rocs, width, label='Test', alpha=0.8)
axes[1].set_xlabel('Model', fontsize=12)
axes[1].set_ylabel('ROC-AUC', fontsize=12)
axes[1].set_title('ROC-AUC: Fine-Tuned Models', fontsize=14, fontweight='bold')
axes[1].set_xticks(x)
axes[1].set_xticklabels(models, rotation=45, ha='right')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# F1
axes[2].bar(x - width/2, val_f1s, width, label='Validation', alpha=0.8)
axes[2].bar(x + width/2, test_f1s, width, label='Test', alpha=0.8)
axes[2].set_xlabel('Model', fontsize=12)
axes[2].set_ylabel('F1 Score', fontsize=12)
axes[2].set_title('F1 Score: Fine-Tuned Models', fontsize=14, fontweight='bold')
axes[2].set_xticks(x)
axes[2].set_xticklabels(models, rotation=45, ha='right')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'finetuning_results.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved visualization to: {OUTPUT_DIR / 'finetuning_results.png'}")
print("=" * 60)
# Out:
# ============================================================
# FINE-TUNING RESULTS SUMMARY
# ============================================================
#
# ================================================================================
# FINE-TUNED MODELS PERFORMANCE
# ================================================================================
#               model      stage  val_acc  val_roc_auc   val_f1  test_acc  test_roc_auc  test_f1
#      Neural Network Fine-tuned 0.552486     0.715040 0.595000  0.654179      0.733970 0.710145
#       Random Forest Fine-tuned 0.502762     0.771575 0.518717  0.622478      0.788812 0.652520
#             XGBoost Fine-tuned 0.519337     0.721388 0.551546  0.628242      0.760276 0.656000
# Logistic Regression Fine-tuned 0.527624     0.691110 0.575682  0.622478      0.672512 0.684337
# ================================================================================
#
# ✓ Saved summary to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/finetuning_summary.csv
# ✓ Saved visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/finetuning_results.png
# ============================================================

# %% [markdown]
# ## 13. Ensemble Model
#
# **This section:**
# 1. Gets validation predictions from all 4 fine-tuned models
# 2. Builds weighted ensemble (weighted by validation ROC-AUC)
# 3. Evaluates ensemble at recording level

# %% [markdown]
# ### 13.1. Get Validation Predictions from All Models

# %%
# ============================================================
# Get Validation Predictions from All Fine-Tuned Models
# ============================================================

print("=" * 60)
print("GETTING VALIDATION PREDICTIONS FROM ALL MODELS")
print("=" * 60)

# Neural Network predictions
print("\nGetting Neural Network predictions...")
val_loader_ft_nn = DataLoader(
    TensorDataset(torch.FloatTensor(X_val_ft), torch.FloatTensor(y_val_ft.reshape(-1, 1))),
    batch_size=32, shuffle=False
)
model_nn_ft.eval()
val_probs_nn_ft = []
with torch.no_grad():
    for x_batch, _ in val_loader_ft_nn:
        x_batch = x_batch.to(DEVICE)
        probs = torch.sigmoid(model_nn_ft(x_batch)).cpu().numpy()
        val_probs_nn_ft.extend(probs)
val_probs_nn_ft = np.array(val_probs_nn_ft).flatten()

# Random Forest predictions
print("Getting Random Forest predictions...")
val_probs_rf_ft = model_rf_ft.predict_proba(X_val_ft)[:, 1]

# XGBoost predictions
print("Getting XGBoost predictions...")
val_probs_xgb_ft = model_xgb_ft.predict_proba(X_val_ft)[:, 1]

# Logistic Regression predictions
print("Getting Logistic Regression predictions...")
val_probs_lr_ft = model_lr_ft.predict_proba(X_val_ft)[:, 1]

print(f"\n✓ All validation predictions obtained:")
print(f"  NN: {len(val_probs_nn_ft)} predictions")
print(f"  RF: {len(val_probs_rf_ft)} predictions")
print(f"  XGB: {len(val_probs_xgb_ft)} predictions")
print(f"  LR: {len(val_probs_lr_ft)} predictions")

# Calculate individual model weights based on validation ROC-AUC
val_roc_nn = roc_auc_score(y_val_ft, val_probs_nn_ft)
val_roc_rf = roc_auc_score(y_val_ft, val_probs_rf_ft)
val_roc_xgb = roc_auc_score(y_val_ft, val_probs_xgb_ft)
val_roc_lr = roc_auc_score(y_val_ft, val_probs_lr_ft)

# Normalize weights (sum to 1)
roc_scores = np.array([val_roc_nn, val_roc_rf, val_roc_xgb, val_roc_lr])
# Handle negative or very low scores
roc_scores = np.maximum(roc_scores, 0.5)  # Minimum weight threshold
weights = roc_scores / roc_scores.sum()

model_names = ['Neural Network', 'Random Forest', 'XGBoost', 'Logistic Regression']
print(f"\n✓ Model weights (based on validation ROC-AUC):")
for name, weight, roc in zip(model_names, weights, [val_roc_nn, val_roc_rf, val_roc_xgb, val_roc_lr]):
    print(f"  {name}: {weight:.4f} (ROC-AUC: {roc:.4f})")
print(f"  Total: {weights.sum():.4f}")
print("=" * 60)
# Out:
# ============================================================
# GETTING VALIDATION PREDICTIONS FROM ALL MODELS
# ============================================================
#
# Getting Neural Network predictions...
# Getting Random Forest predictions...
# Getting XGBoost predictions...
# Getting Logistic Regression predictions...
#
# ✓ All validation predictions obtained:
#   NN: 362 predictions
#   RF: 362 predictions
#   XGB: 362 predictions
#   LR: 362 predictions
#
# ✓ Model weights (based on validation ROC-AUC):
#   Neural Network: 0.2466 (ROC-AUC: 0.7150)
#   Random Forest: 0.2661 (ROC-AUC: 0.7716)
#   XGBoost: 0.2488 (ROC-AUC: 0.7214)
#   Logistic Regression: 0.2384 (ROC-AUC: 0.6911)
#   Total: 1.0000
# ============================================================

# %% [markdown]
# ### 13.2. Build Weighted Ensemble

# %%
# ============================================================
# Build Weighted Ensemble (Soft Voting)
# ============================================================

print("=" * 60)
print("BUILDING WEIGHTED ENSEMBLE")
print("=" * 60)

# Stack all predictions
val_probs_all = np.column_stack([
    val_probs_nn_ft,
    val_probs_rf_ft,
    val_probs_xgb_ft,
    val_probs_lr_ft
])

# Weighted average
val_probs_ensemble = np.average(val_probs_all, axis=1, weights=weights)
val_preds_ensemble = (val_probs_ensemble >= 0.5).astype(int)

# Evaluate ensemble on validation set
val_metrics_ensemble = {
    'accuracy': accuracy_score(y_val_ft, val_preds_ensemble),
    'roc_auc': roc_auc_score(y_val_ft, val_probs_ensemble),
    'f1': f1_score(y_val_ft, val_preds_ensemble, zero_division=0),
    'precision': precision_score(y_val_ft, val_preds_ensemble, zero_division=0),
    'recall': recall_score(y_val_ft, val_preds_ensemble, zero_division=0)
}

print("\n" + "=" * 60)
print("ENSEMBLE vs INDIVIDUAL MODELS (Validation Set)")
print("=" * 60)
print(f"Ensemble:")
print(f"  Acc: {val_metrics_ensemble['accuracy']:.4f}, ROC-AUC: {val_metrics_ensemble['roc_auc']:.4f}, F1: {val_metrics_ensemble['f1']:.4f}")
print(f"\nIndividual Models:")
print(f"  NN:  Acc: {val_metrics_nn_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_nn_ft['roc_auc']:.4f}, F1: {val_metrics_nn_ft['f1']:.4f}")
print(f"  RF:  Acc: {val_metrics_rf_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_rf_ft['roc_auc']:.4f}, F1: {val_metrics_rf_ft['f1']:.4f}")
print(f"  XGB: Acc: {val_metrics_xgb_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_xgb_ft['roc_auc']:.4f}, F1: {val_metrics_xgb_ft['f1']:.4f}")
print(f"  LR:  Acc: {val_metrics_lr_ft['accuracy']:.4f}, ROC-AUC: {val_metrics_lr_ft['roc_auc']:.4f}, F1: {val_metrics_lr_ft['f1']:.4f}")
print("=" * 60)

# Save ensemble weights
ensemble_weights_df = pd.DataFrame({
    'model': model_names,
    'weight': weights,
    'val_roc_auc': [val_roc_nn, val_roc_rf, val_roc_xgb, val_roc_lr]
})
ensemble_weights_df.to_csv(OUTPUT_DIR / 'ensemble_weights.csv', index=False)
print(f"\n✓ Saved ensemble weights to: {OUTPUT_DIR / 'ensemble_weights.csv'}")
# Out:
# ============================================================
# BUILDING WEIGHTED ENSEMBLE
# ============================================================
#
# ============================================================
# ENSEMBLE vs INDIVIDUAL MODELS (Validation Set)
# ============================================================
# Ensemble:
#   Acc: 0.5166, ROC-AUC: 0.7619, F1: 0.5358
#
# Individual Models:
#   NN:  Acc: 0.5525, ROC-AUC: 0.7150, F1: 0.5950
#   RF:  Acc: 0.5028, ROC-AUC: 0.7716, F1: 0.5187
#   XGB: Acc: 0.5193, ROC-AUC: 0.7214, F1: 0.5515
#   LR:  Acc: 0.5276, ROC-AUC: 0.6911, F1: 0.5757
# ============================================================
#
# ✓ Saved ensemble weights to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/ensemble_weights.csv

# %% [markdown]
# ### 13.3. Evaluate Ensemble on Test Set (Recording Level)

# %%
# ============================================================
# Evaluate Ensemble on Test Set (Recording Level)
# ============================================================

print("=" * 60)
print("ENSEMBLE: TEST SET EVALUATION (RECORDING LEVEL)")
print("=" * 60)

# Get test predictions from all models
print("\nGetting test predictions from all models...")

# Neural Network
test_loader_ft_nn = DataLoader(
    TensorDataset(torch.FloatTensor(X_test_ft), torch.FloatTensor(y_test_ft.reshape(-1, 1))),
    batch_size=32, shuffle=False
)
model_nn_ft.eval()
test_probs_nn_ft = []
with torch.no_grad():
    for x_batch, _ in test_loader_ft_nn:
        x_batch = x_batch.to(DEVICE)
        probs = torch.sigmoid(model_nn_ft(x_batch)).cpu().numpy()
        test_probs_nn_ft.extend(probs)
test_probs_nn_ft = np.array(test_probs_nn_ft).flatten()

# Other models
test_probs_rf_ft = model_rf_ft.predict_proba(X_test_ft)[:, 1]
test_probs_xgb_ft = model_xgb_ft.predict_proba(X_test_ft)[:, 1]
test_probs_lr_ft = model_lr_ft.predict_proba(X_test_ft)[:, 1]

# Ensemble predictions
test_probs_all = np.column_stack([
    test_probs_nn_ft,
    test_probs_rf_ft,
    test_probs_xgb_ft,
    test_probs_lr_ft
])

test_probs_ensemble = np.average(test_probs_all, axis=1, weights=weights)
test_preds_ensemble = (test_probs_ensemble >= 0.5).astype(int)

# Evaluate ensemble on test set
test_metrics_ensemble = {
    'accuracy': accuracy_score(y_test_ft, test_preds_ensemble),
    'roc_auc': roc_auc_score(y_test_ft, test_probs_ensemble),
    'f1': f1_score(y_test_ft, test_preds_ensemble, zero_division=0),
    'precision': precision_score(y_test_ft, test_preds_ensemble, zero_division=0),
    'recall': recall_score(y_test_ft, test_preds_ensemble, zero_division=0)
}

print("\n" + "=" * 60)
print("ENSEMBLE vs INDIVIDUAL MODELS (Test Set - Recording Level)")
print("=" * 60)
print(f"Ensemble:")
print(f"  Acc: {test_metrics_ensemble['accuracy']:.4f}, ROC-AUC: {test_metrics_ensemble['roc_auc']:.4f}, F1: {test_metrics_ensemble['f1']:.4f}")
print(f"\nIndividual Models:")
print(f"  NN:  Acc: {test_metrics_nn_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_nn_ft['roc_auc']:.4f}, F1: {test_metrics_nn_ft['f1']:.4f}")
print(f"  RF:  Acc: {test_metrics_rf_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_rf_ft['roc_auc']:.4f}, F1: {test_metrics_rf_ft['f1']:.4f}")
print(f"  XGB: Acc: {test_metrics_xgb_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_xgb_ft['roc_auc']:.4f}, F1: {test_metrics_xgb_ft['f1']:.4f}")
print(f"  LR:  Acc: {test_metrics_lr_ft['accuracy']:.4f}, ROC-AUC: {test_metrics_lr_ft['roc_auc']:.4f}, F1: {test_metrics_lr_ft['f1']:.4f}")
print("=" * 60)

# Save ensemble results
ensemble_results = {
    'model': 'Ensemble (Weighted)',
    'level': 'Recording',
    'val_acc': val_metrics_ensemble['accuracy'],
    'val_roc_auc': val_metrics_ensemble['roc_auc'],
    'val_f1': val_metrics_ensemble['f1'],
    'test_acc': test_metrics_ensemble['accuracy'],
    'test_roc_auc': test_metrics_ensemble['roc_auc'],
    'test_f1': test_metrics_ensemble['f1']
}
pd.DataFrame([ensemble_results]).to_csv(OUTPUT_DIR / 'ensemble_recording_level_results.csv', index=False)
print(f"\n✓ Saved ensemble results to: {OUTPUT_DIR / 'ensemble_recording_level_results.csv'}")
# Out:
# ============================================================
# ENSEMBLE: TEST SET EVALUATION (RECORDING LEVEL)
# ============================================================
#
# Getting test predictions from all models...
#
# ============================================================
# ENSEMBLE vs INDIVIDUAL MODELS (Test Set - Recording Level)
# ============================================================
# Ensemble:
#   Acc: 0.6311, ROC-AUC: 0.7761, F1: 0.6718
#
# Individual Models:
#   NN:  Acc: 0.6542, ROC-AUC: 0.7340, F1: 0.7101
#   RF:  Acc: 0.6225, ROC-AUC: 0.7888, F1: 0.6525
#   XGB: Acc: 0.6282, ROC-AUC: 0.7603, F1: 0.6560
#   LR:  Acc: 0.6225, ROC-AUC: 0.6725, F1: 0.6843
# ============================================================
#
# ✓ Saved ensemble results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/ensemble_recording_level_results.csv

# %% [markdown]
# ## 14. Patient-Level Prediction
#
# **This section:**
# 1. Aggregates recording-level predictions to patient level
# 2. Evaluates ensemble at patient level
# 3. Compares recording-level vs patient-level performance

# %% [markdown]
# ### 14.1. Aggregate Predictions to Patient Level

# %%
# ============================================================
# Aggregate Predictions to Patient Level
# ============================================================

print("=" * 60)
print("AGGREGATING PREDICTIONS TO PATIENT LEVEL")
print("=" * 60)

# Create DataFrame with test predictions and participant IDs
test_predictions_df = pd.DataFrame({
    'participant_id': pid_test_ft,
    'true_label': y_test_ft,
    'prob_ensemble': test_probs_ensemble,
    'pred_ensemble': test_preds_ensemble,
    'prob_nn': test_probs_nn_ft,
    'prob_rf': test_probs_rf_ft,
    'prob_xgb': test_probs_xgb_ft,
    'prob_lr': test_probs_lr_ft
})

print(f"\nTest set: {len(test_predictions_df)} recordings from {len(test_predictions_df['participant_id'].unique())} participants")

# Aggregate to patient level: Use MEDIAN to combine probabilities per patient
patient_level_df = test_predictions_df.groupby('participant_id').agg({
    'true_label': 'first',  # All recordings from same patient have same label
    'prob_ensemble': 'median',
    'prob_nn': 'median',
    'prob_rf': 'median',
    'prob_xgb': 'median',
    'prob_lr': 'median'
}).reset_index()

# Convert averaged probabilities to binary predictions
patient_level_df['pred_ensemble'] = (patient_level_df['prob_ensemble'] >= 0.5).astype(int)
patient_level_df['pred_nn'] = (patient_level_df['prob_nn'] >= 0.5).astype(int)
patient_level_df['pred_rf'] = (patient_level_df['prob_rf'] >= 0.5).astype(int)
patient_level_df['pred_xgb'] = (patient_level_df['prob_xgb'] >= 0.5).astype(int)
patient_level_df['pred_lr'] = (patient_level_df['prob_lr'] >= 0.5).astype(int)

# Add recording count per patient
recording_counts = test_predictions_df.groupby('participant_id').size().reset_index(name='n_recordings')
patient_level_df = patient_level_df.merge(recording_counts, on='participant_id')

print(f"\n✓ Aggregated to patient level:")
print(f"  {len(patient_level_df)} patients")
print(f"  Labels: {np.bincount(patient_level_df['true_label'].astype(int))}")
print(f"  Recordings per patient: {patient_level_df['n_recordings'].min()}-{patient_level_df['n_recordings'].max()} (mean: {patient_level_df['n_recordings'].mean():.1f})")

# Save patient-level predictions
patient_level_df.to_csv(OUTPUT_DIR / 'patient_level_predictions.csv', index=False)
print(f"\n✓ Saved patient-level predictions to: {OUTPUT_DIR / 'patient_level_predictions.csv'}")
print("=" * 60)
# Out:
# ============================================================
# AGGREGATING PREDICTIONS TO PATIENT LEVEL
# ============================================================
#
# Test set: 347 recordings from 9 participants
#
# ✓ Aggregated to patient level:
#   9 patients
#   Labels: [5 4]
#   Recordings per patient: 4-53 (mean: 38.6)
#
# ✓ Saved patient-level predictions to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/patient_level_predictions.csv
# ============================================================

# %% [markdown]
# ### 14.2. Evaluate at Patient Level

# %%
# ============================================================
# Evaluate Ensemble at Patient Level
# ============================================================

print("=" * 60)
print("ENSEMBLE: PATIENT-LEVEL EVALUATION")
print("=" * 60)

# Get true labels and predictions at patient level
y_patient_true = patient_level_df['true_label'].values
y_patient_pred_ensemble = patient_level_df['pred_ensemble'].values
y_patient_prob_ensemble = patient_level_df['prob_ensemble'].values

# Evaluate ensemble at patient level
patient_metrics_ensemble = {
    'accuracy': accuracy_score(y_patient_true, y_patient_pred_ensemble),
    'roc_auc': roc_auc_score(y_patient_true, y_patient_prob_ensemble),
    'f1': f1_score(y_patient_true, y_patient_pred_ensemble, zero_division=0),
    'precision': precision_score(y_patient_true, y_patient_pred_ensemble, zero_division=0),
    'recall': recall_score(y_patient_true, y_patient_pred_ensemble, zero_division=0)
}

# Evaluate individual models at patient level
y_patient_pred_nn = patient_level_df['pred_nn'].values
y_patient_prob_nn = patient_level_df['prob_nn'].values
patient_metrics_nn = {
    'accuracy': accuracy_score(y_patient_true, y_patient_pred_nn),
    'roc_auc': roc_auc_score(y_patient_true, y_patient_prob_nn),
    'f1': f1_score(y_patient_true, y_patient_pred_nn, zero_division=0),
    'precision': precision_score(y_patient_true, y_patient_pred_nn, zero_division=0),
    'recall': recall_score(y_patient_true, y_patient_pred_nn, zero_division=0)
}

y_patient_pred_rf = patient_level_df['pred_rf'].values
y_patient_prob_rf = patient_level_df['prob_rf'].values
patient_metrics_rf = {
    'accuracy': accuracy_score(y_patient_true, y_patient_pred_rf),
    'roc_auc': roc_auc_score(y_patient_true, y_patient_prob_rf),
    'f1': f1_score(y_patient_true, y_patient_pred_rf, zero_division=0),
    'precision': precision_score(y_patient_true, y_patient_pred_rf, zero_division=0),
    'recall': recall_score(y_patient_true, y_patient_pred_rf, zero_division=0)
}

y_patient_pred_xgb = patient_level_df['pred_xgb'].values
y_patient_prob_xgb = patient_level_df['prob_xgb'].values
patient_metrics_xgb = {
    'accuracy': accuracy_score(y_patient_true, y_patient_pred_xgb),
    'roc_auc': roc_auc_score(y_patient_true, y_patient_prob_xgb),
    'f1': f1_score(y_patient_true, y_patient_pred_xgb, zero_division=0),
    'precision': precision_score(y_patient_true, y_patient_pred_xgb, zero_division=0),
    'recall': recall_score(y_patient_true, y_patient_pred_xgb, zero_division=0)
}

y_patient_pred_lr = patient_level_df['pred_lr'].values
y_patient_prob_lr = patient_level_df['prob_lr'].values
patient_metrics_lr = {
    'accuracy': accuracy_score(y_patient_true, y_patient_pred_lr),
    'roc_auc': roc_auc_score(y_patient_true, y_patient_prob_lr),
    'f1': f1_score(y_patient_true, y_patient_pred_lr, zero_division=0),
    'precision': precision_score(y_patient_true, y_patient_pred_lr, zero_division=0),
    'recall': recall_score(y_patient_true, y_patient_pred_lr, zero_division=0)
}

print("\n" + "=" * 60)
print("ENSEMBLE vs INDIVIDUAL MODELS (Patient Level)")
print("=" * 60)
print(f"Ensemble:")
print(f"  Acc: {patient_metrics_ensemble['accuracy']:.4f}, ROC-AUC: {patient_metrics_ensemble['roc_auc']:.4f}, F1: {patient_metrics_ensemble['f1']:.4f}")
print(f"\nIndividual Models:")
print(f"  NN:  Acc: {patient_metrics_nn['accuracy']:.4f}, ROC-AUC: {patient_metrics_nn['roc_auc']:.4f}, F1: {patient_metrics_nn['f1']:.4f}")
print(f"  RF:  Acc: {patient_metrics_rf['accuracy']:.4f}, ROC-AUC: {patient_metrics_rf['roc_auc']:.4f}, F1: {patient_metrics_rf['f1']:.4f}")
print(f"  XGB: Acc: {patient_metrics_xgb['accuracy']:.4f}, ROC-AUC: {patient_metrics_xgb['roc_auc']:.4f}, F1: {patient_metrics_xgb['f1']:.4f}")
print(f"  LR:  Acc: {patient_metrics_lr['accuracy']:.4f}, ROC-AUC: {patient_metrics_lr['roc_auc']:.4f}, F1: {patient_metrics_lr['f1']:.4f}")
print("=" * 60)

# Save patient-level results
patient_results = {
    'model': 'Ensemble (Weighted)',
    'level': 'Patient',
    'accuracy': patient_metrics_ensemble['accuracy'],
    'roc_auc': patient_metrics_ensemble['roc_auc'],
    'f1': patient_metrics_ensemble['f1'],
    'precision': patient_metrics_ensemble['precision'],
    'recall': patient_metrics_ensemble['recall']
}
pd.DataFrame([patient_results]).to_csv(OUTPUT_DIR / 'ensemble_patient_level_results.csv', index=False)
print(f"\n✓ Saved patient-level results to: {OUTPUT_DIR / 'ensemble_patient_level_results.csv'}")
# Out:
# ============================================================
# ENSEMBLE: PATIENT-LEVEL EVALUATION
# ============================================================
#
# ============================================================
# ENSEMBLE vs INDIVIDUAL MODELS (Patient Level)
# ============================================================
# Ensemble:
#   Acc: 0.5556, ROC-AUC: 0.5000, F1: 0.5000
#
# Individual Models:
#   NN:  Acc: 0.4444, ROC-AUC: 0.5000, F1: 0.4444
#   RF:  Acc: 0.3333, ROC-AUC: 0.4500, F1: 0.2500
#   XGB: Acc: 0.5556, ROC-AUC: 0.5500, F1: 0.5000
#   LR:  Acc: 0.5556, ROC-AUC: 0.3500, F1: 0.6000
# ============================================================
#
# ✓ Saved patient-level results to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/ensemble_patient_level_results.csv

# %% [markdown]
# ### 14.3. Recording-Level vs Patient-Level Comparison

# %%
# ============================================================
# Recording-Level vs Patient-Level Comparison
# ============================================================

print("=" * 60)
print("RECORDING-LEVEL vs PATIENT-LEVEL COMPARISON")
print("=" * 60)

comparison_data = {
    'Level': ['Recording', 'Patient'],
    'Accuracy': [test_metrics_ensemble['accuracy'], patient_metrics_ensemble['accuracy']],
    'ROC-AUC': [test_metrics_ensemble['roc_auc'], patient_metrics_ensemble['roc_auc']],
    'F1': [test_metrics_ensemble['f1'], patient_metrics_ensemble['f1']],
    'Precision': [test_metrics_ensemble['precision'], patient_metrics_ensemble['precision']],
    'Recall': [test_metrics_ensemble['recall'], patient_metrics_ensemble['recall']]
}

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "=" * 80)
print("ENSEMBLE PERFORMANCE: RECORDING vs PATIENT LEVEL")
print("=" * 80)
print(comparison_df.to_string(index=False))
print("=" * 80)

# Save comparison
comparison_df.to_csv(OUTPUT_DIR / 'recording_vs_patient_level_comparison.csv', index=False)
print(f"\n✓ Saved comparison to: {OUTPUT_DIR / 'recording_vs_patient_level_comparison.csv'}")

# Visualization
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

levels = comparison_df['Level'].values
accs = comparison_df['Accuracy'].values
rocs = comparison_df['ROC-AUC'].values
f1s = comparison_df['F1'].values

x = np.arange(len(levels))
width = 0.6

# Accuracy
axes[0].bar(x, accs, width, alpha=0.8, color=['steelblue', 'darkorange'])
axes[0].set_xlabel('Level', fontsize=12)
axes[0].set_ylabel('Accuracy', fontsize=12)
axes[0].set_title('Accuracy: Recording vs Patient Level', fontsize=14, fontweight='bold')
axes[0].set_xticks(x)
axes[0].set_xticklabels(levels)
axes[0].set_ylim([0, 1.05])
axes[0].grid(True, alpha=0.3, axis='y')
for i, v in enumerate(accs):
    axes[0].text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom', fontweight='bold')

# ROC-AUC
axes[1].bar(x, rocs, width, alpha=0.8, color=['steelblue', 'darkorange'])
axes[1].set_xlabel('Level', fontsize=12)
axes[1].set_ylabel('ROC-AUC', fontsize=12)
axes[1].set_title('ROC-AUC: Recording vs Patient Level', fontsize=14, fontweight='bold')
axes[1].set_xticks(x)
axes[1].set_xticklabels(levels)
axes[1].set_ylim([0, 1.05])
axes[1].grid(True, alpha=0.3, axis='y')
for i, v in enumerate(rocs):
    axes[1].text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom', fontweight='bold')

# F1
axes[2].bar(x, f1s, width, alpha=0.8, color=['steelblue', 'darkorange'])
axes[2].set_xlabel('Level', fontsize=12)
axes[2].set_ylabel('F1 Score', fontsize=12)
axes[2].set_title('F1 Score: Recording vs Patient Level', fontsize=14, fontweight='bold')
axes[2].set_xticks(x)
axes[2].set_xticklabels(levels)
axes[2].set_ylim([0, 1.05])
axes[2].grid(True, alpha=0.3, axis='y')
for i, v in enumerate(f1s):
    axes[2].text(i, v + 0.02, f'{v:.3f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'recording_vs_patient_level_comparison.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved visualization to: {OUTPUT_DIR / 'recording_vs_patient_level_comparison.png'}")
print("=" * 60)
# Out:
# ============================================================
# RECORDING-LEVEL vs PATIENT-LEVEL COMPARISON
# ============================================================
#
# ================================================================================
# ENSEMBLE PERFORMANCE: RECORDING vs PATIENT LEVEL
# ================================================================================
#     Level  Accuracy  ROC-AUC       F1  Precision   Recall
# Recording  0.631124  0.77609 0.671795   0.879195 0.543568
#   Patient  0.555556  0.50000 0.500000   0.500000 0.500000
# ================================================================================
#
# ✓ Saved comparison to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/recording_vs_patient_level_comparison.csv
# ✓ Saved visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/recording_vs_patient_level_comparison.png
# ============================================================

# %% [markdown]
# ### 14.4. Patient-Level Confusion Matrix and ROC Curve

# %%
# ============================================================
# Patient-Level Confusion Matrix and ROC Curve
# ============================================================

print("=" * 60)
print("PATIENT-LEVEL VISUALIZATIONS")
print("=" * 60)

# Confusion Matrix
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Confusion Matrix
cm_patient = confusion_matrix(y_patient_true, y_patient_pred_ensemble)
sns.heatmap(cm_patient, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=['Control', 'PD'], yticklabels=['Control', 'PD'])
axes[0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
axes[0].set_ylabel('True', fontsize=12, fontweight='bold')
axes[0].set_title('Confusion Matrix: Patient Level', fontsize=14, fontweight='bold')

# ROC Curve
fpr_patient, tpr_patient, _ = roc_curve(y_patient_true, y_patient_prob_ensemble)
axes[1].plot(fpr_patient, tpr_patient, linewidth=2, label=f'Ensemble (AUC = {patient_metrics_ensemble["roc_auc"]:.3f})')
axes[1].plot([0, 1], [0, 1], 'k--', linewidth=1, label='Random')
axes[1].set_xlabel('False Positive Rate', fontsize=12)
axes[1].set_ylabel('True Positive Rate', fontsize=12)
axes[1].set_title('ROC Curve: Patient Level', fontsize=14, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'patient_level_confusion_roc.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved visualization to: {OUTPUT_DIR / 'patient_level_confusion_roc.png'}")

# Print classification report
print("\n" + "=" * 60)
print("PATIENT-LEVEL CLASSIFICATION REPORT")
print("=" * 60)
print(classification_report(y_patient_true, y_patient_pred_ensemble, 
                          target_names=['Control', 'PD']))
print("=" * 60)
# Out:
# ============================================================
# PATIENT-LEVEL VISUALIZATIONS
# ============================================================
# ✓ Saved visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/patient_level_confusion_roc.png
#
# ============================================================
# PATIENT-LEVEL CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#      Control       0.60      0.60      0.60         5
#           PD       0.50      0.50      0.50         4
#
#     accuracy                           0.56         9
#    macro avg       0.55      0.55      0.55         9
# weighted avg       0.56      0.56      0.56         9
#
# ============================================================

# %% [markdown]
# ### 14.5. Final Summary: All Models and Levels

# %%
# ============================================================
# Final Summary: All Models at Recording and Patient Level
# ============================================================

print("=" * 60)
print("FINAL SUMMARY: ALL MODELS AND LEVELS")
print("=" * 60)

# Collect all results
all_results = []

# Recording level
all_results.append({
    'Model': 'Ensemble',
    'Level': 'Recording',
    'Accuracy': test_metrics_ensemble['accuracy'],
    'ROC-AUC': test_metrics_ensemble['roc_auc'],
    'F1': test_metrics_ensemble['f1']
})
all_results.append({
    'Model': 'Neural Network',
    'Level': 'Recording',
    'Accuracy': test_metrics_nn_ft['accuracy'],
    'ROC-AUC': test_metrics_nn_ft['roc_auc'],
    'F1': test_metrics_nn_ft['f1']
})
all_results.append({
    'Model': 'Random Forest',
    'Level': 'Recording',
    'Accuracy': test_metrics_rf_ft['accuracy'],
    'ROC-AUC': test_metrics_rf_ft['roc_auc'],
    'F1': test_metrics_rf_ft['f1']
})
all_results.append({
    'Model': 'XGBoost',
    'Level': 'Recording',
    'Accuracy': test_metrics_xgb_ft['accuracy'],
    'ROC-AUC': test_metrics_xgb_ft['roc_auc'],
    'F1': test_metrics_xgb_ft['f1']
})
all_results.append({
    'Model': 'Logistic Regression',
    'Level': 'Recording',
    'Accuracy': test_metrics_lr_ft['accuracy'],
    'ROC-AUC': test_metrics_lr_ft['roc_auc'],
    'F1': test_metrics_lr_ft['f1']
})

# Patient level
all_results.append({
    'Model': 'Ensemble',
    'Level': 'Patient',
    'Accuracy': patient_metrics_ensemble['accuracy'],
    'ROC-AUC': patient_metrics_ensemble['roc_auc'],
    'F1': patient_metrics_ensemble['f1']
})
all_results.append({
    'Model': 'Neural Network',
    'Level': 'Patient',
    'Accuracy': patient_metrics_nn['accuracy'],
    'ROC-AUC': patient_metrics_nn['roc_auc'],
    'F1': patient_metrics_nn['f1']
})
all_results.append({
    'Model': 'Random Forest',
    'Level': 'Patient',
    'Accuracy': patient_metrics_rf['accuracy'],
    'ROC-AUC': patient_metrics_rf['roc_auc'],
    'F1': patient_metrics_rf['f1']
})
all_results.append({
    'Model': 'XGBoost',
    'Level': 'Patient',
    'Accuracy': patient_metrics_xgb['accuracy'],
    'ROC-AUC': patient_metrics_xgb['roc_auc'],
    'F1': patient_metrics_xgb['f1']
})
all_results.append({
    'Model': 'Logistic Regression',
    'Level': 'Patient',
    'Accuracy': patient_metrics_lr['accuracy'],
    'ROC-AUC': patient_metrics_lr['roc_auc'],
    'F1': patient_metrics_lr['f1']
})

final_summary_df = pd.DataFrame(all_results)

print("\n" + "=" * 80)
print("COMPLETE RESULTS SUMMARY")
print("=" * 80)
print(final_summary_df.to_string(index=False))
print("=" * 80)

# Save final summary
final_summary_df.to_csv(OUTPUT_DIR / 'final_summary_all_models_levels.csv', index=False)
print(f"\n✓ Saved final summary to: {OUTPUT_DIR / 'final_summary_all_models_levels.csv'}")

# Create comprehensive visualization
fig, axes = plt.subplots(2, 3, figsize=(20, 12))

# Recording level metrics
recording_df = final_summary_df[final_summary_df['Level'] == 'Recording']
models_rec = recording_df['Model'].values
accs_rec = recording_df['Accuracy'].values
rocs_rec = recording_df['ROC-AUC'].values
f1s_rec = recording_df['F1'].values

x_rec = np.arange(len(models_rec))
width = 0.6

axes[0, 0].bar(x_rec, accs_rec, width, alpha=0.8)
axes[0, 0].set_xlabel('Model', fontsize=12)
axes[0, 0].set_ylabel('Accuracy', fontsize=12)
axes[0, 0].set_title('Accuracy: Recording Level', fontsize=14, fontweight='bold')
axes[0, 0].set_xticks(x_rec)
axes[0, 0].set_xticklabels(models_rec, rotation=45, ha='right')
axes[0, 0].grid(True, alpha=0.3, axis='y')
axes[0, 0].set_ylim([0, 1.05])

axes[0, 1].bar(x_rec, rocs_rec, width, alpha=0.8)
axes[0, 1].set_xlabel('Model', fontsize=12)
axes[0, 1].set_ylabel('ROC-AUC', fontsize=12)
axes[0, 1].set_title('ROC-AUC: Recording Level', fontsize=14, fontweight='bold')
axes[0, 1].set_xticks(x_rec)
axes[0, 1].set_xticklabels(models_rec, rotation=45, ha='right')
axes[0, 1].grid(True, alpha=0.3, axis='y')
axes[0, 1].set_ylim([0, 1.05])

axes[0, 2].bar(x_rec, f1s_rec, width, alpha=0.8)
axes[0, 2].set_xlabel('Model', fontsize=12)
axes[0, 2].set_ylabel('F1 Score', fontsize=12)
axes[0, 2].set_title('F1 Score: Recording Level', fontsize=14, fontweight='bold')
axes[0, 2].set_xticks(x_rec)
axes[0, 2].set_xticklabels(models_rec, rotation=45, ha='right')
axes[0, 2].grid(True, alpha=0.3, axis='y')
axes[0, 2].set_ylim([0, 1.05])

# Patient level metrics
patient_df = final_summary_df[final_summary_df['Level'] == 'Patient']
models_pat = patient_df['Model'].values
accs_pat = patient_df['Accuracy'].values
rocs_pat = patient_df['ROC-AUC'].values
f1s_pat = patient_df['F1'].values

x_pat = np.arange(len(models_pat))

axes[1, 0].bar(x_pat, accs_pat, width, alpha=0.8, color='darkorange')
axes[1, 0].set_xlabel('Model', fontsize=12)
axes[1, 0].set_ylabel('Accuracy', fontsize=12)
axes[1, 0].set_title('Accuracy: Patient Level', fontsize=14, fontweight='bold')
axes[1, 0].set_xticks(x_pat)
axes[1, 0].set_xticklabels(models_pat, rotation=45, ha='right')
axes[1, 0].grid(True, alpha=0.3, axis='y')
axes[1, 0].set_ylim([0, 1.05])

axes[1, 1].bar(x_pat, rocs_pat, width, alpha=0.8, color='darkorange')
axes[1, 1].set_xlabel('Model', fontsize=12)
axes[1, 1].set_ylabel('ROC-AUC', fontsize=12)
axes[1, 1].set_title('ROC-AUC: Patient Level', fontsize=14, fontweight='bold')
axes[1, 1].set_xticks(x_pat)
axes[1, 1].set_xticklabels(models_pat, rotation=45, ha='right')
axes[1, 1].grid(True, alpha=0.3, axis='y')
axes[1, 1].set_ylim([0, 1.05])

axes[1, 2].bar(x_pat, f1s_pat, width, alpha=0.8, color='darkorange')
axes[1, 2].set_xlabel('Model', fontsize=12)
axes[1, 2].set_ylabel('F1 Score', fontsize=12)
axes[1, 2].set_title('F1 Score: Patient Level', fontsize=14, fontweight='bold')
axes[1, 2].set_xticks(x_pat)
axes[1, 2].set_xticklabels(models_pat, rotation=45, ha='right')
axes[1, 2].grid(True, alpha=0.3, axis='y')
axes[1, 2].set_ylim([0, 1.05])

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'final_summary_all_models_levels.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved final visualization to: {OUTPUT_DIR / 'final_summary_all_models_levels.png'}")
print("=" * 60)
# Out:
# ============================================================
# FINAL SUMMARY: ALL MODELS AND LEVELS
# ============================================================
#
# ================================================================================
# COMPLETE RESULTS SUMMARY
# ================================================================================
#               Model     Level  Accuracy  ROC-AUC       F1
#            Ensemble Recording  0.631124 0.776090 0.671795
#      Neural Network Recording  0.654179 0.733970 0.710145
#       Random Forest Recording  0.622478 0.788812 0.652520
#             XGBoost Recording  0.628242 0.760276 0.656000
# Logistic Regression Recording  0.622478 0.672512 0.684337
#            Ensemble   Patient  0.555556 0.500000 0.500000
#      Neural Network   Patient  0.444444 0.500000 0.444444
#       Random Forest   Patient  0.333333 0.450000 0.250000
#             XGBoost   Patient  0.555556 0.550000 0.500000
# Logistic Regression   Patient  0.555556 0.350000 0.600000
# ================================================================================
#
# ✓ Saved final summary to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/final_summary_all_models_levels.csv
# ✓ Saved final visualization to: /home/Phenotype and Voice for PD/outputs/cluster_14_baseline/final_summary_all_models_levels.png
# ============================================================

# %% [markdown]
# ## 15. Patient-Level Synthetic Data Training
#
# **This section implements a novel approach:**
# 1. Aggregates synthetic data by cluster (mean) → then by synthetic patient (median)
# 2. Aggregates real data by cluster (mean) → then by real patient (median)
# 3. Trains models on patient-level synthetic data
# 4. Validates and tests on patient-level real data
#
# **Benefits:**
# - Reduces issues related to synthetic data quality at recording level
# - Analysis at more aggregate level (patient-level)
# - Better alignment between synthetic and real data distributions

# %%
# ============================================================
# 15.1. Load and Aggregate Synthetic Data to Patient Level
# ============================================================

print("=" * 60)
print("PATIENT-LEVEL SYNTHETIC DATA PREPARATION")
print("=" * 60)

# Load synthetic data (same as Section 11)
VAE_SYNTHETIC_FILE = ROOT / 'outputs' / 'vae_standalone' / 'synthetic_vae_data.csv'

if not VAE_SYNTHETIC_FILE.exists():
    raise FileNotFoundError(
        f"VAE synthetic data file not found: {VAE_SYNTHETIC_FILE}\n"
        f"Please run the VAE_Synthetic_Data_Generation_Standalone_v2 notebook first."
    )

# Load synthetic data
syn_df = pd.read_csv(VAE_SYNTHETIC_FILE)
print(f"\n✓ Loaded synthetic data: {syn_df.shape}")

# Check if it has a 'label' column
if 'label' not in syn_df.columns:
    n_samples = len(syn_df)
    n_ctrl = n_samples // 2
    syn_df['label'] = [0] * n_ctrl + [1] * (n_samples - n_ctrl)

print(f"  Labels: {np.bincount(syn_df['label'].astype(int))} (Control: {np.sum(syn_df['label']==0)}, PD: {np.sum(syn_df['label']==1)})")

# Extract features (exclude label)
syn_feature_cols = [col for col in syn_df.columns if col != 'label']
X_syn_raw = syn_df[syn_feature_cols].copy()
y_syn_raw = syn_df['label'].astype(int).copy()

print(f"\n✓ Synthetic features extracted: {X_syn_raw.shape}")

# Step 1: Aggregate synthetic features by cluster (mean)
print("\n" + "-" * 60)
print("STEP 1: AGGREGATING SYNTHETIC FEATURES BY CLUSTER (MEAN)")
print("-" * 60)

# Use common features between synthetic and original
common_features = [f for f in syn_feature_cols if f in original_feature_cols]
print(f"  Common features: {len(common_features)} (synthetic has {len(syn_feature_cols)}, original has {len(original_feature_cols)})")

if len(common_features) < len(original_feature_cols):
    print(f"  ⚠ Warning: Feature mismatch. Using {len(common_features)} common features.")

# Aggregate by cluster
X_syn_agg, _ = aggregate_features_by_cluster(
    X_syn_raw[common_features].values, 
    common_features, 
    cluster_to_features, 
    aggregation='mean'
)

print(f"✓ Synthetic features aggregated: {len(common_features)} → {X_syn_agg.shape[1]} clusters")

# Step 2: Create synthetic participant IDs and aggregate by patient (median)
print("\n" + "-" * 60)
print("STEP 2: CREATING SYNTHETIC PATIENT IDs AND AGGREGATING BY PATIENT (MEDIAN)")
print("-" * 60)

# Create synthetic participant IDs
# Strategy: Group synthetic recordings into synthetic patients
# Use a reasonable number of recordings per synthetic patient (e.g., 5-10)
# This mimics real-world scenario where each patient has multiple recordings

n_recordings_per_patient = 5  # Average recordings per patient
n_syn_patients = len(X_syn_agg) // n_recordings_per_patient

# Create synthetic participant IDs
syn_participant_ids = []
for i in range(len(X_syn_agg)):
    syn_participant_ids.append(f"syn_patient_{i // n_recordings_per_patient}")

syn_participant_ids = np.array(syn_participant_ids)
print(f"  Created {len(np.unique(syn_participant_ids))} synthetic patients")
print(f"  Average recordings per synthetic patient: {len(X_syn_agg) / len(np.unique(syn_participant_ids)):.1f}")

# Aggregate synthetic data by synthetic patient (mean)
syn_patient_df = pd.DataFrame(X_syn_agg, columns=[f"cluster_{i+1}" for i in range(X_syn_agg.shape[1])])
syn_patient_df['syn_participant_id'] = syn_participant_ids
syn_patient_df['label'] = y_syn_raw.values

# Aggregate by synthetic patient using median
X_syn_patient = syn_patient_df.groupby('syn_participant_id').agg({
    **{f"cluster_{i+1}": 'median' for i in range(X_syn_agg.shape[1])},
    'label': 'first'  # All recordings from same synthetic patient have same label
}).reset_index()

# Extract features and labels
X_syn_patient_features = X_syn_patient[[f"cluster_{i+1}" for i in range(X_syn_agg.shape[1])]].values
y_syn_patient = X_syn_patient['label'].values

print(f"✓ Synthetic data aggregated to patient level:")
print(f"  Patients: {len(X_syn_patient)}")
print(f"  Features: {X_syn_patient_features.shape[1]} (cluster-aggregated)")
print(f"  Labels: {np.bincount(y_syn_patient.astype(int))} (Control: {np.sum(y_syn_patient==0)}, PD: {np.sum(y_syn_patient==1)})")

# Standardize synthetic patient-level data using the aggregated scaler
if 'global_scaler_agg' in globals():
    X_syn_patient_scaled = global_scaler_agg.transform(X_syn_patient_features.astype(np.float32))
else:
    # Fallback: create new scaler
    print("  ⚠ Warning: global_scaler_agg not found. Creating new scaler.")
    from sklearn.preprocessing import StandardScaler
    temp_scaler = StandardScaler()
    X_syn_patient_scaled = temp_scaler.fit_transform(X_syn_patient_features.astype(np.float32))

# Clip extreme values
X_syn_patient_scaled = np.clip(X_syn_patient_scaled, -8.0, 8.0)

print(f"✓ Synthetic patient-level data standardized and ready")
print(f"  Final shape: {X_syn_patient_scaled.shape}")
print("=" * 60)
# Out:
# ============================================================
# PATIENT-LEVEL SYNTHETIC DATA PREPARATION
# ============================================================
#
# ✓ Loaded synthetic data: (61420, 133)
#   Labels: [30710 30710] (Control: 30710, PD: 30710)
#
# ✓ Synthetic features extracted: (61420, 133)
#
# ------------------------------------------------------------
# STEP 1: AGGREGATING SYNTHETIC FEATURES BY CLUSTER (MEAN)
# ------------------------------------------------------------
#   Common features: 131 (synthetic has 133, original has 131)
# ✓ Synthetic features aggregated: 131 → 14 clusters
#
# ------------------------------------------------------------
# STEP 2: CREATING SYNTHETIC PATIENT IDs AND AGGREGATING BY PATIENT (MEDIAN)
# ------------------------------------------------------------
#   Created 12284 synthetic patients
#   Average recordings per synthetic patient: 5.0
# ✓ Synthetic data aggregated to patient level:
#   Patients: 12284
#   Features: 14 (cluster-aggregated)
#   Labels: [6142 6142] (Control: 6142, PD: 6142)
# ✓ Synthetic patient-level data standardized and ready
#   Final shape: (12284, 14)
# ============================================================

# %%
# ============================================================
# 15.2. Aggregate Real Data to Patient Level
# ============================================================

print("=" * 60)
print("AGGREGATING REAL DATA TO PATIENT LEVEL")
print("=" * 60)

# We need to aggregate the original real data (before cluster aggregation) to patient level
# Then apply cluster aggregation, then patient aggregation

# Get original real data splits (from Section 4)
# X_train_raw, X_val_raw, X_test_raw are the original 131-feature data
# pid_train, pid_val, pid_test are the participant IDs

print("\nStep 1: Aggregate original features by cluster (mean) for each split...")

# Aggregate train data by cluster
X_train_agg_for_patient, _ = aggregate_features_by_cluster(
    X_train_raw.values, 
    original_feature_cols, 
    cluster_to_features, 
    aggregation='mean'
)

# Aggregate val data by cluster
X_val_agg_for_patient, _ = aggregate_features_by_cluster(
    X_val_raw.values, 
    original_feature_cols, 
    cluster_to_features, 
    aggregation='mean'
)

# Aggregate test data by cluster
X_test_agg_for_patient, _ = aggregate_features_by_cluster(
    X_test_raw.values, 
    original_feature_cols, 
    cluster_to_features, 
    aggregation='mean'
)

print(f"✓ Cluster aggregation complete:")
print(f"  Train: {X_train_agg_for_patient.shape}")
print(f"  Val: {X_val_agg_for_patient.shape}")
print(f"  Test: {X_test_agg_for_patient.shape}")

print("\nStep 2: Aggregate by patient (median) for each split...")

# Create DataFrames with cluster features and participant IDs
train_df = pd.DataFrame(
    X_train_agg_for_patient, 
    columns=[f"cluster_{i+1}" for i in range(X_train_agg_for_patient.shape[1])]
)
train_df['participant_id'] = pid_train
train_df['label'] = y_train_raw.values.flatten()

val_df = pd.DataFrame(
    X_val_agg_for_patient, 
    columns=[f"cluster_{i+1}" for i in range(X_val_agg_for_patient.shape[1])]
)
val_df['participant_id'] = pid_val
val_df['label'] = y_val_raw.values.flatten()

test_df = pd.DataFrame(
    X_test_agg_for_patient, 
    columns=[f"cluster_{i+1}" for i in range(X_test_agg_for_patient.shape[1])]
)
test_df['participant_id'] = pid_test
test_df['label'] = y_test_raw.values.flatten()

# Aggregate by patient using median
X_train_patient = train_df.groupby('participant_id').agg({
    **{f"cluster_{i+1}": 'median' for i in range(X_train_agg_for_patient.shape[1])},
    'label': 'first'
}).reset_index()

X_val_patient = val_df.groupby('participant_id').agg({
    **{f"cluster_{i+1}": 'median' for i in range(X_val_agg_for_patient.shape[1])},
    'label': 'first'
}).reset_index()

X_test_patient = test_df.groupby('participant_id').agg({
    **{f"cluster_{i+1}": 'median' for i in range(X_test_agg_for_patient.shape[1])},
    'label': 'first'
}).reset_index()

# Extract features and labels
X_train_patient_features = X_train_patient[[f"cluster_{i+1}" for i in range(X_train_agg_for_patient.shape[1])]].values
y_train_patient = X_train_patient['label'].values
pid_train_patient = X_train_patient['participant_id'].values

X_val_patient_features = X_val_patient[[f"cluster_{i+1}" for i in range(X_val_agg_for_patient.shape[1])]].values
y_val_patient = X_val_patient['label'].values
pid_val_patient = X_val_patient['participant_id'].values

X_test_patient_features = X_test_patient[[f"cluster_{i+1}" for i in range(X_test_agg_for_patient.shape[1])]].values
y_test_patient = X_test_patient['label'].values
pid_test_patient = X_test_patient['participant_id'].values

print(f"✓ Real data aggregated to patient level:")
print(f"  Train: {len(X_train_patient)} patients, Labels: {np.bincount(y_train_patient.astype(int))}")
print(f"  Val: {len(X_val_patient)} patients, Labels: {np.bincount(y_val_patient.astype(int))}")
print(f"  Test: {len(X_test_patient)} patients, Labels: {np.bincount(y_test_patient.astype(int))}")

# Standardize using the aggregated scaler (fitted on training data)
if 'global_scaler_agg' in globals():
    X_train_patient_scaled = global_scaler_agg.transform(X_train_patient_features.astype(np.float32))
    X_val_patient_scaled = global_scaler_agg.transform(X_val_patient_features.astype(np.float32))
    X_test_patient_scaled = global_scaler_agg.transform(X_test_patient_features.astype(np.float32))
else:
    # Fallback: create new scaler fitted on training data
    print("  ⚠ Warning: global_scaler_agg not found. Creating new scaler.")
    from sklearn.preprocessing import StandardScaler
    patient_scaler = StandardScaler()
    X_train_patient_scaled = patient_scaler.fit_transform(X_train_patient_features.astype(np.float32))
    X_val_patient_scaled = patient_scaler.transform(X_val_patient_features.astype(np.float32))
    X_test_patient_scaled = patient_scaler.transform(X_test_patient_features.astype(np.float32))

# Clip extreme values
X_train_patient_scaled = np.clip(X_train_patient_scaled, -8.0, 8.0)
X_val_patient_scaled = np.clip(X_val_patient_scaled, -8.0, 8.0)
X_test_patient_scaled = np.clip(X_test_patient_scaled, -8.0, 8.0)

print(f"\n✓ Real patient-level data standardized and ready")
print(f"  Train: {X_train_patient_scaled.shape}")
print(f"  Val: {X_val_patient_scaled.shape}")
print(f"  Test: {X_test_patient_scaled.shape}")
print("=" * 60)
# Out:
# ============================================================
# AGGREGATING REAL DATA TO PATIENT LEVEL
# ============================================================
#
# Step 1: Aggregate original features by cluster (mean) for each split...
# ✓ Cluster aggregation complete:
#   Train: (3071, 14)
#   Val: (832, 14)
#   Test: (976, 14)
#
# Step 2: Aggregate by patient (median) for each split...
# ✓ Real data aggregated to patient level:
#   Train: 80 patients, Labels: [41 39]
#   Val: 20 patients, Labels: [10 10]
#   Test: 25 patients, Labels: [13 12]
#
# ✓ Real patient-level data standardized and ready
#   Train: (80, 14)
#   Val: (20, 14)
#   Test: (25, 14)
# ============================================================

# %% [markdown]
# ### 15.3. Train Models on Patient-Level Synthetic Data

# %%
# ============================================================
# Device Selection with Safe CPU Fallback
# ============================================================

def get_device():
    # Try to use CUDA if available, otherwise CPU
    if torch.cuda.is_available():
        try:
            device = torch.device("cuda")
            # Try a tiny allocation to check if CUDA is actually usable
            _ = torch.tensor([0.0], device=device)
            print("✅ Using CUDA GPU")
            return device
        except RuntimeError as e:
            # If OOM or other CUDA error, fall back to CPU
            print(f"⚠️ CUDA error ({e}); falling back to CPU.")
            return torch.device("cpu")
    else:
        print("⚠️ CUDA not available, using CPU.")
        return torch.device("cpu")

DEVICE = get_device()
print("Final DEVICE:", DEVICE)
# Out:
# ⚠️ CUDA error (CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# ); falling back to CPU.
# Final DEVICE: cpu

# %%
# ============================================================
# Train Neural Network on Patient-Level Synthetic Data
# ============================================================

print("=" * 60)
print("NEURAL NETWORK: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA")
print("=" * 60)

# Initialize model for patient-level data (14 features)
# RegularizedHybridNet only takes input_dim as parameter (architecture is fixed)
model_nn_patient_syn = RegularizedHybridNet(input_dim=14).to(DEVICE)

# Create DataLoaders for patient-level synthetic data
from torch.utils.data import TensorDataset, DataLoader

train_dataset_patient = TensorDataset(
    torch.FloatTensor(X_syn_patient_scaled),
    torch.LongTensor(y_syn_patient)
)
# Use batch_size=32 (same as Section 11) - patient-level data has fewer samples
batch_size_patient = 32
train_loader_patient = DataLoader(train_dataset_patient, batch_size=batch_size_patient, shuffle=True)

val_dataset_patient = TensorDataset(
    torch.FloatTensor(X_val_patient_scaled),
    torch.LongTensor(y_val_patient)
)
val_loader_patient = DataLoader(val_dataset_patient, batch_size=batch_size_patient, shuffle=False)

test_dataset_patient = TensorDataset(
    torch.FloatTensor(X_test_patient_scaled),
    torch.LongTensor(y_test_patient)
)
test_loader_patient = DataLoader(test_dataset_patient, batch_size=batch_size_patient, shuffle=False)

# Train on patient-level synthetic data
print("\nTraining on patient-level synthetic data...")
model_nn_patient_syn, train_history_patient, best_epoch_patient = train_model_with_checkpointing(
    model_nn_patient_syn,
    train_loader_patient,
    val_loader_patient,
    epochs=40,  # Same as used in other sections
    lr=nn_best_params.get('lr', 6e-4),
    weight_decay=nn_best_params.get('weight_decay', 8e-3),
    patience=10
)

# Evaluate on patient-level real data
print("\nEvaluating on patient-level real validation set...")
val_metrics_nn_patient_syn = evaluate_on_real(model_nn_patient_syn, val_loader_patient, DEVICE)

print("\nEvaluating on patient-level real test set...")
test_metrics_nn_patient_syn = evaluate_on_real(model_nn_patient_syn, test_loader_patient, DEVICE)

print("\n" + "=" * 60)
print("NEURAL NETWORK RESULTS (Patient-Level Synthetic Training)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_nn_patient_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_nn_patient_syn['roc_auc']:.4f}, F1: {val_metrics_nn_patient_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_nn_patient_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_nn_patient_syn['roc_auc']:.4f}, F1: {test_metrics_nn_patient_syn['f1']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# NEURAL NETWORK: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA
# ============================================================
#
# Training on patient-level synthetic data...
# Training on device: cpu
# Epochs: 40, LR: 6e-04, Weight decay: 8e-03
# ============================================================
# Epoch   1/40: train_loss=0.5484, val_loss=1.1303, train_acc=0.798, val_acc=0.600, val_roc_auc=0.6000
# Epoch  10/40: train_loss=0.3857, val_loss=1.9951, train_acc=0.959, val_acc=0.500, val_roc_auc=0.7500
# Epoch  20/40: train_loss=0.3743, val_loss=2.0057, train_acc=0.967, val_acc=0.500, val_roc_auc=0.6900
#
# ⏹ Early stopping at epoch 21. Best epoch: 11 (AUC 0.7700)
#
# ✓ Loaded best model from epoch 11 (Val ROC-AUC: 0.7700)
#
# Evaluating on patient-level real validation set...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 50
#      48 # Evaluate on patient-level real data
#      49 print("\nEvaluating on patient-level real validation set...")
# ---> 50 val_metrics_nn_patient_syn = evaluate_on_real(model_nn_patient_syn, val_loader_patient, DEVICE)
#      52 print("\nEvaluating on patient-level real test set...")
#      53 test_metrics_nn_patient_syn = evaluate_on_real(model_nn_patient_syn, test_loader_patient, DEVICE)
#
# Cell In[8], line 58, in evaluate_on_real(model, loader, threshold)
#      55     y_prob = y_prob[mask]
#      56     y_true = y_true[mask]
# ---> 58 y_pred = (y_prob >= threshold).astype(int)  # Use configurable threshold
#      60 acc = accuracy_score(y_true, y_pred)
#      62 if len(np.unique(y_true)) < 2:
#
# TypeError: '>=' not supported between instances of 'float' and 'torch.device'

# %%
# ============================================================
# Train Random Forest on Patient-Level Synthetic Data
# ============================================================

print("=" * 60)
print("RANDOM FOREST: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA")
print("=" * 60)

# Train on patient-level synthetic data
print("\nTraining on patient-level synthetic data...")
model_rf_patient_syn = RandomForestClassifier(**rf_best_params, random_state=SEED)
model_rf_patient_syn.fit(X_syn_patient_scaled, y_syn_patient)

# Evaluate on patient-level real data
print("\nEvaluating on patient-level real validation set...")
val_preds_rf_patient_syn = model_rf_patient_syn.predict(X_val_patient_scaled)
val_probs_rf_patient_syn = model_rf_patient_syn.predict_proba(X_val_patient_scaled)[:, 1]
val_metrics_rf_patient_syn = {
    'accuracy': accuracy_score(y_val_patient, val_preds_rf_patient_syn),
    'roc_auc': roc_auc_score(y_val_patient, val_probs_rf_patient_syn),
    'f1': f1_score(y_val_patient, val_preds_rf_patient_syn, zero_division=0),
    'precision': precision_score(y_val_patient, val_preds_rf_patient_syn, zero_division=0),
    'recall': recall_score(y_val_patient, val_preds_rf_patient_syn, zero_division=0)
}

print("\nEvaluating on patient-level real test set...")
test_preds_rf_patient_syn = model_rf_patient_syn.predict(X_test_patient_scaled)
test_probs_rf_patient_syn = model_rf_patient_syn.predict_proba(X_test_patient_scaled)[:, 1]
test_metrics_rf_patient_syn = {
    'accuracy': accuracy_score(y_test_patient, test_preds_rf_patient_syn),
    'roc_auc': roc_auc_score(y_test_patient, test_probs_rf_patient_syn),
    'f1': f1_score(y_test_patient, test_preds_rf_patient_syn, zero_division=0),
    'precision': precision_score(y_test_patient, test_preds_rf_patient_syn, zero_division=0),
    'recall': recall_score(y_test_patient, test_preds_rf_patient_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("RANDOM FOREST RESULTS (Patient-Level Synthetic Training)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_rf_patient_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_rf_patient_syn['roc_auc']:.4f}, F1: {val_metrics_rf_patient_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_rf_patient_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_rf_patient_syn['roc_auc']:.4f}, F1: {test_metrics_rf_patient_syn['f1']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# RANDOM FOREST: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA
# ============================================================
#
# Training on patient-level synthetic data...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 11
#       9 # Train on patient-level synthetic data
#      10 print("\nTraining on patient-level synthetic data...")
# ---> 11 model_rf_patient_syn = RandomForestClassifier(**rf_best_params, random_state=SEED)
#      12 model_rf_patient_syn.fit(X_syn_patient_scaled, y_syn_patient)
#      14 # Evaluate on patient-level real data
#
# TypeError: sklearn.ensemble._forest.RandomForestClassifier() got multiple values for keyword argument 'random_state'

# %%
# ============================================================
# Train XGBoost on Patient-Level Synthetic Data
# ============================================================

print("=" * 60)
print("XGBOOST: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA")
print("=" * 60)

# Train on patient-level synthetic data
print("\nTraining on patient-level synthetic data...")
model_xgb_patient_syn = xgb.XGBClassifier(**xgb_best_params, random_state=SEED)
model_xgb_patient_syn.fit(X_syn_patient_scaled, y_syn_patient)

# Evaluate on patient-level real data
print("\nEvaluating on patient-level real validation set...")
val_preds_xgb_patient_syn = model_xgb_patient_syn.predict(X_val_patient_scaled)
val_probs_xgb_patient_syn = model_xgb_patient_syn.predict_proba(X_val_patient_scaled)[:, 1]
val_metrics_xgb_patient_syn = {
    'accuracy': accuracy_score(y_val_patient, val_preds_xgb_patient_syn),
    'roc_auc': roc_auc_score(y_val_patient, val_probs_xgb_patient_syn),
    'f1': f1_score(y_val_patient, val_preds_xgb_patient_syn, zero_division=0),
    'precision': precision_score(y_val_patient, val_preds_xgb_patient_syn, zero_division=0),
    'recall': recall_score(y_val_patient, val_preds_xgb_patient_syn, zero_division=0)
}

print("\nEvaluating on patient-level real test set...")
test_preds_xgb_patient_syn = model_xgb_patient_syn.predict(X_test_patient_scaled)
test_probs_xgb_patient_syn = model_xgb_patient_syn.predict_proba(X_test_patient_scaled)[:, 1]
test_metrics_xgb_patient_syn = {
    'accuracy': accuracy_score(y_test_patient, test_preds_xgb_patient_syn),
    'roc_auc': roc_auc_score(y_test_patient, test_probs_xgb_patient_syn),
    'f1': f1_score(y_test_patient, test_preds_xgb_patient_syn, zero_division=0),
    'precision': precision_score(y_test_patient, test_preds_xgb_patient_syn, zero_division=0),
    'recall': recall_score(y_test_patient, test_preds_xgb_patient_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("XGBOOST RESULTS (Patient-Level Synthetic Training)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_xgb_patient_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_xgb_patient_syn['roc_auc']:.4f}, F1: {val_metrics_xgb_patient_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_xgb_patient_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_xgb_patient_syn['roc_auc']:.4f}, F1: {test_metrics_xgb_patient_syn['f1']:.4f}")
print("=" * 60)

# %%
# ============================================================
# Train Logistic Regression on Patient-Level Synthetic Data
# ============================================================

print("=" * 60)
print("LOGISTIC REGRESSION: TRAIN ON PATIENT-LEVEL SYNTHETIC DATA")
print("=" * 60)

# Train on patient-level synthetic data
print("\nTraining on patient-level synthetic data...")
model_lr_patient_syn = LogisticRegression(**lr_best_params, random_state=SEED, max_iter=1000)
model_lr_patient_syn.fit(X_syn_patient_scaled, y_syn_patient)

# Evaluate on patient-level real data
print("\nEvaluating on patient-level real validation set...")
val_preds_lr_patient_syn = model_lr_patient_syn.predict(X_val_patient_scaled)
val_probs_lr_patient_syn = model_lr_patient_syn.predict_proba(X_val_patient_scaled)[:, 1]
val_metrics_lr_patient_syn = {
    'accuracy': accuracy_score(y_val_patient, val_preds_lr_patient_syn),
    'roc_auc': roc_auc_score(y_val_patient, val_probs_lr_patient_syn),
    'f1': f1_score(y_val_patient, val_preds_lr_patient_syn, zero_division=0),
    'precision': precision_score(y_val_patient, val_preds_lr_patient_syn, zero_division=0),
    'recall': recall_score(y_val_patient, val_preds_lr_patient_syn, zero_division=0)
}

print("\nEvaluating on patient-level real test set...")
test_preds_lr_patient_syn = model_lr_patient_syn.predict(X_test_patient_scaled)
test_probs_lr_patient_syn = model_lr_patient_syn.predict_proba(X_test_patient_scaled)[:, 1]
test_metrics_lr_patient_syn = {
    'accuracy': accuracy_score(y_test_patient, test_preds_lr_patient_syn),
    'roc_auc': roc_auc_score(y_test_patient, test_probs_lr_patient_syn),
    'f1': f1_score(y_test_patient, test_preds_lr_patient_syn, zero_division=0),
    'precision': precision_score(y_test_patient, test_preds_lr_patient_syn, zero_division=0),
    'recall': recall_score(y_test_patient, test_preds_lr_patient_syn, zero_division=0)
}

print("\n" + "=" * 60)
print("LOGISTIC REGRESSION RESULTS (Patient-Level Synthetic Training)")
print("=" * 60)
print(f"Validation - Acc: {val_metrics_lr_patient_syn['accuracy']:.4f}, ROC-AUC: {val_metrics_lr_patient_syn['roc_auc']:.4f}, F1: {val_metrics_lr_patient_syn['f1']:.4f}")
print(f"Test       - Acc: {test_metrics_lr_patient_syn['accuracy']:.4f}, ROC-AUC: {test_metrics_lr_patient_syn['roc_auc']:.4f}, F1: {test_metrics_lr_patient_syn['f1']:.4f}")
print("=" * 60)

# %% [markdown]
# ### 15.4. Summary: Patient-Level Synthetic Training Results

# %%
# ============================================================
# Summary: Patient-Level Synthetic Training Results
# ============================================================

print("=" * 80)
print("PATIENT-LEVEL SYNTHETIC TRAINING: COMPREHENSIVE RESULTS")
print("=" * 80)

# Collect all results
patient_syn_results = []

# Neural Network
patient_syn_results.append({
    'Model': 'Neural Network',
    'Val_Acc': val_metrics_nn_patient_syn['accuracy'],
    'Val_ROC_AUC': val_metrics_nn_patient_syn['roc_auc'],
    'Val_F1': val_metrics_nn_patient_syn['f1'],
    'Test_Acc': test_metrics_nn_patient_syn['accuracy'],
    'Test_ROC_AUC': test_metrics_nn_patient_syn['roc_auc'],
    'Test_F1': test_metrics_nn_patient_syn['f1']
})

# Random Forest
patient_syn_results.append({
    'Model': 'Random Forest',
    'Val_Acc': val_metrics_rf_patient_syn['accuracy'],
    'Val_ROC_AUC': val_metrics_rf_patient_syn['roc_auc'],
    'Val_F1': val_metrics_rf_patient_syn['f1'],
    'Test_Acc': test_metrics_rf_patient_syn['accuracy'],
    'Test_ROC_AUC': test_metrics_rf_patient_syn['roc_auc'],
    'Test_F1': test_metrics_rf_patient_syn['f1']
})

# XGBoost
patient_syn_results.append({
    'Model': 'XGBoost',
    'Val_Acc': val_metrics_xgb_patient_syn['accuracy'],
    'Val_ROC_AUC': val_metrics_xgb_patient_syn['roc_auc'],
    'Val_F1': val_metrics_xgb_patient_syn['f1'],
    'Test_Acc': test_metrics_xgb_patient_syn['accuracy'],
    'Test_ROC_AUC': test_metrics_xgb_patient_syn['roc_auc'],
    'Test_F1': test_metrics_xgb_patient_syn['f1']
})

# Logistic Regression
patient_syn_results.append({
    'Model': 'Logistic Regression',
    'Val_Acc': val_metrics_lr_patient_syn['accuracy'],
    'Val_ROC_AUC': val_metrics_lr_patient_syn['roc_auc'],
    'Val_F1': val_metrics_lr_patient_syn['f1'],
    'Test_Acc': test_metrics_lr_patient_syn['accuracy'],
    'Test_ROC_AUC': test_metrics_lr_patient_syn['roc_auc'],
    'Test_F1': test_metrics_lr_patient_syn['f1']
})

# Create DataFrame
patient_syn_df = pd.DataFrame(patient_syn_results)

print("\n" + "=" * 80)
print("PATIENT-LEVEL SYNTHETIC TRAINING RESULTS")
print("=" * 80)
print(patient_syn_df.to_string(index=False))
print("=" * 80)

# Save results
patient_syn_df.to_csv(OUTPUT_DIR / 'patient_level_synthetic_training_results.csv', index=False)
print(f"\n✓ Saved results to: {OUTPUT_DIR / 'patient_level_synthetic_training_results.csv'}")

# Create visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

models = patient_syn_df['Model'].values
val_accs = patient_syn_df['Val_Acc'].values
val_rocs = patient_syn_df['Val_ROC_AUC'].values
val_f1s = patient_syn_df['Val_F1'].values
test_accs = patient_syn_df['Test_Acc'].values
test_rocs = patient_syn_df['Test_ROC_AUC'].values
test_f1s = patient_syn_df['Test_F1'].values

x = np.arange(len(models))
width = 0.6

# Validation metrics
axes[0, 0].bar(x, val_accs, width, alpha=0.8, color='steelblue')
axes[0, 0].set_xlabel('Model', fontsize=12)
axes[0, 0].set_ylabel('Accuracy', fontsize=12)
axes[0, 0].set_title('Validation Accuracy: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[0, 0].set_xticks(x)
axes[0, 0].set_xticklabels(models, rotation=45, ha='right')
axes[0, 0].grid(True, alpha=0.3, axis='y')
axes[0, 0].set_ylim([0, 1.05])

axes[0, 1].bar(x, val_rocs, width, alpha=0.8, color='darkorange')
axes[0, 1].set_xlabel('Model', fontsize=12)
axes[0, 1].set_ylabel('ROC-AUC', fontsize=12)
axes[0, 1].set_title('Validation ROC-AUC: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[0, 1].set_xticks(x)
axes[0, 1].set_xticklabels(models, rotation=45, ha='right')
axes[0, 1].grid(True, alpha=0.3, axis='y')
axes[0, 1].set_ylim([0, 1.05])

axes[0, 2].bar(x, val_f1s, width, alpha=0.8, color='forestgreen')
axes[0, 2].set_xlabel('Model', fontsize=12)
axes[0, 2].set_ylabel('F1 Score', fontsize=12)
axes[0, 2].set_title('Validation F1 Score: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[0, 2].set_xticks(x)
axes[0, 2].set_xticklabels(models, rotation=45, ha='right')
axes[0, 2].grid(True, alpha=0.3, axis='y')
axes[0, 2].set_ylim([0, 1.05])

# Test metrics
axes[1, 0].bar(x, test_accs, width, alpha=0.8, color='steelblue')
axes[1, 0].set_xlabel('Model', fontsize=12)
axes[1, 0].set_ylabel('Accuracy', fontsize=12)
axes[1, 0].set_title('Test Accuracy: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[1, 0].set_xticks(x)
axes[1, 0].set_xticklabels(models, rotation=45, ha='right')
axes[1, 0].grid(True, alpha=0.3, axis='y')
axes[1, 0].set_ylim([0, 1.05])

axes[1, 1].bar(x, test_rocs, width, alpha=0.8, color='darkorange')
axes[1, 1].set_xlabel('Model', fontsize=12)
axes[1, 1].set_ylabel('ROC-AUC', fontsize=12)
axes[1, 1].set_title('Test ROC-AUC: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[1, 1].set_xticks(x)
axes[1, 1].set_xticklabels(models, rotation=45, ha='right')
axes[1, 1].grid(True, alpha=0.3, axis='y')
axes[1, 1].set_ylim([0, 1.05])

axes[1, 2].bar(x, test_f1s, width, alpha=0.8, color='forestgreen')
axes[1, 2].set_xlabel('Model', fontsize=12)
axes[1, 2].set_ylabel('F1 Score', fontsize=12)
axes[1, 2].set_title('Test F1 Score: Patient-Level Synthetic Training', fontsize=14, fontweight='bold')
axes[1, 2].set_xticks(x)
axes[1, 2].set_xticklabels(models, rotation=45, ha='right')
axes[1, 2].grid(True, alpha=0.3, axis='y')
axes[1, 2].set_ylim([0, 1.05])

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'patient_level_synthetic_training_results.png', dpi=300, bbox_inches='tight')
plt.show()
print(f"\n✓ Saved visualization to: {OUTPUT_DIR / 'patient_level_synthetic_training_results.png'}")
print("=" * 80)
